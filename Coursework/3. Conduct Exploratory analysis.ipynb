# %% [markdown]
# **1. Upload the dataset**

# %%
import pandas as pd

# Specify the file path where the CSV file is located
csv_file_path = "2. Prepared_Comments.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)
df
# Out:
#                                            Comment_Body           Author  \
# 0     Atleast twitter is dying so the world will be ...       Daboormero
# 1         Cheemlon Musk looks like he's constantly high       Matt_32506
# 2     I get my news from dogelore! They are even qui...  RevolverPhoenix
# 3     Now we can call every video uploaded on twitte...        Null42x64
# 4                           Cheemlon Mumsk is so cursed  Forsaken_Ad_475
# ...                                                 ...              ...
# 1940        stop brigading the subreddit and get a life     LarsMacReady
# 1941        I don't think you know what that word means     BruceBrewsky
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...  my_blue_pelican
# 1943                   I missed you too angry pixel man     BruceBrewsky
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...  my_blue_pelican
#
#       Upvotes  Awards                 Date  \
# 0         208       0  2023-07-24 15:32:03
# 1         102       0  2023-07-24 15:56:30
# 2          53       0  2023-07-24 15:57:44
# 3          22       0  2023-07-24 18:01:10
# 4          28       0  2023-07-24 15:45:10
# ...       ...     ...                  ...
# 1940        5       0  2023-07-24 18:20:15
# 1941       -2       0  2023-07-24 18:49:41
# 1942        2       0  2023-07-24 18:59:24
# 1943        1       0  2023-07-24 19:01:24
# 1944        1       0  2023-07-24 19:09:34
#
#                                           Fixed_Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1        Cheemlon Musk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDid not you hav...
# 1943                   I missed you too angry pixel man
# 1944  Still did not learn how to read 😞\n\nIt does n...
#
#                                           Lower_Comment  \
# 0     atleast twitter is dying so the world will be ...
# 1        cheemlon musk looks like he is constantly high
# 2     i get my news from dogelore! they are even qui...
# 3     now we can call every video uploaded on twitte...
# 4                           cheemlon mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941       i do not think you know what that word means
# 1942  sup cum rag? i missed you 😊\n\ndid not you hav...
# 1943                   i missed you too angry pixel man
# 1944  still did not learn how to read 😞\n\nit does n...
#
#                                       Corrected_Comment  \
# 0     least twitter is dying so the world will be a ...
# 1        cheemlon must looks like he is constantly high
# 2     i get my news from dogelore! they are even qui...
# 3     now we can call every video unloaded on twitte...
# 4                            cheemlon must is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       i do not think you know what that word means
# 1942  sup cum rag? i missed you 😊\n\ndid not you hav...
# 1943                   i missed you too angry fixed man
# 1944  still did not learn how to read 😞\n\nit does n...
#
#                                     Substituted_Comment  \
# 0     least twitter is dying so the world will be a ...
# 1        cheemlon must looks like he is constantly high
# 2     i get my news from dogelore! they are even qui...
# 3     now we can call every video unloaded on twitte...
# 4                            cheemlon must is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       i do not think you know what that word means
# 1942  sup cum rag? i missed you 😊\n\ndid not you hav...
# 1943                   i missed you too angry fixed man
# 1944  still did not learn how to read 😞\n\nit does n...
#
#                                        Replaced_Comment  \
# 0     least twitter is dying so the world will be a ...
# 1        cheemlon must looks like he is constantly high
# 2     i get my news from dogelore! they are even qui...
# 3     now we can call every video unloaded on twitte...
# 4                            cheemlon must is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       i do not think you know what that word means
# 1942  sup cum rag? i missed you 😊\n\ndid not you hav...
# 1943                   i missed you too angry fixed man
# 1944  still did not learn how to read 😞\n\nit does n...
#
#                                       Tokenized_Comment  \
# 0     least twitter is dying so the world will be a ...
# 1        cheemlon must looks like he is constantly high
# 2     i get my news from dogelore ! they are even qu...
# 3     now we can call every video unloaded on twitte...
# 4                            cheemlon must is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       i do not think you know what that word means
# 1942  sup cum rag ? i missed you 😊 did not you have ...
# 1943                   i missed you too angry fixed man
# 1944  still did not learn how to read 😞 it does not ...
#
#                                       Without_Stopwords  \
# 0                least twitter dying world better place
# 1              cheemlon must looks like constantly high
# 2         get news dogelore ! even quicker south park !
# 3               call every video unloaded twitter video
# 4                                  cheemlon must cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                              think know word means
# 1942  sup cum rag ? missed 😊 chance go outside today...
# 1943                             missed angry fixed man
# 1944  still learn read 😞 matter , ? one episodes ? t...
#
#                                        Prepared_Comment  \
# 0                least twitter dying world better place
# 1              cheemlon must looks like constantly high
# 2           get news dogelore  even quicker south park
# 3               call every video unloaded twitter video
# 4                                  cheemlon must cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                              think know word means
# 1942  sup cum rag  missed  chance go outside today e...
# 1943                             missed angry fixed man
# 1944  still learn read  matter   one episodes  take ...
#
#                                      Lemmatized_Comment
# 0                least twitter dying world better place
# 1               cheemlon must look like constantly high
# 2             get news dogelore even quicker south park
# 3               call every video unloaded twitter video
# 4                                  cheemlon must cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  sup cum rag missed chance go outside today eit...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
# [1945 rows x 14 columns]

# %% [markdown]
# **2. Remove the unnecessary columns**

# %%
df = df[['Comment_Body', 'Lemmatized_Comment']]
df
# Out:
#                                            Comment_Body  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                      Lemmatized_Comment
# 0                least twitter dying world better place
# 1               cheemlon must look like constantly high
# 2             get news dogelore even quicker south park
# 3               call every video unloaded twitter video
# 4                                  cheemlon must cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  sup cum rag missed chance go outside today eit...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
# [1945 rows x 2 columns]

# %% [markdown]
# **3. Rename the columns**

# %%
df.rename(columns={'Comment_Body': 'Comment', 'Lemmatized_Comment': 'Cleaned_Comment'}, inplace=True)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_75353/4234702429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Comment_Body': 'Comment', 'Lemmatized_Comment': 'Cleaned_Comment'}, inplace=True)
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment
# 0                least twitter dying world better place
# 1               cheemlon must look like constantly high
# 2             get news dogelore even quicker south park
# 3               call every video unloaded twitter video
# 4                                  cheemlon must cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  sup cum rag missed chance go outside today eit...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
# [1945 rows x 2 columns]

# %% [markdown]
# **3. Drop the na rows**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1945 entries, 0 to 1944
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Comment          1945 non-null   object
#  1   Cleaned_Comment  1924 non-null   object
# dtypes: object(2)
# memory usage: 30.5+ KB

# %%
df[df['Cleaned_Comment'].isna()]
# Out:
#             Comment Cleaned_Comment
# 20        me to you             NaN
# 189               🤓             NaN
# 251              Ew             NaN
# 287              👅🥾             NaN
# 606              No             NaN
# 654         Just no             NaN
# 665    Why is what?             NaN
# 778        But why?             NaN
# 790              🤣🤣             NaN
# 815               🙈             NaN
# 842           What?             NaN
# 1068            くそ！             NaN
# 1097             sì             NaN
# 1193             Y？             NaN
# 1265           This             NaN
# 1290          We do             NaN
# 1352            No.             NaN
# 1501              💩             NaN
# 1875  Why not both?             NaN
# 1899              🎯             NaN
# 1928           Same             NaN

# %%
df = df.dropna(subset=['Cleaned_Comment'])
df
# Out:
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment
# 0                least twitter dying world better place
# 1               cheemlon must look like constantly high
# 2             get news dogelore even quicker south park
# 3               call every video unloaded twitter video
# 4                                  cheemlon must cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  sup cum rag missed chance go outside today eit...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
# [1924 rows x 2 columns]

# %% [markdown]
# **5. Detect the language**

# %%
from langdetect import detect

def detect_language(comment):
    try:
        return detect(comment)
    except:
        return None

df['Language'] = df['Cleaned_Comment'].apply(detect_language)
df['Language'].value_counts()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_75353/4139810979.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language'] = df['Cleaned_Comment'].apply(detect_language)
# en    1013
# fr     378
# it     214
# af      34
# no      27
# nl      27
# da      24
# tl      23
# so      22
# ro      15
# es      15
# ca      15
# et      13
# cy      12
# fi      10
# pt      10
# sv       9
# tr       7
# sk       7
# hr       7
# id       7
# sq       6
# pl       5
# sw       5
# sl       4
# cs       4
# de       4
# vi       3
# hu       2
# lt       1
# Name: Language, dtype: int64

# %%
import matplotlib.pyplot as plt

average_lengths = df.groupby('Language')['Cleaned_Comment'].apply(lambda x: x.str.len().mean()).reset_index()
average_lengths.rename(columns={'Cleaned_Comment': 'Average_Length'}, inplace=True)

# Create a bigger bar chart
plt.figure(figsize=(10, 6))

# Plot the bar chart
bar_plot = plt.bar(average_lengths['Language'], average_lengths['Average_Length'])

# Add text annotations with the average lengths on the bars
for i, value in enumerate(average_lengths['Average_Length']):
    plt.annotate(f'{value:.2f}', xy=(i, value), ha='center', va='bottom')

plt.xlabel('Language')
plt.ylabel('Average Length')
plt.title('Average Comment Length by Language')

plt.show()

# %%
import numpy as np

# Assuming 'df' is your DataFrame and 'Language' is the column containing language codes.

# Define the mapping of languages to replace
valid_languages = ["en", "fr", "it"]
replacement_language = "others"

# Use numpy.where() to apply the replacement condition
df['Language'] = np.where(df['Language'].isin(valid_languages), df['Language'], replacement_language)
df['Language'].value_counts()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_75353/3353875031.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language'] = np.where(df['Language'].isin(valid_languages), df['Language'], replacement_language)
# en        1013
# fr         378
# others     319
# it         214
# Name: Language, dtype: int64

# %%
value_counts = df['Language'].value_counts()

# Get the labels (unique values) and their respective counts
labels = value_counts.index.tolist()
counts = value_counts.tolist()

# Calculate percentages
total_count = sum(counts)
percentages = [(count / total_count) * 100 for count in counts]

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=labels, autopct='%.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is drawn as a circle.
plt.title('Pie Chart for Language')
plt.show()

# %%
df = df[df['Language'] == "en"]
df
# Out:
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment Language
# 0                least twitter dying world better place       en
# 1               cheemlon must look like constantly high       en
# 2             get news dogelore even quicker south park       en
# 3               call every video unloaded twitter video       en
# 4                                  cheemlon must cursed       en
# ...                                                 ...      ...
# 1939  hur worst thing elson ever done hur tell stock...       en
# 1941                               think know word mean       en
# 1942  sup cum rag missed chance go outside today eit...       en
# 1943                             missed angry fixed man       en
# 1944  still learn read matter one episode take care ...       en
#
# [1013 rows x 3 columns]

# %% [markdown]
# **6. Calculate the length**

# %%
df['Length'] = df['Cleaned_Comment'].apply(len)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_75353/4127819789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Length'] = df['Cleaned_Comment'].apply(len)
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment Language  Length
# 0                least twitter dying world better place       en      38
# 1               cheemlon must look like constantly high       en      39
# 2             get news dogelore even quicker south park       en      41
# 3               call every video unloaded twitter video       en      39
# 4                                  cheemlon must cursed       en      20
# ...                                                 ...      ...     ...
# 1939  hur worst thing elson ever done hur tell stock...       en      62
# 1941                               think know word mean       en      20
# 1942  sup cum rag missed chance go outside today eit...       en     142
# 1943                             missed angry fixed man       en      22
# 1944  still learn read matter one episode take care ...       en      81
#
# [1013 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1013 entries, 0 to 1944
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Comment          1013 non-null   object
#  1   Cleaned_Comment  1013 non-null   object
#  2   Language         1013 non-null   object
#  3   Length           1013 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 39.6+ KB

# %%
df[df.Length<10]
# Out:
#                           Comment Cleaned_Comment Language  Length
# 105                   a child too           child       en       5
# 448              lol\n\nlmao even        may even       en       8
# 645   Iq isn't real you dill weed       real weed       en       9
# 695                      TwXtter.         twitter       en       7
# 785         Why would he do that?           would       en       5
# 818                         Right           right       en       5
# 845         He is up to something       something       en       9
# 1237        Has he been infected?        infected       en       8
# 1288             He acts like it.        act like       en       8
# 1289              Most certainly!       certainly       en       9
# 1293      He was right about them           right       en       5
# 1300            *Most certainly.*       certainly       en       9
# 1711                   Classe X ?         class x       en       7
# 1896                She got fired       got fired       en       9

# %%
df = df[df.Length>=10]
df
# Out:
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment Language  Length
# 0                least twitter dying world better place       en      38
# 1               cheemlon must look like constantly high       en      39
# 2             get news dogelore even quicker south park       en      41
# 3               call every video unloaded twitter video       en      39
# 4                                  cheemlon must cursed       en      20
# ...                                                 ...      ...     ...
# 1939  hur worst thing elson ever done hur tell stock...       en      62
# 1941                               think know word mean       en      20
# 1942  sup cum rag missed chance go outside today eit...       en     142
# 1943                             missed angry fixed man       en      22
# 1944  still learn read matter one episode take care ...       en      81
#
# [999 rows x 4 columns]

# %%
df.Length.describe()
# Out:
# count     999.000000
# mean      104.463463
# std       128.814116
# min        10.000000
# 25%        36.000000
# 50%        65.000000
# 75%       119.000000
# max      1401.000000
# Name: Length, dtype: float64

# %%
df.Length.mode()
# Out:
# 0    23
# Name: Length, dtype: int64

# %% [markdown]
# **7. Term Frequency**

# %%
from collections import Counter

all_comments = ' '.join(df['Cleaned_Comment'])

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

words = word_tokenize(all_comments)

word_counter = Counter(words)

most_common_words = word_counter.most_common(20)

print("Most common 20 words and their frequencies:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most common 20 words and their frequencies:
# twitter: 263
# like: 180
# people: 180
# SIZE: 149
# elson: 145
# x: 130
# one: 125
# think: 122
# would: 118
# company: 115
# make: 95
# must: 93
# get: 81
# want: 78
# thing: 76
# could: 76
# going: 72
# pp: 71
# know: 71
# money: 70
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **8. Word Clouds**

# %%
from wordcloud import WordCloud

all_comments = ' '.join(df['Cleaned_Comment'])

words = word_tokenize(all_comments)
word_counter = Counter(words)
most_common_words = word_counter.most_common(200)

word_freq_dict = dict(most_common_words)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Most Common 200 Words')
plt.show()

# %% [markdown]
# **9. Extracting noun phrases with TextBlob**

# %%
from textblob import TextBlob
nltk.download('brown')

all_comments = ' '.join(df['Cleaned_Comment'])

# Create a TextBlob object
blob = TextBlob(all_comments)

# Extract noun phrases
noun_phrases = blob.noun_phrases

# Count the occurrences of each noun phrase using Counter
noun_phrase_counter = Counter(noun_phrases)

# Get the 10 most common noun phrases
most_common_noun_phrases = noun_phrase_counter.most_common(10)

# Print the results
print("10 most common noun phrases:")
for noun_phrase, frequency in most_common_noun_phrases:
    print(f"{noun_phrase}: {frequency}")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 10 most common noun phrases:
# size: 120
# link: 48
# price: 22
# echo chamber: 11
# social medium: 9
# emerald mine: 5
# size size: 5
# twitter x: 4
# social medium platform: 4
# buying twitter: 4

# %% [markdown]
# **10. Performing the LDA Topic Modelling**

# %%
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from nltk.tokenize import word_tokenize

nltk.download('punkt')

def tokenize_text(text):
    return word_tokenize(text)

df['Tokenized_Comment'] = df['Cleaned_Comment'].apply(tokenize_text)

# Create a dictionary from the tokenized words
dictionary = Dictionary(df['Tokenized_Comment'])

# Create a Bag-of-Words (BOW) representation for each document
bow_corpus = [dictionary.doc2bow(doc) for doc in df['Tokenized_Comment']]

# Train the LDA model
num_topics = 5  # You can set the number of topics as per your requirement
lda_model = LdaModel(corpus=bow_corpus, id2word=dictionary, num_topics=num_topics, passes=10)

# Print the topics and their top words
print("LDA Topics:")
for idx, topic in lda_model.print_topics():
    print(f"Topic {idx}: {topic}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_75353/1651847919.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tokenized_Comment'] = df['Cleaned_Comment'].apply(tokenize_text)
# LDA Topics:
# Topic 0: 0.014*"SIZE" + 0.013*"elson" + 0.012*"twitter" + 0.011*"would" + 0.010*"people" + 0.010*"x" + 0.008*"like" + 0.008*"one" + 0.006*"company" + 0.006*"must"
# Topic 1: 0.015*"twitter" + 0.015*"people" + 0.013*"like" + 0.010*"think" + 0.009*"one" + 0.007*"going" + 0.006*"company" + 0.006*"make" + 0.006*"get" + 0.006*"money"
# Topic 2: 0.023*"twitter" + 0.010*"elson" + 0.009*"x" + 0.008*"company" + 0.008*"name" + 0.007*"still" + 0.006*"like" + 0.006*"new" + 0.006*"log" + 0.006*"would"
# Topic 3: 0.008*"like" + 0.008*"people" + 0.008*"x" + 0.007*"must" + 0.006*"know" + 0.006*"”" + 0.006*"“" + 0.005*"way" + 0.005*"xcom" + 0.005*"man"
# Topic 4: 0.013*"twitter" + 0.011*"think" + 0.010*"like" + 0.008*"make" + 0.008*"pp" + 0.007*"one" + 0.005*"people" + 0.005*"thing" + 0.005*"going" + 0.005*"SIZE"
