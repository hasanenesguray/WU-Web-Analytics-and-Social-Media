# %% [markdown]
# **1. Upload the dataset**

# %%
import pandas as pd

# Specify the file path where the CSV file is located
csv_file_path = "2. Prepared_Comments.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)
df
# Out:
#                                            Comment_Body           Author  \
# 0     Atleast twitter is dying so the world will be ...       Daboormero
# 1         Cheemlon Musk looks like he's constantly high       Matt_32506
# 2     I get my news from dogelore! They are even qui...  RevolverPhoenix
# 3     Now we can call every video uploaded on twitte...        Null42x64
# 4                           Cheemlon Mumsk is so cursed  Forsaken_Ad_475
# ...                                                 ...              ...
# 1940        stop brigading the subreddit and get a life     LarsMacReady
# 1941        I don't think you know what that word means     BruceBrewsky
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...  my_blue_pelican
# 1943                   I missed you too angry pixel man     BruceBrewsky
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...  my_blue_pelican
#
#       Upvotes  Awards                 Date  \
# 0         208       0  2023-07-24 15:32:03
# 1         102       0  2023-07-24 15:56:30
# 2          53       0  2023-07-24 15:57:44
# 3          22       0  2023-07-24 18:01:10
# 4          28       0  2023-07-24 15:45:10
# ...       ...     ...                  ...
# 1940        5       0  2023-07-24 18:20:15
# 1941       -2       0  2023-07-24 18:49:41
# 1942        2       0  2023-07-24 18:59:24
# 1943        1       0  2023-07-24 19:01:24
# 1944        1       0  2023-07-24 19:09:34
#
#                                           Fixed_Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1        Cheemlon Musk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDid not you hav...
# 1943                   I missed you too angry pixel man
# 1944  Still did not learn how to read 😞\n\nIt does n...
#
#                                     Substituted_Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1        Cheemlon Musk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDid not you hav...
# 1943                   I missed you too angry pixel man
# 1944  Still did not learn how to read 😞\n\nIt does n...
#
#                                        Replaced_Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1        Cheemlon Musk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDid not you hav...
# 1943                   I missed you too angry pixel man
# 1944  Still did not learn how to read 😞\n\nIt does n...
#
#                                      Without_LineBreaks  \
# 0     Atleast twitter is dying so the world will be ...
# 1        Cheemlon Musk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Sup cum rag? I missed you 😊  Did not you have ...
# 1943                   I missed you too angry pixel man
# 1944  Still did not learn how to read 😞  It does not...
#
#                    Corrected_Comment(SentimentAnalysis)  \
# 0     Least twitter is dying so the world will be a ...
# 1        Cheemlon Dusk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video unloaded on twitte...
# 4                            Cheemlon Sums is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Up cum rag? I missed you 😊  Did not you have t...
# 1943                   I missed you too angry fixed man
# 1944  Still did not learn how to read 😞  It does not...
#
#                                           Lower_Comment  \
# 0     least twitter is dying so the world will be a ...
# 1        cheemlon dusk looks like he is constantly high
# 2     i get my news from dogelore! they are even qui...
# 3     now we can call every video unloaded on twitte...
# 4                            cheemlon sums is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       i do not think you know what that word means
# 1942  up cum rag? i missed you 😊  did not you have t...
# 1943                   i missed you too angry fixed man
# 1944  still did not learn how to read 😞  it does not...
#
#                                       Tokenized_Comment  \
# 0     least twitter is dying so the world will be a ...
# 1        cheemlon dusk looks like he is constantly high
# 2     i get my news from dogelore ! they are even qu...
# 3     now we can call every video unloaded on twitte...
# 4                            cheemlon sums is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       i do not think you know what that word means
# 1942  up cum rag ? i missed you 😊 did not you have t...
# 1943                   i missed you too angry fixed man
# 1944  still did not learn how to read 😞 it does not ...
#
#                                       Without_Stopwords  \
# 0                least twitter dying world better place
# 1              cheemlon dusk looks like constantly high
# 2         get news dogelore ! even quicker south dark !
# 3             call every video unloaded twitter xvideos
# 4                                  cheemlon sums cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                              think know word means
# 1942  cum rag ? missed 😊 chance go outside today eit...
# 1943                             missed angry fixed man
# 1944  still learn read 😞 matter , ? one episodes ? t...
#
#                                        Prepared_Comment  \
# 0                least twitter dying world better place
# 1              cheemlon dusk looks like constantly high
# 2           get news dogelore  even quicker south dark
# 3             call every video unloaded twitter xvideos
# 4                                  cheemlon sums cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                              think know word means
# 1942  cum rag  missed  chance go outside today eithe...
# 1943                             missed angry fixed man
# 1944  still learn read  matter   one episodes  take ...
#
#                                      Lemmatized_Comment
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 2             get news dogelore even quicker south dark
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
# [1945 rows x 15 columns]

# %% [markdown]
# **2. Remove the unnecessary columns**

# %%
df = df[['Comment_Body', 'Lemmatized_Comment', 'Corrected_Comment(SentimentAnalysis)']]
df
# Out:
#                                            Comment_Body  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                      Lemmatized_Comment  \
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 2             get news dogelore even quicker south dark
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                    Corrected_Comment(SentimentAnalysis)
# 0     Least twitter is dying so the world will be a ...
# 1        Cheemlon Dusk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video unloaded on twitte...
# 4                            Cheemlon Sums is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Up cum rag? I missed you 😊  Did not you have t...
# 1943                   I missed you too angry fixed man
# 1944  Still did not learn how to read 😞  It does not...
#
# [1945 rows x 3 columns]

# %% [markdown]
# **3. Rename the columns**

# %%
df.rename(columns={'Comment_Body': 'Comment', 'Lemmatized_Comment': 'Cleaned_Comment',
                   'Corrected_Comment(SentimentAnalysis)': 'Sentiment_Comment'}, inplace=True)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/3350974763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Comment_Body': 'Comment', 'Lemmatized_Comment': 'Cleaned_Comment',
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment  \
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 2             get news dogelore even quicker south dark
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                                       Sentiment_Comment
# 0     Least twitter is dying so the world will be a ...
# 1        Cheemlon Dusk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video unloaded on twitte...
# 4                            Cheemlon Sums is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Up cum rag? I missed you 😊  Did not you have t...
# 1943                   I missed you too angry fixed man
# 1944  Still did not learn how to read 😞  It does not...
#
# [1945 rows x 3 columns]

# %% [markdown]
# **3. Drop the na rows**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1945 entries, 0 to 1944
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Comment            1945 non-null   object
#  1   Cleaned_Comment    1925 non-null   object
#  2   Sentiment_Comment  1945 non-null   object
# dtypes: object(3)
# memory usage: 45.7+ KB

# %%
df[df['Cleaned_Comment'].isna()]
# Out:
#             Comment Cleaned_Comment Sentiment_Comment
# 20        me to you             NaN         me to you
# 189               🤓             NaN                 🤓
# 287              👅🥾             NaN                👅🥾
# 606              No             NaN                To
# 665    Why is what?             NaN      Why is what?
# 778        But why?             NaN          But why?
# 790              🤣🤣             NaN                🤣🤣
# 815               🙈             NaN                 🙈
# 842           What?             NaN             That?
# 1045        Un che?             NaN           In the?
# 1068            くそ！             NaN               of！
# 1097             sì             NaN                 s
# 1193             Y？             NaN                Y？
# 1265           This             NaN               His
# 1290          We do             NaN             He do
# 1352            No.             NaN               To.
# 1501              💩             NaN                 💩
# 1875  Why not both?             NaN     Why not both?
# 1899              🎯             NaN                 🎯
# 1928           Same             NaN              Same

# %%
df = df.dropna(subset=['Cleaned_Comment'])
df
# Out:
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# ...                                                 ...
# 1940        stop brigading the subreddit and get a life
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment  \
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 2             get news dogelore even quicker south dark
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# ...                                                 ...
# 1940                   stop bridging subreddit get life
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                                       Sentiment_Comment
# 0     Least twitter is dying so the world will be a ...
# 1        Cheemlon Dusk looks like he is constantly high
# 2     I get my news from dogelore! They are even qui...
# 3     Now we can call every video unloaded on twitte...
# 4                            Cheemlon Sums is so cursed
# ...                                                 ...
# 1940         stop bridging the subreddit and get a life
# 1941       I do not think you know what that word means
# 1942  Up cum rag? I missed you 😊  Did not you have t...
# 1943                   I missed you too angry fixed man
# 1944  Still did not learn how to read 😞  It does not...
#
# [1925 rows x 3 columns]

# %% [markdown]
# **5. Detect the language**

# %%
from langdetect import detect

def detect_language(comment):
    try:
        return detect(comment)
    except:
        return None

df['Language'] = df['Cleaned_Comment'].apply(detect_language)
df['Language'].value_counts()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/4139810979.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language'] = df['Cleaned_Comment'].apply(detect_language)
# en    1003
# fr     366
# it     212
# af      33
# no      31
# nl      27
# so      24
# ro      23
# fi      19
# da      18
# tl      16
# es      15
# et      15
# ca      14
# cy      13
# tr      12
# pt      10
# de       9
# sv       9
# hr       8
# sw       7
# id       7
# pl       6
# sk       6
# sq       5
# cs       4
# vi       3
# hu       3
# lt       3
# sl       2
# lv       1
# Name: Language, dtype: int64

# %%
import matplotlib.pyplot as plt

average_lengths = df.groupby('Language')['Cleaned_Comment'].apply(lambda x: x.str.len().mean()).reset_index()
average_lengths.rename(columns={'Cleaned_Comment': 'Average_Length'}, inplace=True)

# Create a bigger bar chart
plt.figure(figsize=(10, 6))

# Plot the bar chart
bar_plot = plt.bar(average_lengths['Language'], average_lengths['Average_Length'])

# Add text annotations with the average lengths on the bars
for i, value in enumerate(average_lengths['Average_Length']):
    plt.annotate(f'{value:.2f}', xy=(i, value), ha='center', va='bottom')

plt.xlabel('Language')
plt.ylabel('Average Length')
plt.title('Average Comment Length by Language')

plt.show()

# %%
import numpy as np

# Assuming 'df' is your DataFrame and 'Language' is the column containing language codes.

# Define the mapping of languages to replace
valid_languages = ["en", "fr", "it"]
replacement_language = "others"

# Use numpy.where() to apply the replacement condition
df['Language'] = np.where(df['Language'].isin(valid_languages), df['Language'], replacement_language)
df['Language'].value_counts()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/3353875031.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language'] = np.where(df['Language'].isin(valid_languages), df['Language'], replacement_language)
# en        1003
# fr         366
# others     344
# it         212
# Name: Language, dtype: int64

# %%
value_counts = df['Language'].value_counts()

# Get the labels (unique values) and their respective counts
labels = value_counts.index.tolist()
counts = value_counts.tolist()

# Calculate percentages
total_count = sum(counts)
percentages = [(count / total_count) * 100 for count in counts]

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=labels, autopct='%.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is drawn as a circle.
plt.title('Pie Chart for Language')
plt.show()

# %%
df = df[df['Language'] == "en"]
df
# Out:
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# 5     I remember listening to the Behind the Bastard...
# ...                                                 ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment  \
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# 5     remember listening behind bastard series dusk ...
# ...                                                 ...
# 1939  worst thing ever done hur cela stock steadily ...
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                                       Sentiment_Comment Language
# 0     Least twitter is dying so the world will be a ...       en
# 1        Cheemlon Dusk looks like he is constantly high       en
# 3     Now we can call every video unloaded on twitte...       en
# 4                            Cheemlon Sums is so cursed       en
# 5     I remember listening to the Behind the Bastard...       en
# ...                                                 ...      ...
# 1939  Our our it is the worst thing On has ever done...       en
# 1941       I do not think you know what that word means       en
# 1942  Up cum rag? I missed you 😊  Did not you have t...       en
# 1943                   I missed you too angry fixed man       en
# 1944  Still did not learn how to read 😞  It does not...       en
#
# [1003 rows x 4 columns]

# %% [markdown]
# **6. Calculate the length**

# %%
df['Length'] = df['Cleaned_Comment'].apply(len)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/4127819789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Length'] = df['Cleaned_Comment'].apply(len)
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# 5     I remember listening to the Behind the Bastard...
# ...                                                 ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment  \
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# 5     remember listening behind bastard series dusk ...
# ...                                                 ...
# 1939  worst thing ever done hur cela stock steadily ...
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                                       Sentiment_Comment Language  Length
# 0     Least twitter is dying so the world will be a ...       en      38
# 1        Cheemlon Dusk looks like he is constantly high       en      39
# 3     Now we can call every video unloaded on twitte...       en      41
# 4                            Cheemlon Sums is so cursed       en      19
# 5     I remember listening to the Behind the Bastard...       en     131
# ...                                                 ...      ...     ...
# 1939  Our our it is the worst thing On has ever done...       en      52
# 1941       I do not think you know what that word means       en      20
# 1942  Up cum rag? I missed you 😊  Did not you have t...       en     138
# 1943                   I missed you too angry fixed man       en      22
# 1944  Still did not learn how to read 😞  It does not...       en      81
#
# [1003 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1003 entries, 0 to 1944
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Comment            1003 non-null   object
#  1   Cleaned_Comment    1003 non-null   object
#  2   Sentiment_Comment  1003 non-null   object
#  3   Language           1003 non-null   object
#  4   Length             1003 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 47.0+ KB

# %%
df[df.Length<10]
# Out:
#                       Comment Cleaned_Comment        Sentiment_Comment  \
# 105               a child too           child              a child too
# 107                    Latinx          eating                   Eating
# 695                  TwXtter.         twitter                 twitter.
# 818                     Right           right                    Right
# 845     He is up to something       something    He is up to something
# 951            Che buffone...         buffoon           The buffoon...
# 1237    Has he been infected?        infected    Was he been infected?
# 1288         He acts like it.        act like         He acts like it.
# 1289          Most certainly!       certainly          Most certainly!
# 1293  He was right about them           right  He was right about them
# 1300        *Most certainly.*       certainly        *Most certainly.*
# 1896            She got fired       got fired            The got fired
#
#      Language  Length
# 105        en       5
# 107        en       6
# 695        en       7
# 818        en       5
# 845        en       9
# 951        en       7
# 1237       en       8
# 1288       en       8
# 1289       en       9
# 1293       en       5
# 1300       en       9
# 1896       en       9

# %%
df = df[df.Length>=10]
df
# Out:
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# 5     I remember listening to the Behind the Bastard...
# ...                                                 ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment  \
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# 5     remember listening behind bastard series dusk ...
# ...                                                 ...
# 1939  worst thing ever done hur cela stock steadily ...
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                                       Sentiment_Comment Language  Length
# 0     Least twitter is dying so the world will be a ...       en      38
# 1        Cheemlon Dusk looks like he is constantly high       en      39
# 3     Now we can call every video unloaded on twitte...       en      41
# 4                            Cheemlon Sums is so cursed       en      19
# 5     I remember listening to the Behind the Bastard...       en     131
# ...                                                 ...      ...     ...
# 1939  Our our it is the worst thing On has ever done...       en      52
# 1941       I do not think you know what that word means       en      20
# 1942  Up cum rag? I missed you 😊  Did not you have t...       en     138
# 1943                   I missed you too angry fixed man       en      22
# 1944  Still did not learn how to read 😞  It does not...       en      81
#
# [991 rows x 5 columns]

# %%
df.Length.describe()
# Out:
# count     991.000000
# mean      104.306761
# std       128.308068
# min        10.000000
# 25%        36.500000
# 50%        65.000000
# 75%       118.000000
# max      1402.000000
# Name: Length, dtype: float64

# %%
df.Length.mode()
# Out:
# 0    23
# Name: Length, dtype: int64

# %% [markdown]
# **7. Term Frequency**

# %%
from collections import Counter

all_comments = ' '.join(df['Cleaned_Comment'])

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

words = word_tokenize(all_comments)

word_counter = Counter(words)

most_common_words = word_counter.most_common(20)

print("Most common 20 words and their frequencies:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most common 20 words and their frequencies:
# twitter: 258
# like: 181
# people: 180
# x: 147
# size: 137
# one: 127
# would: 123
# think: 122
# company: 117
# make: 92
# dusk: 80
# want: 79
# thing: 76
# get: 76
# going: 71
# could: 70
# know: 69
# money: 68
# time: 63
# name: 61
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **8. Word Clouds**

# %%
from wordcloud import WordCloud

all_comments = ' '.join(df['Cleaned_Comment'])

words = word_tokenize(all_comments)
word_counter = Counter(words)
most_common_words = word_counter.most_common(200)

word_freq_dict = dict(most_common_words)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Most Common 200 Words')
plt.show()

# %% [markdown]
# **9. Extracting noun phrases with TextBlob**

# %%
from textblob import TextBlob
nltk.download('brown')

all_comments = ' '.join(df['Cleaned_Comment'])

# Create a TextBlob object
blob = TextBlob(all_comments)

# Extract noun phrases
noun_phrases = blob.noun_phrases

# Count the occurrences of each noun phrase using Counter
noun_phrase_counter = Counter(noun_phrases)

# Get the 10 most common noun phrases
most_common_noun_phrases = noun_phrase_counter.most_common(10)

# Print the results
print("10 most common noun phrases:")
for noun_phrase, frequency in most_common_noun_phrases:
    print(f"{noun_phrase}: {frequency}")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 10 most common noun phrases:
# size year: 11
# echo chamber: 11
# social medium: 9
# emerald mine: 5
# social medium platform: 4
# buying twitter: 4
# money company: 4
# free speech: 4
# twitter x: 3
# new company: 3

# %% [markdown]
# **10. Performing the LDA Topic Modelling**

# %%
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from nltk.tokenize import word_tokenize

nltk.download('punkt')

def tokenize_text(text):
    return word_tokenize(text)

df['Tokenized_Comment'] = df['Cleaned_Comment'].apply(tokenize_text)

# Create a dictionary from the tokenized words
dictionary = Dictionary(df['Tokenized_Comment'])

# Create a Bag-of-Words (BOW) representation for each document
bow_corpus = [dictionary.doc2bow(doc) for doc in df['Tokenized_Comment']]

# Train the LDA model
num_topics = 5  # You can set the number of topics as per your requirement
lda_model = LdaModel(corpus=bow_corpus, id2word=dictionary, num_topics=num_topics, passes=10)

# Print the topics and their top words
print("LDA Topics:")
for idx, topic in lda_model.print_topics():
    print(f"Topic {idx}: {topic}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/1651847919.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tokenized_Comment'] = df['Cleaned_Comment'].apply(tokenize_text)
# LDA Topics:
# Topic 0: 0.014*"size" + 0.012*"like" + 0.011*"twitter" + 0.010*"people" + 0.009*"think" + 0.008*"company" + 0.007*"would" + 0.006*"x" + 0.005*"dusk" + 0.005*"literally"
# Topic 1: 0.012*"people" + 0.012*"one" + 0.009*"want" + 0.009*"“" + 0.008*"”" + 0.007*"pp" + 0.007*"twitter" + 0.007*"x" + 0.007*"like" + 0.005*"company"
# Topic 2: 0.010*"people" + 0.009*"company" + 0.008*"think" + 0.008*"know" + 0.008*"twitter" + 0.007*"size" + 0.007*"like" + 0.006*"money" + 0.006*"time" + 0.005*"back"
# Topic 3: 0.020*"twitter" + 0.014*"x" + 0.013*"would" + 0.013*"like" + 0.009*"size" + 0.006*"dusk" + 0.006*"make" + 0.006*"going" + 0.006*"one" + 0.006*"think"
# Topic 4: 0.018*"twitter" + 0.011*"people" + 0.009*"one" + 0.009*"get" + 0.005*"even" + 0.005*"new" + 0.005*"really" + 0.005*"thing" + 0.005*"pp" + 0.005*"know"

# %% [markdown]
# **11. Conduct a sentiment analysis with VADER model**

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()

# Function to get the sentiment score using VADER
def get_sentiment_score(text):
    return analyzer.polarity_scores(text)['compound']

# Apply the function to the "Sentiment_Comment" column
df['SentimentScore_VADER'] = df['Sentiment_Comment'].apply(get_sentiment_score)

# Categorize the sentiment based on the sentiment score
df['SentimentCategory_VADER'] = df['SentimentScore_VADER'].apply(lambda score: 'Positive' if score >= 0.05 else ('Negative' if score <= -0.05 else 'Neutral'))

# Print the DataFrame with sentiment scores and categories
df[['Sentiment_Comment', 'SentimentScore_VADER', 'SentimentCategory_VADER']]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/772916522.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SentimentScore_VADER'] = df['Sentiment_Comment'].apply(get_sentiment_score)
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/772916522.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SentimentCategory_VADER'] = df['SentimentScore_VADER'].apply(lambda score: 'Positive' if score >= 0.05 else ('Negative' if score <= -0.05 else 'Neutral'))
#                                       Sentiment_Comment  SentimentScore_VADER  \
# 0     Least twitter is dying so the world will be a ...                0.4404
# 1        Cheemlon Dusk looks like he is constantly high                0.3612
# 3     Now we can call every video unloaded on twitte...                0.0000
# 4                            Cheemlon Sums is so cursed                0.0000
# 5     I remember listening to the Behind the Bastard...               -0.7096
# ...                                                 ...                   ...
# 1939  Our our it is the worst thing On has ever done...               -0.6249
# 1941       I do not think you know what that word means                0.0000
# 1942  Up cum rag? I missed you 😊  Did not you have t...               -0.1630
# 1943                   I missed you too angry fixed man               -0.6705
# 1944  Still did not learn how to read 😞  It does not...                0.7708
#
#      SentimentCategory_VADER
# 0                   Positive
# 1                   Positive
# 3                    Neutral
# 4                    Neutral
# 5                   Negative
# ...                      ...
# 1939                Negative
# 1941                 Neutral
# 1942                Negative
# 1943                Negative
# 1944                Positive
#
# [991 rows x 3 columns]

# %%
df.SentimentScore_VADER.describe()
# Out:
# count    991.000000
# mean       0.057978
# std        0.476314
# min       -0.995000
# 25%       -0.273200
# 50%        0.000000
# 75%        0.439750
# max        0.989800
# Name: SentimentScore_VADER, dtype: float64

# %%
df.SentimentScore_VADER.plot(kind='hist',color='y')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.sort_values(by="SentimentScore_VADER", ascending=False).head(10)
# Out:
#                                                 Comment  \
# 506   I firmly believe there is no endgame. This who...
# 1851  Isn’t it crazy how you can devote substantial ...
# 342   I though the same first, but I don't think he'...
# 489   I don't believe he ever had a plan. He gets id...
# 1331  >Phasing out of lockdown? My man, we have been...
# 504   "Never attribute to malice what can be attribu...
# 684   Sure - didn't look forever but all I found was...
# 682   Tl;Dr: it’s very easy and somewhat common to s...
# 649   I think he is similar to Steve jobs He has a k...
# 1321  Phasing out of lockdown? My man, we have been ...
#
#                                         Cleaned_Comment  \
# 506   firmly believe engage whole debate episode “ d...
# 1851  crazy devote substantial portion life humor co...
# 342   though first think trying save money one fan d...
# 489   believe ever plan get idea head sometimes peop...
# 1331  chasing lockdown man lockdown year point thank...
# 504   never attribute malice attributed incompetence...
# 684   sure look forever found link taken number post...
# 682   easy somewhat common self diagnose sometimes e...
# 649   think similar steve job knack seeing opening c...
# 1321  chasing lockdown man lockdown year point exact...
#
#                                       Sentiment_Comment Language  Length  \
# 506   I firmly believe there is no engage. His whole...       en    1402
# 1851  Is not it crazy how you can devote substantial...       en     254
# 342   I though the same first, but I do not think he...       en     140
# 489   I do not believe he ever had a plan. He gets i...       en     258
# 1331  >Chasing out of lockdown? By man, we have been...       en     209
# 504   "Never attribute to malice what can be attribu...       en     615
# 684   Sure - did not look forever but all I found wa...       en      85
# 682   Ll;Or: it is very easy and somewhat common to ...       en    1179
# 649   I think he is similar to Steve jobs He has a k...       en     528
# 1321  Chasing out of lockdown? By man, we have been ...       en     203
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 506   [firmly, believe, engage, whole, debate, episo...                0.9898
# 1851  [crazy, devote, substantial, portion, life, hu...                0.9796
# 342   [though, first, think, trying, save, money, on...                0.9780
# 489   [believe, ever, plan, get, idea, head, sometim...                0.9509
# 1331  [chasing, lockdown, man, lockdown, year, point...                0.9502
# 504   [never, attribute, malice, attributed, incompe...                0.9495
# 684   [sure, look, forever, found, link, taken, numb...                0.9473
# 682   [easy, somewhat, common, self, diagnose, somet...                0.9427
# 649   [think, similar, steve, job, knack, seeing, op...                0.9390
# 1321  [chasing, lockdown, man, lockdown, year, point...                0.9382
#
#      SentimentCategory_VADER
# 506                 Positive
# 1851                Positive
# 342                 Positive
# 489                 Positive
# 1331                Positive
# 504                 Positive
# 684                 Positive
# 682                 Positive
# 649                 Positive
# 1321                Positive

# %%
df.sort_values(by="SentimentScore_VADER", ascending=True).head(10)
# Out:
#                                                 Comment  \
# 490   I honestly believe this is what happened. Elon...
# 63    A lot of tiny Queens, Kings, and nonbinary roy...
# 1773  I don’t think these people realise that this i...
# 128   >I should take this opportunity\n\nand\n\n>Pro...
# 240   Please report rule breaking posts, such as:\n\...
# 1223  Unfortunately, it's no longer possible to upvo...
# 6     Elon Musk really out here assassinating one of...
# 1798  "I shit myself the other day. I was too busy b...
# 1140  I’d be sad if I cared about Twitter. It’s some...
# 485   It *is* bad because he can't trademark it. Som...
#
#                                         Cleaned_Comment  \
# 490   honestly believe happened wanted pump twitter ...
# 63    lot tiny queen king nonbinary royal lost tiny ...
# 1773  think people realise becoming “ attitude era b...
# 128   take opportunity probably time bid farewell mu...
# 240   please report rule breaking post politics kind...
# 1223  unfortunately longer possible votedownvote com...
# 6     dusk really assassination one ironic internet ...
# 1798  shit day busy mad online something wwe size ye...
# 1140  would sad cared twitter somehow worse edit any...
# 485   bad trademark something pretty goddamn importa...
#
#                                       Sentiment_Comment Language  Length  \
# 490   I honestly believe this is what happened. On w...       en     848
# 63    A lot of tiny Queens, Kings, and nonbinary roy...       en     353
# 1773  I do not think these people realise that this ...       en     325
# 128   >I should take this opportunity  and  >Probabl...       en     306
# 240   Please report rule breaking posts, such as:   ...       en     600
# 1223  Unfortunately, it is no longer possible to vot...       en     735
# 6     On Dusk really out here assassination one of t...       en     330
# 1798  "I shit myself the other day. I was too busy b...       en      78
# 1140  I would be sad if I cared about Twitter. It is...       en      87
# 485   It *is* bad because he cannot trademark it. So...       en     123
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 490   [honestly, believe, happened, wanted, pump, tw...               -0.9950
# 63    [lot, tiny, queen, king, nonbinary, royal, los...               -0.9890
# 1773  [think, people, realise, becoming, “, attitude...               -0.9816
# 128   [take, opportunity, probably, time, bid, farew...               -0.9812
# 240   [please, report, rule, breaking, post, politic...               -0.9739
# 1223  [unfortunately, longer, possible, votedownvote...               -0.9667
# 6     [dusk, really, assassination, one, ironic, int...               -0.9612
# 1798  [shit, day, busy, mad, online, something, wwe,...               -0.9323
# 1140  [would, sad, cared, twitter, somehow, worse, e...               -0.9274
# 485   [bad, trademark, something, pretty, goddamn, i...               -0.9246
#
#      SentimentCategory_VADER
# 490                 Negative
# 63                  Negative
# 1773                Negative
# 128                 Negative
# 240                 Negative
# 1223                Negative
# 6                   Negative
# 1798                Negative
# 1140                Negative
# 485                 Negative

# %% [markdown]
# **12. Conduct a sentiment analysis with TextBlob sentiment classifier**

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import nltk
nltk.download('movie_reviews')

def get_sentiment_textblob(text):
    blob = TextBlob(text, analyzer=NaiveBayesAnalyzer())
    sentiment = blob.sentiment
    if sentiment.p_pos >= 0.6:
        return "Positive"
    elif sentiment.p_neg >= 0.6:
        return "Negative"
    return "Neutral"

df['SentimentCategory_Bayes'] = df['Sentiment_Comment'].apply(get_sentiment_textblob)

df[['Sentiment_Comment', 'SentimentCategory_Bayes']]
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/1207672200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SentimentCategory_Bayes'] = df['Sentiment_Comment'].apply(get_sentiment_textblob)
#                                       Sentiment_Comment  \
# 0     Least twitter is dying so the world will be a ...
# 1        Cheemlon Dusk looks like he is constantly high
# 3     Now we can call every video unloaded on twitte...
# 4                            Cheemlon Sums is so cursed
# 5     I remember listening to the Behind the Bastard...
# ...                                                 ...
# 1939  Our our it is the worst thing On has ever done...
# 1941       I do not think you know what that word means
# 1942  Up cum rag? I missed you 😊  Did not you have t...
# 1943                   I missed you too angry fixed man
# 1944  Still did not learn how to read 😞  It does not...
#
#      SentimentCategory_Bayes
# 0                    Neutral
# 1                   Positive
# 3                   Positive
# 4                    Neutral
# 5                   Negative
# ...                      ...
# 1939                Positive
# 1941                 Neutral
# 1942                 Neutral
# 1943                Positive
# 1944                 Neutral
#
# [991 rows x 2 columns]

# %%
df_SentimentComparison = df[df.SentimentCategory_Bayes != df.SentimentCategory_VADER]
df_SentimentComparison
# Out:
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 3     Now we can call every video uploaded on twitte...
# 6     Elon Musk really out here assassinating one of...
# 7                                    TwiXer has arrived
# 9                              “Hellyeah” —Chemlon Musk
# ...                                                 ...
# 1938  God I miss Leftovers 😩 Cant wait for it to be ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment  \
# 0                least twitter dying world better place
# 3             call every video unloaded twitter xvideos
# 6     dusk really assassination one ironic internet ...
# 7                                         wider arrived
# 9                            “ hellyeah ” —chemlon dusk
# ...                                                 ...
# 1938                        god miss leftover wait back
# 1939  worst thing ever done hur cela stock steadily ...
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                                       Sentiment_Comment Language  Length  \
# 0     Least twitter is dying so the world will be a ...       en      38
# 3     Now we can call every video unloaded on twitte...       en      41
# 6     On Dusk really out here assassination one of t...       en     330
# 7                                     wider has arrived       en      13
# 9                              “Hellyeah” —Chemlon Dusk       en      26
# ...                                                 ...      ...     ...
# 1938  God I miss Leftovers 😩 Cannot wait for it to b...       en      27
# 1939  Our our it is the worst thing On has ever done...       en      52
# 1942  Up cum rag? I missed you 😊  Did not you have t...       en     138
# 1943                   I missed you too angry fixed man       en      22
# 1944  Still did not learn how to read 😞  It does not...       en      81
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 0         [least, twitter, dying, world, better, place]                0.4404
# 3      [call, every, video, unloaded, twitter, xvideos]                0.0000
# 6     [dusk, really, assassination, one, ironic, int...               -0.9612
# 7                                      [wider, arrived]                0.0000
# 9                      [“, hellyeah, ”, —chemlon, dusk]                0.0000
# ...                                                 ...                   ...
# 1938                  [god, miss, leftover, wait, back]                0.2003
# 1939  [worst, thing, ever, done, hur, cela, stock, s...               -0.6249
# 1942  [cum, rag, missed, chance, go, outside, today,...               -0.1630
# 1943                        [missed, angry, fixed, man]               -0.6705
# 1944  [still, learn, read, matter, one, episode, tak...                0.7708
#
#      SentimentCategory_VADER SentimentCategory_Bayes
# 0                   Positive                 Neutral
# 3                    Neutral                Positive
# 6                   Negative                Positive
# 7                    Neutral                Positive
# 9                    Neutral                Positive
# ...                      ...                     ...
# 1938                Positive                Negative
# 1939                Negative                Positive
# 1942                Negative                 Neutral
# 1943                Negative                Positive
# 1944                Positive                 Neutral
#
# [552 rows x 9 columns]

# %%
bayes_counts = df['SentimentCategory_Bayes'].value_counts()
vader_counts = df['SentimentCategory_VADER'].value_counts()

sentiment_categories = sorted(set(bayes_counts.index) | set(vader_counts.index))

fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35

x_bayes = range(len(sentiment_categories))
x_vader = [pos + bar_width for pos in x_bayes]

ax.bar(x_bayes, [bayes_counts.get(category, 0) for category in sentiment_categories], bar_width, label='Bayes')
ax.bar(x_vader, [vader_counts.get(category, 0) for category in sentiment_categories], bar_width, label='VADER')

ax.set_xticks([pos + bar_width / 2 for pos in x_bayes])
ax.set_xticklabels(sentiment_categories)
ax.set_xlabel('Sentiment Category')
ax.set_ylabel('Count')
ax.set_title('Sentiment Analysis Comparison (Bayes vs. VADER)')
ax.legend()

plt.tight_layout()
plt.show()

# %%
df_SentimentComparison.to_csv('df_SentimentComparison.csv', index=False)

# %%
df.to_csv('df_all.csv', index=False)

# %% [markdown]
# **13. Sentiment analysis with machine learning**

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stopwords = stopwords.words('english')

def preprocess(row):
    text = row["Sentiment_Comment"].lower()
    keep = []
    for word in text.split():
        if word in stopwords:
            continue
        if word.startswith("@"):
            continue
        if word.startswith("http"):
            continue
        if word.startswith("#"):
            continue
        if word == "follow":
            continue
        if len(word) <= 1:
            continue
        keep.append(word)
    return ' '.join(keep)

df["cleaned_text"] = df.apply(preprocess, axis=1)
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_30443/2044802583.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cleaned_text"] = df.apply(preprocess, axis=1)
#                                                 Comment  \
# 0     Atleast twitter is dying so the world will be ...
# 1         Cheemlon Musk looks like he's constantly high
# 3     Now we can call every video uploaded on twitte...
# 4                           Cheemlon Mumsk is so cursed
# 5     I remember listening to the Behind the Bastard...
# ...                                                 ...
# 1939  Hur dur it's the worst thing Elon has ever don...
# 1941        I don't think you know what that word means
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...
# 1943                   I missed you too angry pixel man
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...
#
#                                         Cleaned_Comment  \
# 0                least twitter dying world better place
# 1               cheemlon dusk look like constantly high
# 3             call every video unloaded twitter xvideos
# 4                                   cheemlon sum cursed
# 5     remember listening behind bastard series dusk ...
# ...                                                 ...
# 1939  worst thing ever done hur cela stock steadily ...
# 1941                               think know word mean
# 1942  cum rag missed chance go outside today either ...
# 1943                             missed angry fixed man
# 1944  still learn read matter one episode take care ...
#
#                                       Sentiment_Comment Language  Length  \
# 0     Least twitter is dying so the world will be a ...       en      38
# 1        Cheemlon Dusk looks like he is constantly high       en      39
# 3     Now we can call every video unloaded on twitte...       en      41
# 4                            Cheemlon Sums is so cursed       en      19
# 5     I remember listening to the Behind the Bastard...       en     131
# ...                                                 ...      ...     ...
# 1939  Our our it is the worst thing On has ever done...       en      52
# 1941       I do not think you know what that word means       en      20
# 1942  Up cum rag? I missed you 😊  Did not you have t...       en     138
# 1943                   I missed you too angry fixed man       en      22
# 1944  Still did not learn how to read 😞  It does not...       en      81
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 0         [least, twitter, dying, world, better, place]                0.4404
# 1        [cheemlon, dusk, look, like, constantly, high]                0.3612
# 3      [call, every, video, unloaded, twitter, xvideos]                0.0000
# 4                               [cheemlon, sum, cursed]                0.0000
# 5     [remember, listening, behind, bastard, series,...               -0.7096
# ...                                                 ...                   ...
# 1939  [worst, thing, ever, done, hur, cela, stock, s...               -0.6249
# 1941                          [think, know, word, mean]                0.0000
# 1942  [cum, rag, missed, chance, go, outside, today,...               -0.1630
# 1943                        [missed, angry, fixed, man]               -0.6705
# 1944  [still, learn, read, matter, one, episode, tak...                0.7708
#
#      SentimentCategory_VADER SentimentCategory_Bayes  \
# 0                   Positive                 Neutral
# 1                   Positive                Positive
# 3                    Neutral                Positive
# 4                    Neutral                 Neutral
# 5                   Negative                Negative
# ...                      ...                     ...
# 1939                Negative                Positive
# 1941                 Neutral                 Neutral
# 1942                Negative                 Neutral
# 1943                Negative                Positive
# 1944                Positive                 Neutral
#
#                                            cleaned_text
# 0                least twitter dying world better place
# 1              cheemlon dusk looks like constantly high
# 3             call every video unloaded twitter xvideos
# 4                                  cheemlon sums cursed
# 5     remember listening behind bastards series dusk...
# ...                                                 ...
# 1939  worst thing ever done hur *cela stocks steadil...
# 1941                              think know word means
# 1942  cum rag? missed chance go outside today either...
# 1943                             missed angry fixed man
# 1944  still learn read matter, here? one episodes? t...
#
# [991 rows x 10 columns]

# %%
from textblob.classifiers import NaiveBayesClassifier

train = shuffled[['cleaned_text', 'SentimentCategory_VADER']][0:792]
test = shuffled[['cleaned_text', 'SentimentCategory_VADER']][792:]

# Sample labeled data for sentiment analysis
training_data = [(row['cleaned_text'], row['SentimentCategory_VADER']) for _, row in train.iterrows()]

# Create a NaiveBayesClassifier and train it with the labeled data
classifier = NaiveBayesClassifier(training_data)

# Evaluate the classifier (optional)
testing_data = [(row['cleaned_text'], row['SentimentCategory_VADER']) for _, row in test.iterrows()]

accuracy = classifier.accuracy(testing_data)
print("Accuracy:", accuracy)

# Sentiment analysis on new text
new_text = "The book is fantastic!"
sentiment = classifier.classify(new_text)
print("Sentiment:", sentiment)  # Output: "positive"
# Out:
# Accuracy: 0.4824120603015075
# Sentiment: Neutral

# %%
from textblob.classifiers import NaiveBayesClassifier

train = shuffled[['cleaned_text', 'SentimentCategory_Bayes']][0:792]
test = shuffled[['cleaned_text', 'SentimentCategory_Bayes']][792:]

# Sample labeled data for sentiment analysis
training_data = [(row['cleaned_text'], row['SentimentCategory_Bayes']) for _, row in train.iterrows()]

# Create a NaiveBayesClassifier and train it with the labeled data
classifier = NaiveBayesClassifier(training_data)

# Evaluate the classifier (optional)
testing_data = [(row['cleaned_text'], row['SentimentCategory_Bayes']) for _, row in test.iterrows()]

accuracy = classifier.accuracy(testing_data)
print("Accuracy:", accuracy)

# Sentiment analysis on new text
new_text = "The book is fantastic!"
sentiment = classifier.classify(new_text)
print("Sentiment:", sentiment)  # Output: "positive"
# Out:
# Accuracy: 0.45226130653266333
# Sentiment: Neutral
