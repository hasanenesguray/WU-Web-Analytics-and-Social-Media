# %% [markdown]
# **1. Upload the dataset**

# %%
import pandas as pd

# Specify the file path where the CSV file is located
csv_file_path = "PreprocessedComments_MargotRobbie.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)
df
# Out:
#                                            Comment_Body                Author  \
# 0     I had to mute the video to enjoy it. Like, shu...         Ok_Shirt_3481
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!        mr-PicklePants
# 2     I was so grateful to learn sign language as pa...           Queenside22
# 3     “Margot! Margot!” …. she’s having a conversati...            hemansteve
# 4     She's clearly using an Australian accent when ...  RepresentativeNice22
# ...                                                 ...                   ...
# 1631       People need to stop because there is NO way.      nghtmareb4coffee
# 1632  I’ve gotten this comment and I look nothing li...               FSU2016
# 1633  I don't know what's hotter, her perfect tongue...        GoonedAndEdged
# 1634                           She loves showing it off            FelixTanim
# 1635  Cant decide if i should bust it on her face or...               jbe0025
#
#      Upvotes Awards                 Date  \
# 0       7392      0  2023-07-25 03:42:18
# 1       4859      1  2023-07-25 03:17:56
# 2       3782      0  2023-07-25 04:03:15
# 3      13596      3  2023-07-25 03:20:43
# 4       4123      0  2023-07-25 03:01:34
# ...      ...    ...                  ...
# 1631       4      0  2023-07-24 23:59:03
# 1632       1      0  2023-07-25 01:20:09
# 1633       9      0  2023-07-26 15:08:41
# 1634       5      0  2023-07-26 15:40:24
# 1635       1      0  2023-07-26 22:03:01
#
#                                           Fixed_Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                     Substituted_Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                        Replaced_Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                      Without_LineBreaks  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                    Corrected_Comment(SentimentAnalysis)  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Forgot, maggot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Forgot! Forgot!” …. she is having a conversat...
# 4     The is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is of way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is other, her perfect tongu...
# 1634                           The loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                           Lower_Comment  \
# 0     i had to mute the video to enjoy it. like, shu...
# 1             forgot, maggot, margot, margot, margot!!!
# 2     i was so grateful to learn sign language as pa...
# 3     “forgot! forgot!” …. she is having a conversat...
# 4     the is clearly using an australian accent when...
# ...                                                 ...
# 1631       people need to stop because there is of way.
# 1632  i have gotten this comment and i look nothing ...
# 1633  i do not know what is other, her perfect tongu...
# 1634                           the loves showing it off
# 1635  cannot decide if i should bust it on her face ...
#
#                                       Tokenized_Comment  \
# 0     i had to mute the video to enjoy it . like , s...
# 1      forgot , maggot , margot , margot , margot ! ! !
# 2     i was so grateful to learn sign language as pa...
# 3     “ forgot ! forgot ! ” … . she is having a conv...
# 4     the is clearly using an australian accent when...
# ...                                                 ...
# 1631      people need to stop because there is of way .
# 1632  i have gotten this comment and i look nothing ...
# 1633  i do not know what is other , her perfect tong...
# 1634                           the loves showing it off
# 1635  can not decide if i should bust it on her face...
#
#                                       Without_Stopwords  \
# 0     mute video enjoy . like , shut luck brow . bus...
# 1      forgot , maggot , margot , margot , margot ! ! !
# 2     grateful learn sign language part curriculum p...
# 3       “ forgot ! forgot ! ” … . conversation dickhead
# 4        clearly using australian accent signs ! dare ?
# ...                                                 ...
# 1631                             people need stop way .
# 1632            gotten comment look nothing like either
# 1633  know , perfect tongue getting slipped forgot like
# 1634                                      loves showing
# 1635                        decide bust face stomach💦🥜🤔
#
#                                        Prepared_Comment  \
# 0     mute video enjoy  like  shut luck brow  busy t...
# 1             forgot  maggot  margot  margot  margot
# 2     grateful learn sign language part curriculum p...
# 3            forgot  forgot  ” …  conversation dickhead
# 4          clearly using australian accent signs  dare
# ...                                                 ...
# 1631                              people need stop way
# 1632            gotten comment look nothing like either
# 1633   know  perfect tongue getting slipped forgot like
# 1634                                      loves showing
# 1635                           decide bust face stomach
#
#                                      Lemmatized_Comment
# 0     mute video enjoy like shut luck brow busy talk...
# 1                    forgot maggot margot margot margot
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# ...                                                 ...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
# 1635                           decide bust face stomach
#
# [1636 rows x 15 columns]

# %% [markdown]
# **2. Drop duplicates**

# %%
df = df.drop_duplicates(subset=['Comment_Body', 'Author'])
df
# Out:
#                                            Comment_Body                Author  \
# 0     I had to mute the video to enjoy it. Like, shu...         Ok_Shirt_3481
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!        mr-PicklePants
# 2     I was so grateful to learn sign language as pa...           Queenside22
# 3     “Margot! Margot!” …. she’s having a conversati...            hemansteve
# 4     She's clearly using an Australian accent when ...  RepresentativeNice22
# ...                                                 ...                   ...
# 1631       People need to stop because there is NO way.      nghtmareb4coffee
# 1632  I’ve gotten this comment and I look nothing li...               FSU2016
# 1633  I don't know what's hotter, her perfect tongue...        GoonedAndEdged
# 1634                           She loves showing it off            FelixTanim
# 1635  Cant decide if i should bust it on her face or...               jbe0025
#
#      Upvotes Awards                 Date  \
# 0       7392      0  2023-07-25 03:42:18
# 1       4859      1  2023-07-25 03:17:56
# 2       3782      0  2023-07-25 04:03:15
# 3      13596      3  2023-07-25 03:20:43
# 4       4123      0  2023-07-25 03:01:34
# ...      ...    ...                  ...
# 1631       4      0  2023-07-24 23:59:03
# 1632       1      0  2023-07-25 01:20:09
# 1633       9      0  2023-07-26 15:08:41
# 1634       5      0  2023-07-26 15:40:24
# 1635       1      0  2023-07-26 22:03:01
#
#                                           Fixed_Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                     Substituted_Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                        Replaced_Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                      Without_LineBreaks  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she is having a conversat...
# 4     She is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is hotter, her perfect tong...
# 1634                           She loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                    Corrected_Comment(SentimentAnalysis)  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Forgot, maggot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Forgot! Forgot!” …. she is having a conversat...
# 4     The is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is of way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is other, her perfect tongu...
# 1634                           The loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
#                                           Lower_Comment  \
# 0     i had to mute the video to enjoy it. like, shu...
# 1             forgot, maggot, margot, margot, margot!!!
# 2     i was so grateful to learn sign language as pa...
# 3     “forgot! forgot!” …. she is having a conversat...
# 4     the is clearly using an australian accent when...
# ...                                                 ...
# 1631       people need to stop because there is of way.
# 1632  i have gotten this comment and i look nothing ...
# 1633  i do not know what is other, her perfect tongu...
# 1634                           the loves showing it off
# 1635  cannot decide if i should bust it on her face ...
#
#                                       Tokenized_Comment  \
# 0     i had to mute the video to enjoy it . like , s...
# 1      forgot , maggot , margot , margot , margot ! ! !
# 2     i was so grateful to learn sign language as pa...
# 3     “ forgot ! forgot ! ” … . she is having a conv...
# 4     the is clearly using an australian accent when...
# ...                                                 ...
# 1631      people need to stop because there is of way .
# 1632  i have gotten this comment and i look nothing ...
# 1633  i do not know what is other , her perfect tong...
# 1634                           the loves showing it off
# 1635  can not decide if i should bust it on her face...
#
#                                       Without_Stopwords  \
# 0     mute video enjoy . like , shut luck brow . bus...
# 1      forgot , maggot , margot , margot , margot ! ! !
# 2     grateful learn sign language part curriculum p...
# 3       “ forgot ! forgot ! ” … . conversation dickhead
# 4        clearly using australian accent signs ! dare ?
# ...                                                 ...
# 1631                             people need stop way .
# 1632            gotten comment look nothing like either
# 1633  know , perfect tongue getting slipped forgot like
# 1634                                      loves showing
# 1635                        decide bust face stomach💦🥜🤔
#
#                                        Prepared_Comment  \
# 0     mute video enjoy  like  shut luck brow  busy t...
# 1             forgot  maggot  margot  margot  margot
# 2     grateful learn sign language part curriculum p...
# 3            forgot  forgot  ” …  conversation dickhead
# 4          clearly using australian accent signs  dare
# ...                                                 ...
# 1631                              people need stop way
# 1632            gotten comment look nothing like either
# 1633   know  perfect tongue getting slipped forgot like
# 1634                                      loves showing
# 1635                           decide bust face stomach
#
#                                      Lemmatized_Comment
# 0     mute video enjoy like shut luck brow busy talk...
# 1                    forgot maggot margot margot margot
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# ...                                                 ...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
# 1635                           decide bust face stomach
#
# [1618 rows x 15 columns]

# %% [markdown]
# **3. Remove the unnecessary columns**

# %%
df = df[['Comment_Body', 'Lemmatized_Comment', 'Corrected_Comment(SentimentAnalysis)']]
df
# Out:
#                                            Comment_Body  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
# 1635  Cant decide if i should bust it on her face or...
#
#                                      Lemmatized_Comment  \
# 0     mute video enjoy like shut luck brow busy talk...
# 1                    forgot maggot margot margot margot
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# ...                                                 ...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
# 1635                           decide bust face stomach
#
#                    Corrected_Comment(SentimentAnalysis)
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Forgot, maggot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Forgot! Forgot!” …. she is having a conversat...
# 4     The is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is of way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is other, her perfect tongu...
# 1634                           The loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
# [1618 rows x 3 columns]

# %% [markdown]
# **4. Rename the columns**

# %%
df.rename(columns={'Comment_Body': 'Comment', 'Lemmatized_Comment': 'Cleaned_Comment',
                   'Corrected_Comment(SentimentAnalysis)': 'Sentiment_Comment'}, inplace=True)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/3350974763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Comment_Body': 'Comment', 'Lemmatized_Comment': 'Cleaned_Comment',
#                                                 Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
# 1635  Cant decide if i should bust it on her face or...
#
#                                         Cleaned_Comment  \
# 0     mute video enjoy like shut luck brow busy talk...
# 1                    forgot maggot margot margot margot
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# ...                                                 ...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
# 1635                           decide bust face stomach
#
#                                       Sentiment_Comment
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Forgot, maggot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Forgot! Forgot!” …. she is having a conversat...
# 4     The is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is of way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is other, her perfect tongu...
# 1634                           The loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
# [1618 rows x 3 columns]

# %% [markdown]
# **5. Check the na rows**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1618 entries, 0 to 1635
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Comment            1618 non-null   object
#  1   Cleaned_Comment    1586 non-null   object
#  2   Sentiment_Comment  1614 non-null   object
# dtypes: object(3)
# memory usage: 50.6+ KB

# %%
df[df['Cleaned_Comment'].isna()]
# Out:
#                                                 Comment Cleaned_Comment  \
# 50                                                    💗             NaN
# 493                                                 Mis             NaN
# 652                                                ~~~~             NaN
# 862   We will definitely see Robbie as Harley again ...             NaN
# 863   But I am curious to see how they will balance ...             NaN
# 864   But I am curious to see how they will balance ...             NaN
# 865   but i am curious to see how they will balance ...             NaN
# 935                                        Who doesn't?             NaN
# 995                            Isn’t it the other Ryan?             NaN
# 1082                                    Idk who that is             NaN
# 1088                                               who?             NaN
# 1093                                               Who?             NaN
# 1095                                 Who tf is that lol             NaN
# 1096                                               Who?             NaN
# 1097                                         Who's she?             NaN
# 1102                                               Who?             NaN
# 1104                                               Who?             NaN
# 1105                                               Who?             NaN
# 1106                                               Who?             NaN
# 1116                                               Her?             NaN
# 1137                                                 No             NaN
# 1143                                                No.             NaN
# 1186                                      Didn't we all             NaN
# 1236                                       All of them.             NaN
# 1377                                         ❤️❤️❤️❤️❤️             NaN
# 1491                                               Wow!             NaN
# 1496                                               Katy             NaN
# 1503                                               Katy             NaN
# 1517                                                Iyy             NaN
# 1563                                                 NO             NaN
# 1597                                             Wow!!!             NaN
# 1601                                                Why             NaN
#
#              Sentiment_Comment
# 50                           💗
# 493                        His
# 652                       ~~~~
# 862                        NaN
# 863                        NaN
# 864                        NaN
# 865                        NaN
# 935              Who does not?
# 995    Is not it the other An?
# 1082  I To Not Now who that is
# 1088                      who?
# 1093                      Who?
# 1095         Who of is that ll
# 1096                      Who?
# 1097               Who is she?
# 1102                      Who?
# 1104                      Who?
# 1105                      Who?
# 1106                      Who?
# 1116                      Her?
# 1137                        To
# 1143                       To.
# 1186            Did not we all
# 1236              All of them.
# 1377                ❤️❤️❤️❤️❤️
# 1491                      Now!
# 1496                        At
# 1503                        At
# 1517                        By
# 1563                        of
# 1597                    Now!!!
# 1601                       Why

# %%
df.dropna(inplace=True)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/955798070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#                                                 Comment  \
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Margot, margot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# ...                                                 ...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
# 1635  Cant decide if i should bust it on her face or...
#
#                                         Cleaned_Comment  \
# 0     mute video enjoy like shut luck brow busy talk...
# 1                    forgot maggot margot margot margot
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# ...                                                 ...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
# 1635                           decide bust face stomach
#
#                                       Sentiment_Comment
# 0     I had to mute the video to enjoy it. Like, shu...
# 1             Forgot, maggot, MaRgOt, mArGoT, MARGOT!!!
# 2     I was so grateful to learn sign language as pa...
# 3     “Forgot! Forgot!” …. she is having a conversat...
# 4     The is clearly using an Australian accent when...
# ...                                                 ...
# 1631       People need to stop because there is of way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is other, her perfect tongu...
# 1634                           The loves showing it off
# 1635  Cannot decide if i should bust it on her face ...
#
# [1586 rows x 3 columns]

# %% [markdown]
# **6. Detect the language**

# %%
from langdetect import detect

def detect_language(comment):
    try:
        return detect(comment)
    except:
        return None

df['Language'] = df['Cleaned_Comment'].apply(detect_language)
df['Language'].value_counts()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/4139810979.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language'] = df['Cleaned_Comment'].apply(detect_language)
# en    1128
# af      63
# no      40
# da      37
# fr      34
# it      32
# ro      32
# nl      29
# tl      26
# cy      21
# so      18
# tr      14
# et      14
# sl      13
# es      11
# sv       7
# sk       7
# hu       6
# pl       6
# fi       6
# pt       5
# sw       5
# ca       5
# de       4
# lv       4
# sq       4
# id       4
# hr       4
# vi       2
# cs       2
# lt       2
# Name: Language, dtype: int64

# %%
import matplotlib.pyplot as plt

average_lengths = df.groupby('Language')['Cleaned_Comment'].apply(lambda x: x.str.len().mean()).reset_index()
average_lengths.rename(columns={'Cleaned_Comment': 'Average_Length'}, inplace=True)

# Create a bigger bar chart
plt.figure(figsize=(10, 6))

# Plot the bar chart
bar_plot = plt.bar(average_lengths['Language'], average_lengths['Average_Length'])

# Add text annotations with the average lengths on the bars
for i, value in enumerate(average_lengths['Average_Length']):
    plt.annotate(f'{value:.2f}', xy=(i, value), ha='center', va='bottom')

plt.xlabel('Language')
plt.ylabel('Average Length')
plt.title('Average Comment Length by Language')

plt.show()

# %%
import numpy as np

# Assuming 'df' is your DataFrame and 'Language' is the column containing language codes.

# Define the mapping of languages to replace
valid_languages = ["en", "af", "no", "fr", "da", "ro", "it", "nl", "tl", "cy"]
replacement_language = "others"

# Use numpy.where() to apply the replacement condition
df['Language'] = np.where(df['Language'].isin(valid_languages), df['Language'], replacement_language)
df['Language'].value_counts()
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/1135340442.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Language'] = np.where(df['Language'].isin(valid_languages), df['Language'], replacement_language)
# en        1128
# others     144
# af          63
# no          40
# da          37
# fr          34
# it          32
# ro          32
# nl          29
# tl          26
# cy          21
# Name: Language, dtype: int64

# %%
# Count the occurrences of each language
value_counts = df['Language'].value_counts()

# Sort the values in descending order
sorted_counts = value_counts.sort_values(ascending=True)

# Get the labels (unique values) and their respective counts
labels = sorted_counts.index.tolist()
counts = sorted_counts.tolist()

# Calculate percentages
total_count = sum(counts)
percentages = [(count / total_count) * 100 for count in counts]

# Create the bar chart with a bigger frame
plt.figure(figsize=(25, 8))  # Adjust the figure size as needed
bars = plt.barh(labels, counts, color=plt.cm.Paired.colors)

# Add count and percentage annotations on the bars
for bar, count, percentage in zip(bars, counts, percentages):
    plt.annotate(f'{count} ({percentage:.1f}%)', xy=(count, bar.get_y() + bar.get_height() / 2),
                 xytext=(5, 0), textcoords='offset points', va='center')

plt.xlabel('Count')
plt.ylabel('Language')
plt.title('Language Breakdown')
plt.tight_layout()  # To avoid label cutoffs
plt.show()

# %%
df = df[df['Language'] == "en"]
df
# Out:
#                                                 Comment  \
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# 5     New level of respect for her unlocked. Clearly...
# 7     How? How in the world does she become this dam...
# ...                                                 ...
# 1630  i wish people would stop saying this, as if he...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
#
#                                         Cleaned_Comment  \
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# 5     new level respect unlocked clearly treating ha...
# 7            world become damn attractive perfect woman
# ...                                                 ...
# 1630  wish people would stop saying ego big enough a...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
#
#                                       Sentiment_Comment Language
# 2     I was so grateful to learn sign language as pa...       en
# 3     “Forgot! Forgot!” …. she is having a conversat...       en
# 4     The is clearly using an Australian accent when...       en
# 5     New level of respect for her unlocked. Clearly...       en
# 7     Now? Now in the world does she become this dam...       en
# ...                                                 ...      ...
# 1630  i wish people would stop saying this, as if he...       en
# 1631       People need to stop because there is of way.       en
# 1632  I have gotten this comment and I look nothing ...       en
# 1633  I do not know what is other, her perfect tongu...       en
# 1634                           The loves showing it off       en
#
# [1128 rows x 4 columns]

# %% [markdown]
# **7. Calculate the length**

# %%
df['Length'] = df['Cleaned_Comment'].apply(len)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/4127819789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Length'] = df['Cleaned_Comment'].apply(len)
#                                                 Comment  \
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# 5     New level of respect for her unlocked. Clearly...
# 7     How? How in the world does she become this dam...
# ...                                                 ...
# 1630  i wish people would stop saying this, as if he...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
#
#                                         Cleaned_Comment  \
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# 5     new level respect unlocked clearly treating ha...
# 7            world become damn attractive perfect woman
# ...                                                 ...
# 1630  wish people would stop saying ego big enough a...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
#
#                                       Sentiment_Comment Language  Length
# 2     I was so grateful to learn sign language as pa...       en     168
# 3     “Forgot! Forgot!” …. she is having a conversat...       en      39
# 4     The is clearly using an Australian accent when...       en      41
# 5     New level of respect for her unlocked. Clearly...       en     129
# 7     Now? Now in the world does she become this dam...       en      42
# ...                                                 ...      ...     ...
# 1630  i wish people would stop saying this, as if he...       en      52
# 1631       People need to stop because there is of way.       en      20
# 1632  I have gotten this comment and I look nothing ...       en      39
# 1633  I do not know what is other, her perfect tongu...       en      47
# 1634                           The loves showing it off       en      12
#
# [1128 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1128 entries, 2 to 1634
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Comment            1128 non-null   object
#  1   Cleaned_Comment    1128 non-null   object
#  2   Sentiment_Comment  1128 non-null   object
#  3   Language           1128 non-null   object
#  4   Length             1128 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 52.9+ KB

# %%
df[df.Length<10]
# Out:
#                                   Comment Cleaned_Comment  \
# 64                           Wholesome af       wholesome
# 255                        You know why 👀            know
# 444             He'll naw she's overrated        operated
# 658                         she's kenough          enough
# 758                          Mid, my ass.              as
# 760   Well, I must be the Tin Man then! 😂       well must
# 842                             I hope so            hope
# 846             cant read my cant read my       read read
# 858                            I hope not            hope
# 1004                i clicked on 'more' 😭         clicked
# 1094             I don't know who that is            know
# 1200               What is this title lol           title
# 1213                               Team 1       team size
# 1255                            finally!!         finally
# 1350                            Sam Smith           smith
# 1355                           Alix Earle       six earle
# 1439                     I love her feet!       love foot
#
#                       Sentiment_Comment Language  Length
# 64                         Wholesome of       en       9
# 255                      You know why 👀       en       4
# 444         He will now she is operated       en       8
# 658                       she is enough       en       6
# 758                        Did, my ass.       en       2
# 760   Well, I must be the In An then! 😂       en       9
# 842                           I hope so       en       4
# 846       cannot read my cannot read my       en       9
# 858                          I hope not       en       4
# 1004              i clicked on 'more' 😭       en       7
# 1094          I do not know who that is       en       4
# 1200              That is this title ll       en       5
# 1213                        Team [SIZE]       en       9
# 1255                          finally!!       en       7
# 1350                           Am Smith       en       5
# 1355                          Six Earle       en       9
# 1439                   I love her feet!       en       9

# %%
df.Length.describe()
# Out:
# count    1128.000000
# mean       87.809397
# std        97.012563
# min         2.000000
# 25%        33.000000
# 50%        56.000000
# 75%       105.000000
# max       951.000000
# Name: Length, dtype: float64

# %%
df.Length.mode()
# Out:
# 0    39
# Name: Length, dtype: int64

# %% [markdown]
# **8. Term Frequency**

# %%
from collections import Counter

all_comments = ' '.join(df['Cleaned_Comment'])

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

words = word_tokenize(all_comments)

word_counter = Counter(words)

most_common_words = word_counter.most_common(20)

print("Most common 20 words and their frequencies:")
for word, frequency in most_common_words:
    print(f"{word}: {frequency}")
# Out:
# Most common 20 words and their frequencies:
# forgot: 228
# would: 221
# like: 217
# size: 194
# think: 185
# movie: 170
# marie: 158
# people: 137
# hobby: 134
# good: 106
# one: 102
# great: 99
# woman: 98
# look: 98
# make: 97
# see: 95
# get: 94
# know: 83
# really: 82
# role: 82
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **9. Word Clouds**

# %%
from wordcloud import WordCloud

all_comments = ' '.join(df['Cleaned_Comment'])

words = word_tokenize(all_comments)
word_counter = Counter(words)
most_common_words = word_counter.most_common(200)

word_freq_dict = dict(most_common_words)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud - Most Common 200 Words')
plt.show()

# %% [markdown]
# **10. Extracting noun phrases with TextBlob**

# %%
from textblob import TextBlob
nltk.download('brown')

all_comments = ' '.join(df['Cleaned_Comment'])

# Create a TextBlob object
blob = TextBlob(all_comments)

# Extract noun phrases
noun_phrases = blob.noun_phrases

# Count the occurrences of each noun phrase using Counter
noun_phrase_counter = Counter(noun_phrases)

# Get the 10 most common noun phrases
most_common_noun_phrases = noun_phrase_counter.most_common(10)

# Print the results
print("10 most common noun phrases:")
for noun_phrase, frequency in most_common_noun_phrases:
    print(f"{noun_phrase}: {frequency}")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 10 most common noun phrases:
# forgot hobby: 18
# great actress: 9
# complete missile: 8
# due storm: 8
# barley ruin: 6
# box office: 5
# movie star: 5
# promising young woman: 4
# forgot hobby mid: 4
# box office star: 4

# %% [markdown]
# **11. Performing the LDA Topic Modelling**

# %%
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from nltk.tokenize import word_tokenize

nltk.download('punkt')

def tokenize_text(text):
    return word_tokenize(text)

df['Tokenized_Comment'] = df['Cleaned_Comment'].apply(tokenize_text)

# Create a dictionary from the tokenized words
dictionary = Dictionary(df['Tokenized_Comment'])

# Create a Bag-of-Words (BOW) representation for each document
bow_corpus = [dictionary.doc2bow(doc) for doc in df['Tokenized_Comment']]

# Train the LDA model
num_topics = 5  # You can set the number of topics as per your requirement
lda_model = LdaModel(corpus=bow_corpus, id2word=dictionary, num_topics=num_topics, passes=10)

# Print the topics and their top words
print("LDA Topics:")
for idx, topic in lda_model.print_topics():
    print(f"Topic {idx}: {topic}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/1651847919.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tokenized_Comment'] = df['Cleaned_Comment'].apply(tokenize_text)
# LDA Topics:
# Topic 0: 0.029*"forgot" + 0.010*"hobby" + 0.008*"think" + 0.007*"way" + 0.007*"like" + 0.007*"men" + 0.006*"look" + 0.006*"people" + 0.006*"movie" + 0.005*"going"
# Topic 1: 0.029*"would" + 0.014*"like" + 0.012*"movie" + 0.011*"people" + 0.011*"due" + 0.010*"actress" + 0.009*"size" + 0.009*"storm" + 0.009*"role" + 0.007*"forgot"
# Topic 2: 0.014*"like" + 0.013*"would" + 0.012*"great" + 0.012*"movie" + 0.012*"marie" + 0.011*"think" + 0.010*"know" + 0.009*"look" + 0.008*"could" + 0.008*"people"
# Topic 3: 0.023*"size" + 0.018*"marie" + 0.013*"woman" + 0.012*"forgot" + 0.012*"hobby" + 0.012*"like" + 0.012*"think" + 0.007*"could" + 0.007*"make" + 0.007*"movie"
# Topic 4: 0.013*"sign" + 0.011*"language" + 0.011*"think" + 0.011*"forgot" + 0.011*"size" + 0.010*"like" + 0.009*"one" + 0.008*"really" + 0.007*"good" + 0.007*"movie"

# %% [markdown]
# **12. Conduct a sentiment analysis with VADER model**

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()

# Function to get the sentiment score using VADER
def get_sentiment_score(text):
    return analyzer.polarity_scores(text)['compound']

# Apply the function to the "Sentiment_Comment" column
df['SentimentScore_VADER'] = df['Sentiment_Comment'].apply(get_sentiment_score)

# Categorize the sentiment based on the sentiment score
df['SentimentCategory_VADER'] = df['SentimentScore_VADER'].apply(lambda score: 'Positive' if score >= 0.05 else ('Negative' if score <= -0.05 else 'Neutral'))

# Print the DataFrame with sentiment scores and categories
df[['Sentiment_Comment', 'SentimentScore_VADER', 'SentimentCategory_VADER']]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/772916522.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SentimentScore_VADER'] = df['Sentiment_Comment'].apply(get_sentiment_score)
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/772916522.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SentimentCategory_VADER'] = df['SentimentScore_VADER'].apply(lambda score: 'Positive' if score >= 0.05 else ('Negative' if score <= -0.05 else 'Neutral'))
#                                       Sentiment_Comment  SentimentScore_VADER  \
# 2     I was so grateful to learn sign language as pa...                0.9210
# 3     “Forgot! Forgot!” …. she is having a conversat...               -0.6892
# 4     The is clearly using an Australian accent when...                0.4574
# 5     New level of respect for her unlocked. Clearly...                0.8748
# 7     Now? Now in the world does she become this dam...                0.5907
# ...                                                 ...                   ...
# 1630  i wish people would stop saying this, as if he...                0.1280
# 1631       People need to stop because there is of way.               -0.2960
# 1632  I have gotten this comment and I look nothing ...               -0.2755
# 1633  I do not know what is other, her perfect tongu...                0.7351
# 1634                           The loves showing it off                0.5719
#
#      SentimentCategory_VADER
# 2                   Positive
# 3                   Negative
# 4                   Positive
# 5                   Positive
# 7                   Positive
# ...                      ...
# 1630                Positive
# 1631                Negative
# 1632                Negative
# 1633                Positive
# 1634                Positive
#
# [1128 rows x 3 columns]

# %%
df.SentimentScore_VADER.describe()
# Out:
# count    1128.000000
# mean        0.257846
# std         0.485069
# min        -0.987400
# 25%         0.000000
# 50%         0.318200
# 75%         0.658850
# max         0.993700
# Name: SentimentScore_VADER, dtype: float64

# %%
df.sort_values(by="SentimentScore_VADER", ascending=False).head(10)
# Out:
#                                                 Comment  \
# 798   I would agree but I really think Barbie’s chan...
# 1142  Nope, at least in an acting capacity.\n\nIt's ...
# 1080  She's definitely attractive, arguably one of t...
# 1203  This guy is way beyond idiotic. Hollywood has ...
# 954   I’ve been watching a lot of Margot Robbie Barb...
# 1120  She just isn't that attractive how Redditors s...
# 1162  Nominated surely? She has a great performance ...
# 876   I always thought she was good but this was the...
# 1126  I haven't seen the film, but personally I am n...
# 910   Usually she annoys me to death in the over the...
#
#                                         Cleaned_Comment  \
# 798   would agree really think marie ’ chance way ov...
# 1142  hope least acting capacity weird forgot tom ma...
# 1080  definitely attractive arguably one beautiful s...
# 1203  guy way beyond idiotic hollywood become place ...
# 954   watching lot forgot hobby marie interview seem...
# 1120  attractive editor say also forget size year ol...
# 1162  nominated surely great performance likely eith...
# 876   always thought good performance convinced migh...
# 1126  seen film personally attracted personal prefer...
# 910   usually annoy death top covertly comedy stuff ...
#
#                                       Sentiment_Comment Language  Length  \
# 798   I would agree but I really think Marie’s chanc...       en     848
# 1142  Hope, at least in an acting capacity.  It is w...       en     364
# 1080  The is definitely attractive, arguably one of ...       en     314
# 1203  His guy is way beyond idiotic. Hollywood has b...       en     504
# 954   I have been watching a lot of Forgot Hobbies M...       en     245
# 1120  The just is not that attractive how Editors sa...       en     358
# 1162  Nominated surely? The has a great performance ...       en     260
# 876   I always thought she was good but this was the...       en     230
# 1126  I have not seen the film, but personally I am ...       en     209
# 910   Usually she annoy me to death in the over the ...       en     247
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 798   [would, agree, really, think, marie, ’, chance...                0.9937
# 1142  [hope, least, acting, capacity, weird, forgot,...                0.9881
# 1080  [definitely, attractive, arguably, one, beauti...                0.9866
# 1203  [guy, way, beyond, idiotic, hollywood, become,...                0.9863
# 954   [watching, lot, forgot, hobby, marie, intervie...                0.9844
# 1120  [attractive, editor, say, also, forget, size, ...                0.9836
# 1162  [nominated, surely, great, performance, likely...                0.9825
# 876   [always, thought, good, performance, convinced...                0.9791
# 1126  [seen, film, personally, attracted, personal, ...                0.9767
# 910   [usually, annoy, death, top, covertly, comedy,...                0.9741
#
#      SentimentCategory_VADER
# 798                 Positive
# 1142                Positive
# 1080                Positive
# 1203                Positive
# 954                 Positive
# 1120                Positive
# 1162                Positive
# 876                 Positive
# 1126                Positive
# 910                 Positive

# %%
df.sort_values(by="SentimentScore_VADER", ascending=True).head(10)
# Out:
#                                                 Comment  \
# 233   Misogyny (and racism, homophobia, etc) really ...
# 1129  Innocuous answer to a stupid interview questio...
# 1206  I'm not upset about it. I'm sorry. It seems li...
# 458   I say it would've been fine. She's a good actr...
# 231   Men hate movies that they are not the centre o...
# 634   hasn’t she been rich for a while, where’d all ...
# 230   >So, like, why are dudes so mad about Margot R...
# 877   She gets fewer showy lines than Ryan (although...
# 229   I believe the hate comes from your average mil...
# 1548  How is this even a debate?  \n\nGunn was sayin...
#
#                                         Cleaned_Comment  \
# 233   misogyny racism photophobia etc really make se...
# 1129  innocuous answer stupid interview question pic...
# 1206  upset sorry seems like properly protected trut...
# 458   say would fine good actress killed barley ruin...
# 231   men hate move centre attention made gazegratif...
# 634   rich suicide squad money go lady also hell wou...
# 230   like duke mad forgot hobby anyway intellectual...
# 877   get fewer showy line although still get them— ...
# 229   believe hate come average military standardiss...
# 1548  even debate turn saying even month ago iowa da...
#
#                                       Sentiment_Comment Language  Length  \
# 233   Misogyny (and racism, photophobia, etc) really...       en     542
# 1129  Innocuous answer to a stupid interview questio...       en     218
# 1206  I am not upset about it. I am sorry. It seems ...       en     402
# 458   I say it would have been fine. The is a good a...       en     223
# 231   Men hate moves that they are not the centre of...       en     141
# 634   has not she been rich for a while, where did a...       en      70
# 230   >To, like, why are dukes so mad about Forgot H...       en     239
# 877   The gets fewer showy lines than An (although s...       en     202
# 229   I believe the hate comes from your average mil...       en     595
# 1548  Now is this even a debate?    Turn was saying ...       en     177
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 233   [misogyny, racism, photophobia, etc, really, m...               -0.9874
# 1129  [innocuous, answer, stupid, interview, questio...               -0.9684
# 1206  [upset, sorry, seems, like, properly, protecte...               -0.9578
# 458   [say, would, fine, good, actress, killed, barl...               -0.9203
# 231   [men, hate, move, centre, attention, made, gaz...               -0.8979
# 634   [rich, suicide, squad, money, go, lady, also, ...               -0.8945
# 230   [like, duke, mad, forgot, hobby, anyway, intel...               -0.8897
# 877   [get, fewer, showy, line, although, still, get...               -0.8896
# 229   [believe, hate, come, average, military, stand...               -0.8865
# 1548  [even, debate, turn, saying, even, month, ago,...               -0.8813
#
#      SentimentCategory_VADER
# 233                 Negative
# 1129                Negative
# 1206                Negative
# 458                 Negative
# 231                 Negative
# 634                 Negative
# 230                 Negative
# 877                 Negative
# 229                 Negative
# 1548                Negative

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have your data in a pandas DataFrame called 'df'
# and the 'SentimentScore_VADER' column contains the sentiment scores.

# Plot the histogram
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.hist(df['SentimentScore_VADER'], bins=20, edgecolor='black')  # You can adjust the number of bins as needed
plt.title('Sentiment Score Histogram (VADER)')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# **13. Conduct a sentiment analysis with TextBlob sentiment classifier**

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import nltk
nltk.download('movie_reviews')

def get_sentiment_textblob(text):
    blob = TextBlob(text, analyzer=NaiveBayesAnalyzer())
    sentiment = blob.sentiment
    if sentiment.p_pos >= 0.6:
        return "Positive"
    elif sentiment.p_neg >= 0.6:
        return "Negative"
    return "Neutral"

df['SentimentCategory_Bayes'] = df['Sentiment_Comment'].apply(get_sentiment_textblob)

df[['Sentiment_Comment', 'SentimentCategory_Bayes']]
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/1207672200.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SentimentCategory_Bayes'] = df['Sentiment_Comment'].apply(get_sentiment_textblob)
#                                       Sentiment_Comment  \
# 2     I was so grateful to learn sign language as pa...
# 3     “Forgot! Forgot!” …. she is having a conversat...
# 4     The is clearly using an Australian accent when...
# 5     New level of respect for her unlocked. Clearly...
# 7     Now? Now in the world does she become this dam...
# ...                                                 ...
# 1630  i wish people would stop saying this, as if he...
# 1631       People need to stop because there is of way.
# 1632  I have gotten this comment and I look nothing ...
# 1633  I do not know what is other, her perfect tongu...
# 1634                           The loves showing it off
#
#      SentimentCategory_Bayes
# 2                   Positive
# 3                   Negative
# 4                   Positive
# 5                   Positive
# 7                   Positive
# ...                      ...
# 1630                Negative
# 1631                 Neutral
# 1632                Negative
# 1633                Negative
# 1634                Positive
#
# [1128 rows x 2 columns]

# %%
df[df.SentimentCategory_Bayes != df.SentimentCategory_VADER]
# Out:
#                                                 Comment  \
# 15    Sign language should be taught as a second lan...
# 17    I googled her name, and the google page change...
# 19    Well of course Margot Robbie is able to do thi...
# 23    I love how happy she got when she realized she...
# 24    Okay, I was never really a fan, but I can't he...
# ...                                                 ...
# 1622  James Gunn has said numerous times he wants to...
# 1624  It's def Margot Robbie and Carla Delevingne is...
# 1630  i wish people would stop saying this, as if he...
# 1631       People need to stop because there is NO way.
# 1633  I don't know what's hotter, her perfect tongue...
#
#                                         Cleaned_Comment  \
# 15    sign language taught second language option sc...
# 17     growled name goose page changed marie theme cool
# 19    well course forgot hobby able surprised simult...
# 23    love happy got realized knew could speak back ...
# 24               okay never really fan help respect lot
# ...                                                 ...
# 1622  james turn said numerous time want continue wo...
# 1624  def forgot hobby early delevingne one cropped ...
# 1630  wish people would stop saying ego big enough a...
# 1631                               people need stop way
# 1633    know perfect tongue getting slipped forgot like
#
#                                       Sentiment_Comment Language  Length  \
# 15    Sign language should be taught as a second lan...       en      73
# 17    I growled her name, and the goose page changed...       en      48
# 19    Well of course Forgot Hobbies is able to do th...       en     165
# 23    I love how happy she got when she realized she...       en      56
# 24    Okay, I was never really a fan, but I cannot h...       en      38
# ...                                                 ...      ...     ...
# 1622  James Turn has said numerous times he wants to...       en     224
# 1624  It is def Forgot Hobbies and Early Delevingne ...       en      88
# 1630  i wish people would stop saying this, as if he...       en      52
# 1631       People need to stop because there is of way.       en      20
# 1633  I do not know what is other, her perfect tongu...       en      47
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 15    [sign, language, taught, second, language, opt...                0.0000
# 17    [growled, name, goose, page, changed, marie, t...                0.4572
# 19    [well, course, forgot, hobby, able, surprised,...                0.9217
# 23    [love, happy, got, realized, knew, could, spea...                0.8860
# 24       [okay, never, really, fan, help, respect, lot]               -0.7474
# ...                                                 ...                   ...
# 1622  [james, turn, said, numerous, time, want, cont...                0.8782
# 1624  [def, forgot, hobby, early, delevingne, one, c...                0.0000
# 1630  [wish, people, would, stop, saying, ego, big, ...                0.1280
# 1631                          [people, need, stop, way]               -0.2960
# 1633  [know, perfect, tongue, getting, slipped, forg...                0.7351
#
#      SentimentCategory_VADER SentimentCategory_Bayes
# 15                   Neutral                Positive
# 17                  Positive                Negative
# 19                  Positive                Negative
# 23                  Positive                 Neutral
# 24                  Negative                 Neutral
# ...                      ...                     ...
# 1622                Positive                Negative
# 1624                 Neutral                Negative
# 1630                Positive                Negative
# 1631                Negative                 Neutral
# 1633                Positive                Negative
#
# [601 rows x 9 columns]

# %% [markdown]
# **14. Conduct a sentiment analysis with SocialSent**

# %%
import pandas as pd

df_lex = pd.read_csv("2000.tsv", sep="\t", header=None)
df_lex.columns=["word","sentiment", "std.dev"]
df_lex
# Out:
#            word  sentiment  std.dev
# 0          ugly      -3.90     1.16
# 1       painful      -3.69     1.53
# 2        intent      -3.49     1.67
# 3      terrible      -3.38     1.55
# 4         drunk      -3.28     1.16
# ...         ...        ...      ...
# 4919  perfectly       2.69     0.83
# 4920   romantic       2.70     0.76
# 4921   delicate       2.72     0.93
# 4922  beautiful       2.73     0.69
# 4923  wonderful       2.76     0.71
#
# [4924 rows x 3 columns]

# %%
df_lex["sentiment"].plot(kind="hist", color="g",
                         title="Frequency distribution of normalised sentiment score")
# Out:
# <AxesSubplot: title={'center': 'Frequency distribution of normalised sentiment score'}, ylabel='Frequency'>

# %%
df_lex["sentiment"].describe()
# Out:
# count    4924.000000
# mean        0.000014
# std         0.737869
# min        -3.900000
# 25%        -0.290000
# 50%         0.050000
# 75%         0.350000
# max         2.760000
# Name: sentiment, dtype: float64

# %%
df_lex.sort_values(by='sentiment', ascending=True)
# Out:
#            word  sentiment  std.dev
# 0          ugly      -3.90     1.16
# 1       painful      -3.69     1.53
# 2        intent      -3.49     1.67
# 3      terrible      -3.38     1.55
# 4         drunk      -3.28     1.16
# ...         ...        ...      ...
# 4919  perfectly       2.69     0.83
# 4920   romantic       2.70     0.76
# 4921   delicate       2.72     0.93
# 4922  beautiful       2.73     0.69
# 4923  wonderful       2.76     0.71
#
# [4924 rows x 3 columns]

# %%
df_lex.sort_values(by='sentiment', ascending=False)
# Out:
#            word  sentiment  std.dev
# 4923  wonderful       2.76     0.71
# 4922  beautiful       2.73     0.69
# 4921   delicate       2.72     0.93
# 4920   romantic       2.70     0.76
# 4919  perfectly       2.69     0.83
# ...         ...        ...      ...
# 4         drunk      -3.28     1.16
# 3      terrible      -3.38     1.55
# 2        intent      -3.49     1.67
# 1       painful      -3.69     1.53
# 0          ugly      -3.90     1.16
#
# [4924 rows x 3 columns]

# %%
mapping = {}
for row in df_lex[["word", "sentiment"]].to_dict("records"):
  mapping[row["word"]] = row["sentiment"]
mapping
# Out:
# {'ugly': -3.9,
#  'painful': -3.69,
#  'intent': -3.49,
#  'terrible': -3.38,
#  'drunk': -3.28,
#  'tragedy': -3.26,
#  'awful': -3.21,
#  'weak': -3.12,
#  'worst': -3.1,
#  'accident': -3.03,
#  'nightmare': -3.02,
#  'victim': -3.01,
#  'destruction': -2.95,
#  'faced': -2.93,
#  'damned': -2.92,
#  'souls': -2.92,
#  'scary': -2.92,
#  'poverty': -2.89,
#  'suicide': -2.85,
#  'events': -2.85,
#  'sorts': -2.84,
#  'trapped': -2.83,
#  'monster': -2.82,
#  'lonely': -2.8,
#  'circles': -2.8,
#  'scream': -2.79,
#  'ridiculous': -2.76,
#  'situations': -2.75,
#  'fate': -2.69,
#  'stupid': -2.67,
#  'bitter': -2.66,
#  'rural': -2.66,
#  'harsh': -2.66,
#  'fault': -2.62,
#  're': -2.6,
#  'occurred': -2.6,
#  'circumstances': -2.59,
#  'blame': -2.59,
#  'housing': -2.58,
#  'snake': -2.58,
#  'bored': -2.56,
#  'blacks': -2.55,
#  'sick': -2.53,
#  'dragon': -2.51,
#  'complained': -2.51,
#  'nasty': -2.5,
#  'tired': -2.49,
#  'acts': -2.48,
#  'bloody': -2.48,
#  'beast': -2.47,
#  'smelled': -2.44,
#  'minority': -2.43,
#  'incident': -2.42,
#  'boring': -2.42,
#  'creatures': -2.42,
#  'suffering': -2.39,
#  'creature': -2.39,
#  'anxious': -2.37,
#  'smells': -2.36,
#  'suffer': -2.36,
#  'frustrated': -2.36,
#  'worried': -2.34,
#  'mistakes': -2.33,
#  'witch': -2.33,
#  'battles': -2.31,
#  'upset': -2.3,
#  'angry': -2.3,
#  'beings': -2.29,
#  'victims': -2.28,
#  'mad': -2.27,
#  'admitted': -2.27,
#  'suffered': -2.27,
#  'confused': -2.26,
#  'opponents': -2.26,
#  'deadly': -2.26,
#  'smell': -2.26,
#  'alien': -2.25,
#  'stayed': -2.24,
#  'inevitable': -2.21,
#  'bother': -2.2,
#  'hungry': -2.2,
#  'scent': -2.19,
#  'cole': -2.19,
#  'bothered': -2.19,
#  'shame': -2.17,
#  'frightened': -2.15,
#  'troubled': -2.15,
#  'random': -2.15,
#  'guessed': -2.14,
#  'disaster': -2.12,
#  'ghost': -2.11,
#  'mess': -2.11,
#  'exhausted': -2.1,
#  'punishment': -2.1,
#  'demanding': -2.09,
#  'fucking': -2.09,
#  'contrast': -2.09,
#  'merely': -2.09,
#  'minds': -2.08,
#  'disappointed': -2.08,
#  'belong': -2.07,
#  'practically': -2.07,
#  'necessarily': -2.07,
#  'desperate': -2.07,
#  'strange': -2.06,
#  'aging': -2.06,
#  'crash': -2.05,
#  'bin': -2.05,
#  'worse': -2.04,
#  'hurt': -2.02,
#  'deaths': -2.01,
#  'cast': -2.01,
#  'scared': -2.01,
#  'lack': -1.97,
#  'fever': -1.96,
#  'concerned': -1.95,
#  'dirty': -1.94,
#  'murder': -1.93,
#  'likes': -1.93,
#  'powers': -1.92,
#  'burns': -1.91,
#  'remind': -1.89,
#  'crime': -1.89,
#  'mistake': -1.87,
#  'cat': -1.86,
#  'crimes': -1.86,
#  'lillian': -1.85,
#  'humanity': -1.85,
#  'uncomfortable': -1.85,
#  'injured': -1.84,
#  'damage': -1.82,
#  'dangerous': -1.82,
#  'devil': -1.81,
#  'occasional': -1.81,
#  'dealing': -1.8,
#  'insisted': -1.8,
#  'hurricane': -1.78,
#  'committed': -1.78,
#  'precisely': -1.77,
#  'cheap': -1.76,
#  'forgot': -1.74,
#  'everywhere': -1.74,
#  'cigarettes': -1.73,
#  'considering': -1.73,
#  'creation': -1.72,
#  'protest': -1.72,
#  'death': -1.72,
#  'deserve': -1.71,
#  'enemies': -1.71,
#  'gods': -1.7,
#  'families': -1.69,
#  'nervous': -1.69,
#  'causing': -1.69,
#  'wounded': -1.68,
#  'improve': -1.68,
#  'animal': -1.68,
#  'fool': -1.68,
#  'harm': -1.68,
#  'suspect': -1.68,
#  'occur': -1.67,
#  'minor': -1.66,
#  'guilty': -1.66,
#  'bird': -1.66,
#  'invisible': -1.65,
#  'suddenly': -1.64,
#  'chaos': -1.64,
#  'mccarthy': -1.63,
#  'smoke': -1.63,
#  'startled': -1.62,
#  'violence': -1.62,
#  'living': -1.62,
#  'feared': -1.62,
#  'threatened': -1.61,
#  'injuries': -1.6,
#  'injury': -1.6,
#  'innocent': -1.59,
#  'magic': -1.59,
#  'accompanied': -1.59,
#  'crisis': -1.58,
#  'bear': -1.56,
#  'soap': -1.56,
#  'embarrassed': -1.56,
#  'dogs': -1.55,
#  'tiger': -1.55,
#  'wealthy': -1.54,
#  'dog': -1.54,
#  'wolf': -1.54,
#  'burned': -1.53,
#  'arrested': -1.53,
#  'bomb': -1.52,
#  'bunch': -1.52,
#  'wound': -1.52,
#  'shocked': -1.52,
#  'absolute': -1.51,
#  'damn': -1.51,
#  'caused': -1.51,
#  'severe': -1.51,
#  'spirits': -1.5,
#  'accused': -1.5,
#  'sweat': -1.5,
#  'angels': -1.5,
#  'assault': -1.49,
#  'strikes': -1.48,
#  'attacks': -1.46,
#  'deeply': -1.46,
#  'survived': -1.46,
#  'pig': -1.46,
#  'beer': -1.44,
#  'insects': -1.44,
#  'stroke': -1.44,
#  'attack': -1.44,
#  'terrorism': -1.44,
#  'illness': -1.44,
#  'animals': -1.43,
#  'dumb': -1.43,
#  'humans': -1.42,
#  'pain': -1.42,
#  'killed': -1.41,
#  'lately': -1.41,
#  'whole': -1.4,
#  'mixed': -1.4,
#  'tail': -1.4,
#  'afraid': -1.4,
#  'communities': -1.39,
#  'virus': -1.39,
#  'trembling': -1.39,
#  'terrorist': -1.38,
#  'birds': -1.38,
#  'sad': -1.37,
#  'elderly': -1.37,
#  'whoever': -1.36,
#  'drank': -1.36,
#  'cared': -1.36,
#  'urban': -1.36,
#  'spell': -1.35,
#  'tobacco': -1.35,
#  'bleeding': -1.35,
#  'increasingly': -1.34,
#  'drinks': -1.34,
#  'useless': -1.34,
#  'giant': -1.33,
#  'pet': -1.33,
#  'drink': -1.33,
#  'changing': -1.33,
#  'act': -1.33,
#  'loss': -1.33,
#  'bears': -1.32,
#  'threatening': -1.32,
#  'stunned': -1.32,
#  'flies': -1.32,
#  'killing': -1.31,
#  'feeling': -1.31,
#  'situation': -1.31,
#  'racial': -1.3,
#  'countless': -1.3,
#  'explosion': -1.3,
#  'arrest': -1.3,
#  'alcohol': -1.29,
#  'wished': -1.29,
#  'repeatedly': -1.28,
#  'bandar': -1.28,
#  'nation': -1.27,
#  'drinking': -1.27,
#  'affected': -1.27,
#  'trap': -1.27,
#  'trouble': -1.26,
#  'suspected': -1.26,
#  'consequences': -1.26,
#  'changed': -1.26,
#  'bug': -1.26,
#  'bull': -1.25,
#  'residents': -1.25,
#  'conditions': -1.25,
#  'cigarette': -1.25,
#  'involved': -1.25,
#  'liked': -1.25,
#  'destroyed': -1.24,
#  'robot': -1.24,
#  'counted': -1.24,
#  'fought': -1.24,
#  'symptoms': -1.23,
#  'disorder': -1.23,
#  'african': -1.23,
#  'surprised': -1.22,
#  'big': -1.22,
#  'infection': -1.22,
#  'bitch': -1.21,
#  'causes': -1.21,
#  'jail': -1.21,
#  'burning': -1.21,
#  'collapse': -1.21,
#  'imagined': -1.21,
#  'terrorists': -1.2,
#  'cause': -1.2,
#  'essentially': -1.19,
#  'crazy': -1.19,
#  'cry': -1.19,
#  'reaction': -1.19,
#  'threats': -1.19,
#  'failure': -1.18,
#  'isolated': -1.18,
#  'got': -1.18,
#  'relieved': -1.18,
#  'witness': -1.17,
#  'teddy': -1.17,
#  'crying': -1.17,
#  'violent': -1.17,
#  'scene': -1.16,
#  'result': -1.16,
#  'slavery': -1.16,
#  'reminded': -1.15,
#  'cats': -1.14,
#  'immigrants': -1.14,
#  'species': -1.14,
#  'prison': -1.14,
#  'habit': -1.13,
#  'enemy': -1.13,
#  'disease': -1.13,
#  'cities': -1.13,
#  'warned': -1.13,
#  'vulnerable': -1.12,
#  'scenes': -1.12,
#  'recovery': -1.12,
#  'seemingly': -1.11,
#  'ali': -1.11,
#  'abruptly': -1.11,
#  'sort': -1.11,
#  'mouse': -1.1,
#  'boy': -1.1,
#  'feed': -1.1,
#  'trick': -1.1,
#  'regions': -1.1,
#  'sometimes': -1.1,
#  'destroy': -1.09,
#  'knew': -1.09,
#  'air': -1.09,
#  'damp': -1.08,
#  'danger': -1.08,
#  'phenomenon': -1.08,
#  'hunger': -1.08,
#  'serious': -1.07,
#  'feel': -1.07,
#  'abuse': -1.07,
#  'worlds': -1.07,
#  'error': -1.07,
#  'definition': -1.07,
#  'towns': -1.07,
#  'rich': -1.06,
#  'charges': -1.06,
#  'illegal': -1.06,
#  'clean': -1.06,
#  'attitude': -1.06,
#  'collapsed': -1.05,
#  'transformed': -1.05,
#  'saddam': -1.05,
#  'challenge': -1.05,
#  'actions': -1.05,
#  'wise': -1.05,
#  'distant': -1.05,
#  'frequent': -1.04,
#  'nest': -1.04,
#  'ill': -1.04,
#  'combination': -1.04,
#  'peterson': -1.04,
#  'talked': -1.03,
#  'aware': -1.03,
#  'charged': -1.03,
#  'weapons': -1.03,
#  'problems': -1.03,
#  'horror': -1.03,
#  'deal': -1.03,
#  'wings': -1.03,
#  'depression': -1.03,
#  'alabama': -1.02,
#  'breath': -1.02,
#  'afghanistan': -1.02,
#  'taliban': -1.02,
#  'observed': -1.02,
#  'cage': -1.02,
#  'experienced': -1.02,
#  'saudi': -1.02,
#  'sounded': -1.01,
#  'captured': -1.01,
#  'diseases': -1.01,
#  'loves': -1.01,
#  'demands': -1.01,
#  'convinced': -1.01,
#  'gang': -1.01,
#  'initially': -1.01,
#  'ethnic': -1.0,
#  'possibility': -1.0,
#  'criminal': -1.0,
#  'coffin': -0.99,
#  'potentially': -0.99,
#  'aimed': -0.98,
#  'fires': -0.98,
#  'bastard': -0.98,
#  'champagne': -0.98,
#  'challenges': -0.98,
#  'healing': -0.98,
#  'areas': -0.97,
#  'dying': -0.97,
#  'breathe': -0.97,
#  'feeding': -0.97,
#  'resulting': -0.97,
#  'deer': -0.97,
#  'bite': -0.97,
#  'afford': -0.97,
#  'silly': -0.97,
#  'killer': -0.97,
#  'threat': -0.96,
#  'warming': -0.96,
#  'bodies': -0.96,
#  'ass': -0.96,
#  'bacteria': -0.95,
#  'taste': -0.95,
#  'slave': -0.95,
#  'fish': -0.95,
#  'solve': -0.95,
#  'escaped': -0.95,
#  'woke': -0.95,
#  'suburban': -0.94,
#  'extreme': -0.94,
#  'weapon': -0.94,
#  'hunt': -0.94,
#  'americans': -0.94,
#  'mississippi': -0.94,
#  'represent': -0.94,
#  'wrong': -0.94,
#  'pipe': -0.94,
#  'criticism': -0.93,
#  'intense': -0.93,
#  'whites': -0.93,
#  'individuals': -0.93,
#  'panic': -0.93,
#  'loud': -0.93,
#  'eaten': -0.92,
#  'alarm': -0.92,
#  'southern': -0.92,
#  'survive': -0.92,
#  'ignoring': -0.91,
#  'forgotten': -0.91,
#  'smoking': -0.91,
#  'pakistan': -0.91,
#  'lots': -0.91,
#  'attacked': -0.91,
#  'northern': -0.91,
#  'washed': -0.91,
#  'homes': -0.9,
#  'concerns': -0.9,
#  'stern': -0.9,
#  'noise': -0.89,
#  'area': -0.89,
#  'faint': -0.89,
#  'rescue': -0.89,
#  'sheep': -0.88,
#  'problem': -0.88,
#  'wild': -0.88,
#  'throat': -0.88,
#  'biological': -0.88,
#  'stress': -0.88,
#  'due': -0.88,
#  'awkward': -0.88,
#  'cleaning': -0.87,
#  'immigration': -0.87,
#  'prevent': -0.87,
#  'target': -0.87,
#  'represented': -0.87,
#  'aids': -0.87,
#  'wondering': -0.87,
#  'battle': -0.87,
#  'sudden': -0.87,
#  'somewhat': -0.86,
#  'sound': -0.86,
#  'lot': -0.86,
#  'immediate': -0.86,
#  'care': -0.86,
#  'population': -0.86,
#  'guy': -0.86,
#  'human': -0.85,
#  'treat': -0.85,
#  'wars': -0.85,
#  'nerve': -0.85,
#  'country': -0.85,
#  'flying': -0.85,
#  'avoid': -0.85,
#  'cow': -0.85,
#  'units': -0.85,
#  'these': -0.85,
#  'knight': -0.85,
#  'slept': -0.84,
#  'jay': -0.84,
#  'dusty': -0.84,
#  'indians': -0.84,
#  'fraud': -0.83,
#  'screaming': -0.83,
#  'prisoners': -0.82,
#  'hero': -0.82,
#  'drugs': -0.82,
#  'hear': -0.82,
#  'existence': -0.82,
#  'curious': -0.82,
#  'issue': -0.81,
#  'confusion': -0.81,
#  'wake': -0.81,
#  'blind': -0.81,
#  'trial': -0.81,
#  'aspects': -0.81,
#  'dream': -0.8,
#  'survival': -0.8,
#  'event': -0.8,
#  'powerful': -0.8,
#  'linked': -0.8,
#  'absence': -0.8,
#  'encounter': -0.8,
#  'bone': -0.8,
#  'facing': -0.8,
#  'heard': -0.8,
#  'islamic': -0.8,
#  'reference': -0.8,
#  'dreams': -0.8,
#  'riding': -0.8,
#  'strike': -0.8,
#  'kinds': -0.79,
#  'constantly': -0.79,
#  'defeat': -0.79,
#  'endless': -0.79,
#  'shouting': -0.79,
#  'centers': -0.79,
#  'cycle': -0.79,
#  'remote': -0.78,
#  'climate': -0.78,
#  'hunting': -0.78,
#  'alike': -0.78,
#  'direct': -0.78,
#  'screamed': -0.78,
#  'wet': -0.78,
#  'laden': -0.78,
#  'shit': -0.77,
#  'limited': -0.77,
#  'viewed': -0.77,
#  'laugh': -0.77,
#  'dull': -0.76,
#  'shift': -0.76,
#  'variety': -0.76,
#  'hunter': -0.76,
#  'rival': -0.76,
#  'becoming': -0.76,
#  'thing': -0.76,
#  'struck': -0.76,
#  'racing': -0.76,
#  'angle': -0.76,
#  'fly': -0.76,
#  'hollow': -0.75,
#  'figures': -0.75,
#  'fresh': -0.75,
#  'asleep': -0.75,
#  'persons': -0.75,
#  'diabetes': -0.75,
#  'jet': -0.74,
#  'characters': -0.74,
#  'stare': -0.74,
#  'helicopter': -0.74,
#  'internal': -0.74,
#  'empire': -0.74,
#  'felt': -0.74,
#  'blood': -0.73,
#  'fur': -0.73,
#  'cattle': -0.73,
#  'surrounding': -0.73,
#  'targets': -0.73,
#  'admit': -0.73,
#  'plane': -0.73,
#  'concentration': -0.73,
#  'badly': -0.73,
#  'physically': -0.73,
#  'toilet': -0.73,
#  'reasons': -0.73,
#  'knocked': -0.73,
#  'remarkable': -0.72,
#  'fighting': -0.72,
#  'argued': -0.72,
#  'races': -0.72,
#  'mental': -0.72,
#  'lit': -0.72,
#  'police': -0.72,
#  'bit': -0.72,
#  'familiar': -0.72,
#  'allies': -0.72,
#  'acting': -0.72,
#  'risk': -0.71,
#  'facilities': -0.71,
#  'led': -0.71,
#  'cases': -0.71,
#  'flew': -0.71,
#  'bottle': -0.71,
#  'impressed': -0.71,
#  'fire': -0.71,
#  'kill': -0.71,
#  'fight': -0.71,
#  'coastal': -0.71,
#  'instantly': -0.71,
#  'transportation': -0.7,
#  'hears': -0.7,
#  'convince': -0.7,
#  'kitchen': -0.69,
#  'offices': -0.69,
#  'war': -0.69,
#  'responsible': -0.69,
#  'losses': -0.68,
#  'troops': -0.68,
#  'fired': -0.68,
#  'drug': -0.68,
#  'civilization': -0.68,
#  'handful': -0.68,
#  'quit': -0.68,
#  'crew': -0.68,
#  'basement': -0.68,
#  'upstairs': -0.67,
#  'highly': -0.67,
#  'swallowed': -0.67,
#  'capture': -0.67,
#  'change': -0.67,
#  'changes': -0.67,
#  'feels': -0.67,
#  'joining': -0.67,
#  'forces': -0.67,
#  'closely': -0.67,
#  'associated': -0.67,
#  'resist': -0.67,
#  'baghdad': -0.67,
#  'cave': -0.67,
#  'shock': -0.67,
#  'lone': -0.67,
#  'rome': -0.66,
#  'blast': -0.66,
#  'referred': -0.66,
#  'schools': -0.66,
#  'excited': -0.66,
#  'stated': -0.66,
#  'authorities': -0.66,
#  'fuck': -0.66,
#  'interested': -0.66,
#  'farms': -0.65,
#  'hell': -0.65,
#  'case': -0.65,
#  'wash': -0.65,
#  'jump': -0.65,
#  'effects': -0.65,
#  'coffee': -0.65,
#  'garbage': -0.65,
#  'wine': -0.65,
#  'meat': -0.65,
#  'alone': -0.65,
#  'involving': -0.65,
#  'critics': -0.65,
#  'equivalent': -0.65,
#  'continuing': -0.65,
#  'latter': -0.65,
#  'ears': -0.64,
#  'extremely': -0.64,
#  'fed': -0.64,
#  'declined': -0.64,
#  'statistics': -0.64,
#  'literally': -0.64,
#  'iran': -0.64,
#  'blow': -0.64,
#  'basically': -0.64,
#  'plot': -0.64,
#  'traveling': -0.64,
#  'historical': -0.64,
#  'describes': -0.64,
#  'jury': -0.64,
#  'steal': -0.64,
#  'room': -0.64,
#  'flames': -0.64,
#  'demanded': -0.63,
#  'filled': -0.63,
#  'spreading': -0.63,
#  'missile': -0.63,
#  'condition': -0.63,
#  'bet': -0.63,
#  'risks': -0.63,
#  'such': -0.63,
#  'opposed': -0.63,
#  'muslim': -0.63,
#  'heavily': -0.63,
#  'boom': -0.63,
#  'torn': -0.63,
#  'against': -0.62,
#  'becomes': -0.62,
#  'investigation': -0.62,
#  'overhead': -0.62,
#  'sentence': -0.62,
#  'louder': -0.62,
#  'landing': -0.62,
#  'genes': -0.62,
#  'sleep': -0.62,
#  'ate': -0.62,
#  'thousands': -0.62,
#  'straw': -0.62,
#  'region': -0.62,
#  'terror': -0.62,
#  'cancer': -0.62,
#  'opposition': -0.62,
#  'count': -0.61,
#  'poured': -0.61,
#  'sleeping': -0.61,
#  'rapid': -0.61,
#  'spite': -0.61,
#  'nor': -0.61,
#  'evolution': -0.61,
#  'mentioned': -0.61,
#  'bedroom': -0.61,
#  'race': -0.61,
#  'iraqi': -0.61,
#  'stole': -0.61,
#  'bullet': -0.61,
#  'particularly': -0.61,
#  'shower': -0.6,
#  'difficult': -0.6,
#  'reality': -0.6,
#  'burn': -0.6,
#  'moreover': -0.6,
#  'without': -0.6,
#  'episode': -0.6,
#  'bottles': -0.6,
#  'psychological': -0.6,
#  'affect': -0.6,
#  'cure': -0.6,
#  'terms': -0.6,
#  'firing': -0.6,
#  'trigger': -0.6,
#  'burst': -0.59,
#  'limits': -0.59,
#  'pressure': -0.59,
#  'raw': -0.59,
#  'during': -0.59,
#  'challenging': -0.59,
#  'planes': -0.59,
#  'iraq': -0.58,
#  'space': -0.58,
#  'ordinary': -0.58,
#  'economic': -0.58,
#  'shut': -0.58,
#  'aircraft': -0.58,
#  'grew': -0.58,
#  'exposure': -0.58,
#  'signs': -0.58,
#  'genetic': -0.58,
#  'tea': -0.58,
#  'shoot': -0.58,
#  'hearing': -0.58,
#  'labor': -0.58,
#  'laughter': -0.58,
#  'buildings': -0.58,
#  'awake': -0.58,
#  'purpose': -0.58,
#  'emergency': -0.57,
#  'gotten': -0.57,
#  'less': -0.57,
#  'type': -0.57,
#  'pouring': -0.57,
#  'chemicals': -0.57,
#  'shot': -0.57,
#  'treated': -0.57,
#  'rid': -0.57,
#  'acknowledged': -0.57,
#  'funny': -0.57,
#  'sink': -0.57,
#  'groups': -0.56,
#  'ignore': -0.56,
#  'mention': -0.56,
#  'development': -0.56,
#  'catching': -0.56,
#  'washing': -0.56,
#  'hunters': -0.56,
#  'protect': -0.56,
#  'hit': -0.56,
#  'concluded': -0.56,
#  'comment': -0.55,
#  'mercy': -0.55,
#  'anxiety': -0.55,
#  'blew': -0.55,
#  'needs': -0.55,
#  'flame': -0.55,
#  'flight': -0.54,
#  'apparent': -0.54,
#  'patients': -0.54,
#  'actual': -0.54,
#  'decisions': -0.54,
#  'prospect': -0.54,
#  'busy': -0.54,
#  'little': -0.54,
#  'ribs': -0.54,
#  'repair': -0.54,
#  'politicians': -0.54,
#  'community': -0.54,
#  'gene': -0.54,
#  'spots': -0.54,
#  'citizens': -0.54,
#  'activities': -0.53,
#  'majority': -0.53,
#  'soldiers': -0.53,
#  'missed': -0.53,
#  'tension': -0.53,
#  'lighting': -0.53,
#  'steam': -0.53,
#  'nuclear': -0.53,
#  'difficulty': -0.53,
#  'sharply': -0.53,
#  'processes': -0.53,
#  'slaves': -0.53,
#  'shooting': -0.53,
#  'wing': -0.53,
#  'pills': -0.52,
#  'favor': -0.52,
#  'negative': -0.52,
#  'projects': -0.52,
#  'added': -0.52,
#  'ignored': -0.52,
#  'issues': -0.52,
#  'construction': -0.52,
#  'eat': -0.52,
#  'ian': -0.52,
#  'sounds': -0.52,
#  'expecting': -0.52,
#  'suggested': -0.52,
#  'shield': -0.52,
#  'cries': -0.51,
#  'storm': -0.51,
#  'constant': -0.51,
#  'thinks': -0.51,
#  'wildlife': -0.51,
#  'examples': -0.51,
#  'burden': -0.51,
#  'spread': -0.51,
#  'leader': -0.5,
#  'guns': -0.5,
#  'border': -0.5,
#  'cloud': -0.5,
#  'broken': -0.5,
#  'partly': -0.5,
#  'tales': -0.5,
#  'fierce': -0.5,
#  'glass': -0.5,
#  'decline': -0.5,
#  'denied': -0.5,
#  'towel': -0.5,
#  'brain': -0.5,
#  'recognized': -0.5,
#  'dozens': -0.5,
#  'arab': -0.5,
#  'somebody': -0.5,
#  'fog': -0.5,
#  'identity': -0.5,
#  'became': -0.49,
#  'shadow': -0.49,
#  'lightning': -0.49,
#  'too': -0.49,
#  'brad': -0.49,
#  'charge': -0.49,
#  'typically': -0.49,
#  'landed': -0.49,
#  'realized': -0.49,
#  'himself': -0.49,
#  'powell': -0.49,
#  'thoroughly': -0.49,
#  'mood': -0.49,
#  'effectively': -0.49,
#  'teeth': -0.49,
#  'currently': -0.49,
#  'makes': -0.49,
#  'cruz': -0.48,
#  'quickly': -0.48,
#  'al': -0.48,
#  'yankees': -0.48,
#  'joke': -0.48,
#  'total': -0.48,
#  'treatment': -0.48,
#  'dust': -0.48,
#  'facts': -0.48,
#  'types': -0.48,
#  'tissue': -0.48,
#  'horses': -0.48,
#  'brains': -0.48,
#  'bathroom': -0.48,
#  'breakfast': -0.47,
#  'mist': -0.47,
#  'jokes': -0.47,
#  'rooms': -0.47,
#  'bar': -0.47,
#  'footsteps': -0.47,
#  'ongoing': -0.47,
#  'believes': -0.47,
#  'combat': -0.47,
#  'many': -0.47,
#  'seemed': -0.47,
#  'punch': -0.47,
#  'harris': -0.47,
#  'pilot': -0.47,
#  'nonetheless': -0.47,
#  'armed': -0.47,
#  'horse': -0.47,
#  'gulf': -0.47,
#  'shadows': -0.46,
#  'shapes': -0.46,
#  'sharp': -0.46,
#  'grief': -0.46,
#  'voices': -0.46,
#  'alliance': -0.46,
#  'everyday': -0.46,
#  'stomach': -0.46,
#  'link': -0.46,
#  'eliot': -0.45,
#  'mild': -0.45,
#  'hoped': -0.45,
#  'rough': -0.45,
#  'overcome': -0.45,
#  'bucket': -0.45,
#  'juice': -0.45,
#  'claimed': -0.45,
#  'expensive': -0.45,
#  'sliced': -0.45,
#  'farmers': -0.45,
#  'stuff': -0.45,
#  'duncan': -0.45,
#  'barrel': -0.45,
#  'matters': -0.44,
#  'hide': -0.44,
#  'cells': -0.44,
#  'universe': -0.44,
#  'wiped': -0.44,
#  'rifle': -0.44,
#  'surgery': -0.44,
#  'mysterious': -0.44,
#  'vanished': -0.44,
#  'lead': -0.44,
#  'gun': -0.44,
#  'often': -0.44,
#  'several': -0.43,
#  'proved': -0.43,
#  'shelter': -0.43,
#  'pitch': -0.43,
#  'become': -0.43,
#  'cops': -0.43,
#  'again': -0.43,
#  'detective': -0.43,
#  'northwest': -0.43,
#  'unknown': -0.43,
#  'themselves': -0.43,
#  'proposed': -0.43,
#  'altogether': -0.43,
#  'wondered': -0.43,
#  'kid': -0.43,
#  'eating': -0.43,
#  'went': -0.43,
#  'shots': -0.43,
#  'force': -0.43,
#  'kicking': -0.43,
#  'describe': -0.43,
#  'calvin': -0.42,
#  'odd': -0.42,
#  'soldier': -0.42,
#  'gone': -0.42,
#  'lungs': -0.42,
#  'failing': -0.42,
#  'orleans': -0.42,
#  'numerous': -0.42,
#  'dozen': -0.42,
#  'ai': -0.42,
#  'tended': -0.42,
#  'doctors': -0.42,
#  'blowing': -0.42,
#  'chemical': -0.42,
#  'challenged': -0.42,
#  'diverse': -0.41,
#  'hogan': -0.41,
#  'clouds': -0.41,
#  'background': -0.41,
#  'lawyer': -0.41,
#  'consciousness': -0.41,
#  'argue': -0.41,
#  'clinical': -0.41,
#  'existed': -0.41,
#  'workers': -0.41,
#  'patient': -0.41,
#  'domestic': -0.41,
#  'crack': -0.41,
#  'explanation': -0.41,
#  'unusual': -0.41,
#  'regarding': -0.41,
#  'lives': -0.41,
#  'handle': -0.41,
#  'jews': -0.41,
#  'skinny': -0.4,
#  'moment': -0.4,
#  'impression': -0.4,
#  'harder': -0.4,
#  'cop': -0.4,
#  ...}

# %%
def sentiment_score(row):
  text = row["Sentiment_Comment"].lower()
  score = 0
  n = 0
  for word in text.split():
    if word in mapping:
      n += 1
      score += mapping[word]
  if n > 0:
    return score / n
  return 0

df["SentimentScore_SocialSent"] = df.apply(sentiment_score, axis=1)
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/707511239.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SentimentScore_SocialSent"] = df.apply(sentiment_score, axis=1)
#                                                 Comment  \
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# 5     New level of respect for her unlocked. Clearly...
# 7     How? How in the world does she become this dam...
# ...                                                 ...
# 1630  i wish people would stop saying this, as if he...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
#
#                                         Cleaned_Comment  \
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# 5     new level respect unlocked clearly treating ha...
# 7            world become damn attractive perfect woman
# ...                                                 ...
# 1630  wish people would stop saying ego big enough a...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
#
#                                       Sentiment_Comment Language  Length  \
# 2     I was so grateful to learn sign language as pa...       en     168
# 3     “Forgot! Forgot!” …. she is having a conversat...       en      39
# 4     The is clearly using an Australian accent when...       en      41
# 5     New level of respect for her unlocked. Clearly...       en     129
# 7     Now? Now in the world does she become this dam...       en      42
# ...                                                 ...      ...     ...
# 1630  i wish people would stop saying this, as if he...       en      52
# 1631       People need to stop because there is of way.       en      20
# 1632  I have gotten this comment and I look nothing ...       en      39
# 1633  I do not know what is other, her perfect tongu...       en      47
# 1634                           The loves showing it off       en      12
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 2     [grateful, learn, sign, language, part, curric...                0.9210
# 3        [forgot, forgot, ”, …, conversation, dickhead]               -0.6892
# 4      [clearly, using, australian, accent, sign, dare]                0.4574
# 5     [new, level, respect, unlocked, clearly, treat...                0.8748
# 7     [world, become, damn, attractive, perfect, woman]                0.5907
# ...                                                 ...                   ...
# 1630  [wish, people, would, stop, saying, ego, big, ...                0.1280
# 1631                          [people, need, stop, way]               -0.2960
# 1632     [gotten, comment, look, nothing, like, either]               -0.2755
# 1633  [know, perfect, tongue, getting, slipped, forg...                0.7351
# 1634                                    [love, showing]                0.5719
#
#      SentimentCategory_VADER SentimentCategory_Bayes  \
# 2                   Positive                Positive
# 3                   Negative                Negative
# 4                   Positive                Positive
# 5                   Positive                Positive
# 7                   Positive                Positive
# ...                      ...                     ...
# 1630                Positive                Negative
# 1631                Negative                 Neutral
# 1632                Negative                Negative
# 1633                Positive                Negative
# 1634                Positive                Positive
#
#       SentimentScore_SocialSent
# 2                      0.277647
# 3                      0.815000
# 4                      0.290000
# 5                      0.263000
# 7                     -0.507500
# ...                         ...
# 1630                  -0.156667
# 1631                  -0.103333
# 1632                  -0.278000
# 1633                  -0.354000
# 1634                  -0.296667
#
# [1128 rows x 10 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have your data in a pandas DataFrame called 'df'
# and the 'SentimentScore_VADER' column contains the sentiment scores.

# Plot the histogram
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.hist(df['SentimentScore_SocialSent'], bins=20, edgecolor='black')  # You can adjust the number of bins as needed
plt.title('Sentiment Score Histogram (SocialSent)')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Categorize the sentiment based on the sentiment score
df['SentimentCategory_SocialSent'] = df['SentimentScore_SocialSent'].apply(lambda score: 'Positive' if score >= 0.05 else ('Negative' if score <= -0.05 else 'Neutral'))
df
# Out:
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/1396522850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SentimentCategory_SocialSent'] = df['SentimentScore_SocialSent'].apply(lambda score: 'Positive' if score >= 0.05 else ('Negative' if score <= -0.05 else 'Neutral'))
#                                                 Comment  \
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# 5     New level of respect for her unlocked. Clearly...
# 7     How? How in the world does she become this dam...
# ...                                                 ...
# 1630  i wish people would stop saying this, as if he...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
#
#                                         Cleaned_Comment  \
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# 5     new level respect unlocked clearly treating ha...
# 7            world become damn attractive perfect woman
# ...                                                 ...
# 1630  wish people would stop saying ego big enough a...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
#
#                                       Sentiment_Comment Language  Length  \
# 2     I was so grateful to learn sign language as pa...       en     168
# 3     “Forgot! Forgot!” …. she is having a conversat...       en      39
# 4     The is clearly using an Australian accent when...       en      41
# 5     New level of respect for her unlocked. Clearly...       en     129
# 7     Now? Now in the world does she become this dam...       en      42
# ...                                                 ...      ...     ...
# 1630  i wish people would stop saying this, as if he...       en      52
# 1631       People need to stop because there is of way.       en      20
# 1632  I have gotten this comment and I look nothing ...       en      39
# 1633  I do not know what is other, her perfect tongu...       en      47
# 1634                           The loves showing it off       en      12
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 2     [grateful, learn, sign, language, part, curric...                0.9210
# 3        [forgot, forgot, ”, …, conversation, dickhead]               -0.6892
# 4      [clearly, using, australian, accent, sign, dare]                0.4574
# 5     [new, level, respect, unlocked, clearly, treat...                0.8748
# 7     [world, become, damn, attractive, perfect, woman]                0.5907
# ...                                                 ...                   ...
# 1630  [wish, people, would, stop, saying, ego, big, ...                0.1280
# 1631                          [people, need, stop, way]               -0.2960
# 1632     [gotten, comment, look, nothing, like, either]               -0.2755
# 1633  [know, perfect, tongue, getting, slipped, forg...                0.7351
# 1634                                    [love, showing]                0.5719
#
#      SentimentCategory_VADER SentimentCategory_Bayes  \
# 2                   Positive                Positive
# 3                   Negative                Negative
# 4                   Positive                Positive
# 5                   Positive                Positive
# 7                   Positive                Positive
# ...                      ...                     ...
# 1630                Positive                Negative
# 1631                Negative                 Neutral
# 1632                Negative                Negative
# 1633                Positive                Negative
# 1634                Positive                Positive
#
#       SentimentScore_SocialSent SentimentCategory_SocialSent
# 2                      0.277647                     Positive
# 3                      0.815000                     Positive
# 4                      0.290000                     Positive
# 5                      0.263000                     Positive
# 7                     -0.507500                     Negative
# ...                         ...                          ...
# 1630                  -0.156667                     Negative
# 1631                  -0.103333                     Negative
# 1632                  -0.278000                     Negative
# 1633                  -0.354000                     Negative
# 1634                  -0.296667                     Negative
#
# [1128 rows x 11 columns]

# %%
bayes_counts = df['SentimentCategory_Bayes'].value_counts()
vader_counts = df['SentimentCategory_VADER'].value_counts()
social_sent_counts = df['SentimentCategory_SocialSent'].value_counts()

# Combine the sentiment categories from all three columns and sort them
sentiment_categories = sorted(set(bayes_counts.index) | set(vader_counts.index) | set(social_sent_counts.index))

fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.25

x_bayes = range(len(sentiment_categories))
x_vader = [pos + bar_width for pos in x_bayes]
x_social_sent = [pos + bar_width * 2 for pos in x_bayes]

ax.bar(x_bayes, [bayes_counts.get(category, 0) for category in sentiment_categories], bar_width, label='Bayes')
ax.bar(x_vader, [vader_counts.get(category, 0) for category in sentiment_categories], bar_width, label='VADER')
ax.bar(x_social_sent, [social_sent_counts.get(category, 0) for category in sentiment_categories], bar_width, label='SocialSent')

ax.set_xticks([pos + bar_width for pos in x_bayes])
ax.set_xticklabels(sentiment_categories, rotation=45, ha='right')
ax.set_xlabel('Sentiment Category')
ax.set_ylabel('Count')
ax.set_title('Sentiment Analysis Comparison')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **15. Sentiment analysis with machine learning**

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stopwords = stopwords.words('english')

def preprocess(row):
    text = row["Sentiment_Comment"].lower()
    keep = []
    for word in text.split():
        if word in stopwords:
            continue
        if word.startswith("@"):
            continue
        if word.startswith("http"):
            continue
        if word.startswith("#"):
            continue
        if word == "follow":
            continue
        if len(word) <= 1:
            continue
        keep.append(word)
    return ' '.join(keep)

df["cleaned_text"] = df.apply(preprocess, axis=1)
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /var/folders/_k/_rt6thqx6mj63rxtq_q_l7j00000gn/T/ipykernel_22599/2044802583.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cleaned_text"] = df.apply(preprocess, axis=1)
#                                                 Comment  \
# 2     I was so grateful to learn sign language as pa...
# 3     “Margot! Margot!” …. she’s having a conversati...
# 4     She's clearly using an Australian accent when ...
# 5     New level of respect for her unlocked. Clearly...
# 7     How? How in the world does she become this dam...
# ...                                                 ...
# 1630  i wish people would stop saying this, as if he...
# 1631       People need to stop because there is NO way.
# 1632  I’ve gotten this comment and I look nothing li...
# 1633  I don't know what's hotter, her perfect tongue...
# 1634                           She loves showing it off
#
#                                         Cleaned_Comment  \
# 2     grateful learn sign language part curriculum p...
# 3               forgot forgot ” … conversation dickhead
# 4             clearly using australian accent sign dare
# 5     new level respect unlocked clearly treating ha...
# 7            world become damn attractive perfect woman
# ...                                                 ...
# 1630  wish people would stop saying ego big enough a...
# 1631                               people need stop way
# 1632            gotten comment look nothing like either
# 1633    know perfect tongue getting slipped forgot like
# 1634                                       love showing
#
#                                       Sentiment_Comment Language  Length  \
# 2     I was so grateful to learn sign language as pa...       en     168
# 3     “Forgot! Forgot!” …. she is having a conversat...       en      39
# 4     The is clearly using an Australian accent when...       en      41
# 5     New level of respect for her unlocked. Clearly...       en     129
# 7     Now? Now in the world does she become this dam...       en      42
# ...                                                 ...      ...     ...
# 1630  i wish people would stop saying this, as if he...       en      52
# 1631       People need to stop because there is of way.       en      20
# 1632  I have gotten this comment and I look nothing ...       en      39
# 1633  I do not know what is other, her perfect tongu...       en      47
# 1634                           The loves showing it off       en      12
#
#                                       Tokenized_Comment  SentimentScore_VADER  \
# 2     [grateful, learn, sign, language, part, curric...                0.9210
# 3        [forgot, forgot, ”, …, conversation, dickhead]               -0.6892
# 4      [clearly, using, australian, accent, sign, dare]                0.4574
# 5     [new, level, respect, unlocked, clearly, treat...                0.8748
# 7     [world, become, damn, attractive, perfect, woman]                0.5907
# ...                                                 ...                   ...
# 1630  [wish, people, would, stop, saying, ego, big, ...                0.1280
# 1631                          [people, need, stop, way]               -0.2960
# 1632     [gotten, comment, look, nothing, like, either]               -0.2755
# 1633  [know, perfect, tongue, getting, slipped, forg...                0.7351
# 1634                                    [love, showing]                0.5719
#
#      SentimentCategory_VADER SentimentCategory_Bayes  \
# 2                   Positive                Positive
# 3                   Negative                Negative
# 4                   Positive                Positive
# 5                   Positive                Positive
# 7                   Positive                Positive
# ...                      ...                     ...
# 1630                Positive                Negative
# 1631                Negative                 Neutral
# 1632                Negative                Negative
# 1633                Positive                Negative
# 1634                Positive                Positive
#
#       SentimentScore_SocialSent SentimentCategory_SocialSent  \
# 2                      0.277647                     Positive
# 3                      0.815000                     Positive
# 4                      0.290000                     Positive
# 5                      0.263000                     Positive
# 7                     -0.507500                     Negative
# ...                         ...                          ...
# 1630                  -0.156667                     Negative
# 1631                  -0.103333                     Negative
# 1632                  -0.278000                     Negative
# 1633                  -0.354000                     Negative
# 1634                  -0.296667                     Negative
#
#                                            cleaned_text
# 2     grateful learn sign language part curriculum p...
# 3            “forgot! forgot!” …. conversation dickhead
# 4      clearly using australian accent signs! dare she?
# 5     new level respect unlocked. clearly treating h...
# 7     now? world become damn attractive? perfect woman.
# ...                                                 ...
# 1630  wish people would stop saying this, ego big en...
# 1631                              people need stop way.
# 1632            gotten comment look nothing like either
# 1633  know other, perfect tongue getting slipped for...
# 1634                                      loves showing
#
# [1128 rows x 12 columns]

# %%
from textblob.classifiers import NaiveBayesClassifier

train = df[['cleaned_text', 'SentimentCategory_VADER']][0:792]
test = df[['cleaned_text', 'SentimentCategory_VADER']][792:]

# Sample labeled data for sentiment analysis
training_data = [(row['cleaned_text'], row['SentimentCategory_VADER']) for _, row in train.iterrows()]

# Create a NaiveBayesClassifier and train it with the labeled data
classifier = NaiveBayesClassifier(training_data)

# Evaluate the classifier (optional)
testing_data = [(row['cleaned_text'], row['SentimentCategory_VADER']) for _, row in test.iterrows()]

accuracy = classifier.accuracy(testing_data)
print("Accuracy with VADER:", accuracy)

# Sentiment analysis on new text
new_text = "The book is fantastic!"
sentiment = classifier.classify(new_text)
print("Sentiment:", sentiment)  # Output: "positive"
# Out:
# Accuracy with VADER: 0.5505952380952381
# Sentiment: Positive

# %%
from textblob.classifiers import NaiveBayesClassifier

train = df[['cleaned_text', 'SentimentCategory_Bayes']][0:792]
test = df[['cleaned_text', 'SentimentCategory_Bayes']][792:]

# Sample labeled data for sentiment analysis
training_data = [(row['cleaned_text'], row['SentimentCategory_Bayes']) for _, row in train.iterrows()]

# Create a NaiveBayesClassifier and train it with the labeled data
classifier = NaiveBayesClassifier(training_data)

# Evaluate the classifier (optional)
testing_data = [(row['cleaned_text'], row['SentimentCategory_Bayes']) for _, row in test.iterrows()]

accuracy = classifier.accuracy(testing_data)
print("Accuracy with Bayes:", accuracy)

# Sentiment analysis on new text
new_text = "The book is fantastic!"
sentiment = classifier.classify(new_text)
print("Sentiment:", sentiment)  # Output: "positive"
# Out:
# Accuracy with Bayes: 0.48214285714285715
# Sentiment: Neutral

# %%
train = df[['cleaned_text', 'SentimentCategory_SocialSent']][0:792]
test = df[['cleaned_text', 'SentimentCategory_SocialSent']][792:]

# Sample labeled data for sentiment analysis
training_data = [(row['cleaned_text'], row['SentimentCategory_SocialSent']) for _, row in train.iterrows()]

# Create a NaiveBayesClassifier and train it with the labeled data
classifier = NaiveBayesClassifier(training_data)

# Evaluate the classifier (optional)
testing_data = [(row['cleaned_text'], row['SentimentCategory_SocialSent']) for _, row in test.iterrows()]

accuracy = classifier.accuracy(testing_data)
print("Accuracy with SocialSent:", accuracy)

# Sentiment analysis on new text
new_text = "The book is fantastic!"
sentiment = classifier.classify(new_text)
print("Sentiment:", sentiment)  # Output: "positive"
# Out:
# Accuracy with SocialSent: 0.6041666666666666
# Sentiment: Positive

# %% [markdown]
# **16. Extract the dataframe as csv**

# %%
df.to_csv('SentimentAnalysis_MargotRobbie.csv', index=False)
