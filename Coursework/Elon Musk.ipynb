# %%
import pandas as pd

# Specify the file path where the CSV file is located
csv_file_path = "reddit_comments.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#                                            Comment_Body           Author  \
# 0     Atleast twitter is dying so the world will be ...       Daboormero
# 1         Cheemlon Musk looks like he's constantly high       Matt_32506
# 2     I get my news from dogelore! They are even qui...  RevolverPhoenix
# 3     Now we can call every video uploaded on twitte...        Null42x64
# 4                           Cheemlon Mumsk is so cursed  Forsaken_Ad_475
# ...                                                 ...              ...
# 1940        stop brigading the subreddit and get a life     LarsMacReady
# 1941        I don't think you know what that word means     BruceBrewsky
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...  my_blue_pelican
# 1943                   I missed you too angry pixel man     BruceBrewsky
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...  my_blue_pelican
#
#       Upvotes  Awards                 Date
# 0         208       0  2023-07-24 15:32:03
# ...

# %%
from textblob import TextBlob

# Assuming you have the 'df' DataFrame with a column 'Comment_Body'

# Function to apply TextBlob and get sentiment and subjectivity
def analyze_comment(comment):
    blob = TextBlob(comment)
    corrected_comment = blob.correct()
    sentiment = blob.sentiment.polarity
    subjectivity = blob.sentiment.subjectivity
    return corrected_comment, sentiment, subjectivity

# Apply TextBlob to the 'Comment_Body' column and create new columns for sentiment and subjectivity
df[['Corrected_Comment', 'Sentiment', 'Subjectivity']] = df['Comment_Body'].apply(lambda x: pd.Series(analyze_comment(x)))

# Now, 'df' contains new columns 'Sentiment' and 'Subjectivity' based on TextBlob analysis.

# %%
df
# Out:
#                                            Comment_Body           Author  \
# 0     Atleast twitter is dying so the world will be ...       Daboormero
# 1         Cheemlon Musk looks like he's constantly high       Matt_32506
# 2     I get my news from dogelore! They are even qui...  RevolverPhoenix
# 3     Now we can call every video uploaded on twitte...        Null42x64
# 4                           Cheemlon Mumsk is so cursed  Forsaken_Ad_475
# ...                                                 ...              ...
# 1940        stop brigading the subreddit and get a life     LarsMacReady
# 1941        I don't think you know what that word means     BruceBrewsky
# 1942  Sup cum rag? I missed you 😊\n\nDidn't you have...  my_blue_pelican
# 1943                   I missed you too angry pixel man     BruceBrewsky
# 1944  Still didn't learn how to read 😞\n\nIt doesn't...  my_blue_pelican
#
#       Upvotes  Awards                 Date  \
# 0         208       0  2023-07-24 15:32:03
# ...
