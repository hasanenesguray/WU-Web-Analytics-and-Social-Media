# %% [markdown]
# **1. Upload the dataset**

# %%
import pandas as pd

# Specify the file path where the CSV file is located
csv_file_path = "reddit_comments_ElonMusk.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)
df
# Out:
#                                            Comment_Body                Author  \
# 0     This is evident with the differences between h...  BadBoysWillBeSpanked
# 1     I have been warning about this for 2 years. Ho...                Hatrct
# 2     Tesla / Space X:\n\n* All the sexual assault, ...                Chroko
# 3     I firmly believe there is no endgame. This who...              Joec1211
# 4     Unfortunately unpopular opinion:\n\nElon musk ...              SkonerTM
# ...                                                 ...                   ...
# 1995  I just can't help but wonder if he is playing ...       XHandsomexJackx
# 1996  That is such an unimaginative and petty list a...                 Surur
# 1997  Good to see the hearings methods are working t...          dandilion788
# 1998  x.com was a farce. Elon actually tried coding ...                  oht7
# 1999  How many times does someone need to tell the r...          couchnapper3
#
#       Upvotes  Awards                 Date
# 0           1       0  2023-07-28 16:20:38
# 1           3       0  2023-07-26 00:57:32
# 2           2       0  2023-07-28 07:43:22
# 3          10       0  2023-07-24 20:30:07
# 4           0       0  2023-07-29 22:41:01
# ...       ...     ...                  ...
# 1995        2       0  2023-07-28 04:55:09
# 1996      -17       0  2023-07-28 10:34:27
# 1997        1       0  2023-07-27 18:17:28
# 1998        1       0  2023-07-25 05:00:55
# 1999        3       0  2023-07-28 01:45:31
#
# [2000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Comment_Body  2000 non-null   object
#  1   Author        2000 non-null   object
#  2   Upvotes       2000 non-null   int64
#  3   Awards        2000 non-null   int64
#  4   Date          2000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 78.2+ KB

# %% [markdown]
# **2. Adjust the type of the columns**

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Comment_Body  2000 non-null   object
#  1   Author        2000 non-null   object
#  2   Upvotes       2000 non-null   int64
#  3   Awards        2000 non-null   int64
#  4   Date          2000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 78.2+ KB

# %%
df
# Out:
#                                            Comment_Body                Author  \
# 0     This is evident with the differences between h...  BadBoysWillBeSpanked
# 1     I have been warning about this for 2 years. Ho...                Hatrct
# 2     Tesla / Space X:\n\n* All the sexual assault, ...                Chroko
# 3     I firmly believe there is no endgame. This who...              Joec1211
# 4     Unfortunately unpopular opinion:\n\nElon musk ...              SkonerTM
# ...                                                 ...                   ...
# 1995  I just can't help but wonder if he is playing ...       XHandsomexJackx
# 1996  That is such an unimaginative and petty list a...                 Surur
# 1997  Good to see the hearings methods are working t...          dandilion788
# 1998  x.com was a farce. Elon actually tried coding ...                  oht7
# 1999  How many times does someone need to tell the r...          couchnapper3
#
#       Upvotes  Awards                Date
# 0           1       0 2023-07-28 16:20:38
# 1           3       0 2023-07-26 00:57:32
# 2           2       0 2023-07-28 07:43:22
# 3          10       0 2023-07-24 20:30:07
# 4           0       0 2023-07-29 22:41:01
# ...       ...     ...                 ...
# 1995        2       0 2023-07-28 04:55:09
# 1996      -17       0 2023-07-28 10:34:27
# 1997        1       0 2023-07-27 18:17:28
# 1998        1       0 2023-07-25 05:00:55
# 1999        3       0 2023-07-28 01:45:31
#
# [2000 rows x 5 columns]

# %% [markdown]
# **3. Visualize the dataset**

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the "Date" column
# Convert the "Date" column to pandas datetime type if it's not already in the datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Create the histogram
plt.figure(figsize=(10, 6))  # Set the figure size (adjust as needed)
plt.hist(df['Date'], bins=20, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('Histogram of Comments related with Margot Robbie')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines to y-axis
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have your data in a pandas DataFrame called 'df'
# and the 'Author' column contains the names of authors.

# Exclude rows with the author '[deleted]'
df_filtered = df[df['Author'] != '[deleted]']

# Count the occurrences of each author
author_counts = df_filtered['Author'].value_counts()

# Select the top 15 authors (excluding [deleted])
top_15_authors = author_counts.head(15)

# Plot the bar graph for top 15 authors (excluding [deleted])
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
top_15_authors.plot(kind='bar')
plt.title('Top 15 Authors')
plt.xlabel('Authors')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()  # To avoid label cutoffs
plt.show()

# %%
sorted_df = df.sort_values(by='Upvotes', ascending=False)

top_5_comments_upvotes = sorted_df.head(5)
top_5_comments_upvotes
# Out:
#                                            Comment_Body                Author  \
# 295   I will never understand how someone posts a pi...  politicsfuckingsucks
# 763   If you havent clicked the link and watched the...               phroug2
# 1352  Literally just took everything unique about Tw...      IvanTheAppealing
# 310   Remember the woman who wrote the big long edit...            rolandfoxx
# 1967  LOL - meanwhile pornography and and even pedop...          InternetPeon
#
#       Upvotes  Awards                Date
# 295      7553      13 2023-07-29 20:20:33
# 763      4000       0 2023-07-28 21:42:49
# 1352     3626       0 2023-07-29 17:37:41
# 310      3507       0 2023-07-27 19:21:53
# 1967     3331       0 2023-07-28 21:10:51

# %%
for i, comment in enumerate(top_5_comments_upvotes['Comment_Body']):
    print(i, comment)
# Out:
# 0 I will never understand how someone posts a picture of a video and then is satisfied the message was conveyed or something. Wtf you making me google and shit for. [link to tweet](https://twitter.com/LolOverruled/status/1685339679032287233). The video is pretty fucking astonishing. Shows Elon not giving the slightest fuck about other people. Like our poster not including a link.
# 1 If you havent clicked the link and watched the ad, you should; its great!
#
# "Get out of our bedroom!"
#
# "I won the last election. I'm not going anywhere. I'm just gonna watch...and make sure you dont do anything illegal."
# 2 Literally just took everything unique about Twitter and threw it in the garbage cause this 12 year old of a man REALLY thinks the letter x is cool.
# 3 Remember the woman who wrote the big long editorial about how with Elon in charge Twitter was finally going to do more than pay lip service to getting all the exploitative content posters off the platform?
#
# **Edit:**  [Here's the editorial](https://www.newsweek.com/while-blue-checks-whine-about-extremism-elon-musk-protecting-sexually-exploited-children-opinion-1761383)
# 4 LOL - meanwhile pornography and and even pedophilia is readily available site wide along with its purveyors.

# %%
sorted_df = df.sort_values(by='Awards', ascending=False)

top_5_comments_awards = sorted_df.head(5)
top_5_comments_awards
# Out:
#                                            Comment_Body                Author  \
# 295   I will never understand how someone posts a pi...  politicsfuckingsucks
# 34    We can't always avoid products from companies ...             ibond_007
# 1528  Non vedo l'ora\n\nhttps://preview.redd.it/tedp...         Palle_rotonde
# 1444  Elon is the sole reason we're not buying a Mod...           klasspirate
# 719   Ah yes, Mr. Free Speech Absolutist at work. 😂\...           Speculawyer
#
#       Upvotes  Awards                Date
# 295      7553      13 2023-07-29 20:20:33
# 34        430       4 2023-07-28 04:30:19
# 1528     1093       4 2023-07-24 10:46:50
# 1444      540       3 2023-07-28 20:50:49
# 719       870       3 2023-07-29 14:33:05

# %%
for i, comment in enumerate(top_5_comments_awards['Comment_Body']):
    print(i, comment)
# Out:
# 0 I will never understand how someone posts a picture of a video and then is satisfied the message was conveyed or something. Wtf you making me google and shit for. [link to tweet](https://twitter.com/LolOverruled/status/1685339679032287233). The video is pretty fucking astonishing. Shows Elon not giving the slightest fuck about other people. Like our poster not including a link.
# 1 We can't always avoid products from companies whose CEO is an asshole!. That said, Tesla product itself is piece of shit. Every fucking shit he claimed about Tesla was vaporware!
#
# 1. Elon said, tesla super charging won't be profit centers, but it turned out to be. He jacked up the price and now it is at par with gas prices!
# 2. Tesla service centers won't be profit centers. But the service centers are worse than auto dealers. They lie, they over charge and they rip the customer off!
# 3. The car will be an appreciating asset. Fuck! It is the worst depreciating asset, I have ever owned!
# 4. FSD will drive coast to coast by 2016 and it is 2023 it can't even do a simple highway driving without phantom breaks.
# 5. The car mileage is fake. Elon cooked up the numbers and the real world mileage of Audi is better than Tesla.
# 6. The car rattles like piece of shit..
# 7. The service experience is pathetic.
# 8. Tesla insurance is fucking fraud. I can't call a customer service. I have to be on the phone for 45 mins just to get hold of an operator.
# 9. The fucking list goes  on and on.
#
# Yes I don't want to buy the car because it is a piece of shit not just because Elon is a scumbag!
# 2 Non vedo l'ora
#
# https://preview.redd.it/tedp8kob7wdb1.jpeg?width=720&format=pjpg&auto=webp&s=25a91b891fc5aead583e1e54694f27d4e4b49d14
# 3 Elon is the sole reason we're not buying a Model Y right now and instead are saving for the more expensive R1S. The guy is an embarrassment.
# 4 Ah yes, Mr. Free Speech Absolutist at work. 😂
#
# He has absolutely revealed himself as petty and a massive liar.
#
# BTW, that commercial is hilarious, check it out!
#
# Let's Streisand effect that commercial!
# https://youtu.be/z10j_H7zOb8

# %% [markdown]
# **4.Apply Contractions to fix the comments**

# %%
import contractions
df['Fixed_Comment'] = df['Comment_Body'].apply(contractions.fix)
df[df['Fixed_Comment'] != df['Comment_Body']][8:]
# Out:
#                                            Comment_Body              Author  \
# 8     Eh I can kind of see where he's coming from he...  ObservationalHumor
# 9     Elon needs to step down like Steve Jobs did in...            Nooooeel
# 10    If you think he’s anything less than a genius,...           McCool303
# 11    I hate Musk and his followers as much as every...             eNkelll
# 12    Elon Musk is rebranding Twitter -- one of the ...    derelictdickweed
# ...                                                 ...                 ...
# 1989  Just a quick money grab. They released 1% of t...              ipsole
# 1990  Probably changed it to X for some easier way f...            JZeus_09
# 1991  "Tweeting" can just as easily evolve into "Xin...          superc3lll
# 1995  I just can't help but wonder if he is playing ...     XHandsomexJackx
# 1999  How many times does someone need to tell the r...        couchnapper3
#
#       Upvotes  Awards                Date  \
# 8           3       0 2023-07-28 15:29:59
# 9          13       0 2023-07-28 07:48:36
# 10          1       0 2023-07-25 18:50:43
# 11         -2       0 2023-07-28 07:24:02
# 12        101       0 2023-07-24 13:23:47
# ...       ...     ...                 ...
# 1989        1       0 2023-07-26 00:13:06
# 1990        1       0 2023-07-25 18:34:06
# 1991        6       0 2023-07-24 19:39:47
# 1995        2       0 2023-07-28 04:55:09
# 1999        3       0 2023-07-28 01:45:31
#
#                                           Fixed_Comment
# 8     Eh I can kind of see where he is coming from h...
# 9     Elon needs to step down like Steve Jobs did in...
# 10    If you think he is anything less than a genius...
# 11    I hate Musk and his followers as much as every...
# 12    Elon Musk is rebranding Twitter -- one of the ...
# ...                                                 ...
# 1989  Just a quick money grab. They released 1% of t...
# 1990  Probably changed it to X for some easier way f...
# 1991  "Tweeting" can just as easily evolve into "Xin...
# 1995  I just cannot help but wonder if he is playing...
# 1999  How many times does someone need to tell the r...
#
# [1287 rows x 6 columns]

# %% [markdown]
# **5. Patterns Substitution**

# %%
import re

price_pattern = r'\$\d+(\.\d{2})?'   # Matches prices in the format $X.XX or $X
size_pattern = r'\b\d+(?:\.\d+)?(?:x\d+(?:\.\d+)?)?\b'   # Matches sizes like 10x10 or 2.5x3.2
volume_pattern = r'\b\d+(?:\.\d+)?\s*[Ll]\b'   # Matches volumes like 1L or 0.5 l
weight_pattern = r'\b\d+(?:\.\d+)?\s*[Kk][Gg]\b'   # Matches weights like 2.5 kg or 10.2 Kg

def substitute_patterns(text):
    text = re.sub(price_pattern, '[PRICE]', text)
    text = re.sub(size_pattern, '[SIZE]', text)
    text = re.sub(volume_pattern, '[VOLUME]', text)
    text = re.sub(weight_pattern, '[WEIGHT]', text)
    return text

df['Substituted_Comment'] = df['Fixed_Comment'].apply(substitute_patterns)
df[df['Substituted_Comment'] != df['Fixed_Comment']][['Comment_Body','Substituted_Comment']][1:]
# Out:
#                                            Comment_Body  \
# 1     I have been warning about this for 2 years. Ho...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# 6     For what its worth, I found the original tweet...
# 7     The thing about Musk, is that he's an incredib...
# 8     Eh I can kind of see where he's coming from he...
# ...                                                 ...
# 1936  FYI\n\nThere’s a 30 day timer on full account ...
# 1945  I did not believe it at first but this motherf...
# 1964  Musk is continually stuck in the 1999-2000 era...
# 1976  He just wants to be the talk of the town 24/7,...
# 1989  Just a quick money grab. They released 1% of t...
#
#                                     Substituted_Comment
# 1     I have been warning about this for [SIZE] year...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# 6     For what its worth, I found the original tweet...
# 7     The thing about Musk, is that he is an incredi...
# 8     Eh I can kind of see where he is coming from h...
# ...                                                 ...
# 1936  FYI\n\nThere is a [SIZE] day timer on full acc...
# 1945  I did not believe it at first but this motherf...
# 1964  Musk is continually stuck in the [SIZE]-[SIZE]...
# 1976  He just wants to be the talk of the town [SIZE...
# 1989  Just a quick money grab. They released [SIZE]%...
#
# [364 rows x 2 columns]

# %% [markdown]
# **6. Http links replacement**

# %%
link_pattern = r'https?://\S+'

def substitute_links(text):
    return re.sub(link_pattern, '[LINK]', text)

df['Replaced_Comment'] = df['Substituted_Comment'].apply(substitute_links)
df[df['Substituted_Comment'] != df['Replaced_Comment']][['Comment_Body','Replaced_Comment']][67:]
# Out:
#                                            Comment_Body  \
# 1316  https://preview.redd.it/q5y8oginlwdb1.png?widt...
# 1389  Facciamo una caffettiera\n\nhttps://preview.re...
# 1391  Just leaving this here... \n\nhttps://preview....
# 1528  Non vedo l'ora\n\nhttps://preview.redd.it/tedp...
# 1531  https://philmaffetone.com/researchers-find-dra...
# 1582  [Elias sure isn't a fan of Elon Musk](https://...
# 1654  &#x200B;\n\nhttps://preview.redd.it/go1mouq5pp...
# 1668  All yall do yourself a favor and watch this do...
# 1703  [https://twitter.com/kyledunnigan/status/16585...
# 1757  In case people forgot: https://www.educator.co...
# 1789  Ce logo me fait penser une version ali express...
# 1833  A me pare un plagio a [Xorg](https://gitlab.fr...
# 1993  [That ad](https://youtu.be/z10j_H7zOb8) is inc...
#
#                                        Replaced_Comment
# 1316          [LINK]\n\nIndecisione su quale X cliccare
# 1389                 Facciamo una caffettiera\n\n[LINK]
# 1391               Just leaving this here... \n\n[LINK]
# 1528                           Non vedo l'ora\n\n[LINK]
# 1531                                             [LINK]
# 1582      [Elias sure is not a fan of Elon Musk]([LINK]
# 1654                                 &#x200B;\n\n[LINK]
# 1668  All you all do yourself a favor and watch this...
# 1703                                            [[LINK]
# 1757                      In case people forgot: [LINK]
# 1789  Ce logo me fait penser une version ali express...
# 1833     A me pare un plagio a [Xorg]([LINK] ma ok Elon
# 1993  [That ad]([LINK] is incredible. Good thing Elo...

# %%
df = df[df["Replaced_Comment"]!="[[LINK]"]
df = df[df["Replaced_Comment"]!="[LINK]"]
df = df[df["Replaced_Comment"]!="&#x200B;\n\n[LINK]"]
df
# Out:
#                                            Comment_Body                Author  \
# 0     This is evident with the differences between h...  BadBoysWillBeSpanked
# 1     I have been warning about this for 2 years. Ho...                Hatrct
# 2     Tesla / Space X:\n\n* All the sexual assault, ...                Chroko
# 3     I firmly believe there is no endgame. This who...              Joec1211
# 4     Unfortunately unpopular opinion:\n\nElon musk ...              SkonerTM
# ...                                                 ...                   ...
# 1995  I just can't help but wonder if he is playing ...       XHandsomexJackx
# 1996  That is such an unimaginative and petty list a...                 Surur
# 1997  Good to see the hearings methods are working t...          dandilion788
# 1998  x.com was a farce. Elon actually tried coding ...                  oht7
# 1999  How many times does someone need to tell the r...          couchnapper3
#
#       Upvotes  Awards                Date  \
# 0           1       0 2023-07-28 16:20:38
# 1           3       0 2023-07-26 00:57:32
# 2           2       0 2023-07-28 07:43:22
# 3          10       0 2023-07-24 20:30:07
# 4           0       0 2023-07-29 22:41:01
# ...       ...     ...                 ...
# 1995        2       0 2023-07-28 04:55:09
# 1996      -17       0 2023-07-28 10:34:27
# 1997        1       0 2023-07-27 18:17:28
# 1998        1       0 2023-07-25 05:00:55
# 1999        3       0 2023-07-28 01:45:31
#
#                                           Fixed_Comment  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for 2 years. Ho...
# 2     Tesla / Space X:\n\n* All the sexual assault, ...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                                     Substituted_Comment  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for [SIZE] year...
# 2     Tesla / Space X:\n\n* All the sexual assault, ...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                                        Replaced_Comment
# 0     This is evident with the differences between h...
# 1     I have been warning about this for [SIZE] year...
# 2     Tesla / Space X:\n\n* All the sexual assault, ...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
# [1997 rows x 8 columns]

# %% [markdown]
# **7. Remove Line Breaks**

# %%
def remove_line_breaks(text):
    return text.replace('\n', ' ')

df['Without_LineBreaks'] = df['Replaced_Comment'].apply(remove_line_breaks)

df[df['Replaced_Comment'] != df['Without_LineBreaks']][['Comment_Body','Without_LineBreaks']][48:]
# Out:
#                                            Comment_Body  \
# 51    Here was the negotiation:\n\nMusk: "I want you...
# 52    I'm not saying that Elon Musk himself is a ped...
# 53    This is what I don't understand. Why do we hav...
# 54    Truth. All the legacy blue checks from pre mus...
# 55    tldr; Twitter is set to undergo a major rebran...
# ...                                                 ...
# 1948  Why is anyone still on twitter still after all...
# 1953  Who would think he wasn't up to something? \n\...
# 1965  What a dirtbag using another family’s trauma t...
# 1971  Pior que tinha um usuário do twitter cujo user...
# 1992  La phrase "je twitte" sera donc remplacée par ...
#
#                                      Without_LineBreaks
# 51    Here was the negotiation:  Musk: "I want your ...
# 52    I am not saying that Elon Musk himself is a pe...
# 53    This is what I do not understand. Why do we ha...
# 54    Truth. All the legacy blue checks from pre mus...
# 55    tldr; Twitter is set to undergo a major rebran...
# ...                                                 ...
# 1948  Why is anyone still on twitter still after all...
# 1953  Who would think he was not up to something?   ...
# 1965  What a dirtbag using another family’s trauma t...
# 1971  Pior que tinha um usuário do twitter cujo user...
# 1992  La phrase "je twitte" sera donc remplacée par ...
#
# [662 rows x 2 columns]

# %% [markdown]
# **8. Apply TextBlob to correct comments**

# %%
from textblob import TextBlob

def correct_comment(comment):
    blob = TextBlob(comment)
    corrected_comment = blob.correct()
    return str(corrected_comment)

df['Corrected_Comment(SentimentAnalysis)'] = df['Without_LineBreaks'].apply(correct_comment)
df[df['Without_LineBreaks'] != df['Corrected_Comment(SentimentAnalysis)']][['Comment_Body','Corrected_Comment(SentimentAnalysis)']][2:12]
# Out:
#                                          Comment_Body  \
# 2   Tesla / Space X:\n\n* All the sexual assault, ...
# 3   I firmly believe there is no endgame. This who...
# 4   Unfortunately unpopular opinion:\n\nElon musk ...
# 5   A long time ago I worked with a startup founde...
# 6   For what its worth, I found the original tweet...
# 7   The thing about Musk, is that he's an incredib...
# 8   Eh I can kind of see where he's coming from he...
# 9   Elon needs to step down like Steve Jobs did in...
# 10  If you think he’s anything less than a genius,...
# 11  I hate Musk and his followers as much as every...
#
#                  Corrected_Comment(SentimentAnalysis)
# 2   Cela / Space X:  * All the sexual assault, har...
# 3   I firmly believe there is no engage. His whole...
# 4   Unfortunately unpopular opinion:  On must has ...
# 5   A long time ago I worked with a started founde...
# 6   For what its worth, I found the original sweet...
# 7   The thing about Dusk, is that he is an incredi...
# 8   Oh I can kind of see where he is coming from h...
# 9   On needs to step down like Steve Sobs did in [...
# 10  Of you think he is anything less than a genius...
# 11  I hate Dusk and his followers as much as every...

# %%
words_to_keep = ['This', 'Tesla', 'Elon', 'elon', 'Musk', 'musk', 'Steve', 'Jobs', 'Trump', 'Paypal', 'PayPal', 'SpaceX',
                 'Space X', 'Sell', "Let's", "endgame", "Bad", "Might", "Plot", "Guy", "app", 'What', 'donut', 'My',
                 'Just', 'So', 'Can', 'No', 'Could', 'media']

def correct_comment(row):
    preserved_words = set(words_to_keep)
    preserved_punctuations = set(['.', ',', '!', '?', ':', ';'])

    words = re.findall(r'\w+|[^\w\s]', row)

    processed_words = [word if word in preserved_words or word in preserved_punctuations else str(TextBlob(word).correct()) for word in words]

    return ' '.join(processed_words)


df['Corrected_Comment(SentimentAnalysis)'] = df['Without_LineBreaks'].apply(correct_comment)
df[df['Without_LineBreaks'] != df['Corrected_Comment(SentimentAnalysis)']][['Comment_Body', 'Corrected_Comment(SentimentAnalysis)']][323:]
# Out:
#                                            Comment_Body  \
# 323   From "free speech absolutist" to "free speech ...
# 324   I'm seeing some people saying it's the same vi...
# 325   My town has a sign like this for a “new” (actu...
# 326   A blockchain developed by AI and backed by the...
# 327   In season 5 of Arrested Development Michael fi...
# ...                                                 ...
# 1995  I just can't help but wonder if he is playing ...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                    Corrected_Comment(SentimentAnalysis)
# 323   From " free speech absolutism " to " free spee...
# 324   I am seeing some people saying it is the same ...
# 325   My town has a sign like this for a “ new ” ( a...
# 326   A blockchain developed by of and backed by the...
# 327   In season [ SIZE ] of Arrested Development Mic...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an imaginative and petty list and...
# 1997  Good to see the hearings methods are working t...
# 1998  x . com was a farce . Elon actually tried comi...
# 1999  Now many times does someone need to tell the r...
#
# [1666 rows x 2 columns]

# %% [markdown]
# **9.Add a common case stage**

# %%
df['Lower_Comment'] = df['Corrected_Comment(SentimentAnalysis)'].str.lower()
df[['Comment_Body', 'Lower_Comment']]
# Out:
#                                            Comment_Body  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for 2 years. Ho...
# 2     Tesla / Space X:\n\n* All the sexual assault, ...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# ...                                                 ...
# 1995  I just can't help but wonder if he is playing ...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                                           Lower_Comment
# 0     this is evident with the differences between h...
# 1     i have been warning about this for [ size ] ye...
# 2     tesla / space x : * all the sexual assault , h...
# 3     i firmly believe there is no endgame . this wh...
# 4     unfortunately unpopular opinion : elon musk ha...
# ...                                                 ...
# 1995  i just cannot help but wonder if he is playing...
# 1996  that is such an imaginative and petty list and...
# 1997  good to see the hearings methods are working t...
# 1998  x . com was a farce . elon actually tried comi...
# 1999  now many times does someone need to tell the r...
#
# [1997 rows x 2 columns]

# %% [markdown]
# **10. Tokenization**

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

nltk.download('punkt')

def tokenize_text(text):
    sentences = sent_tokenize(text)   # Tokenize into sentences
    words = [word_tokenize(sentence) for sentence in sentences]   # Tokenize each sentence into words
    return ' '.join([' '.join(sentence) for sentence in words]) 

df['Tokenized_Comment'] = df['Lower_Comment'].apply(tokenize_text)
df[df['Tokenized_Comment'] != df['Lower_Comment']][['Lower_Comment', 'Tokenized_Comment']][339:]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                           Lower_Comment  \
# 1995  i just cannot help but wonder if he is playing...
# 1999  now many times does someone need to tell the r...
#
#                                       Tokenized_Comment
# 1995  i just can not help but wonder if he is playin...
# 1999  now many times does someone need to tell the r...

# %% [markdown]
# **11. Remove the stopwords**

# %%
from nltk.corpus import stopwords

def remove_stopwords_except_not(text):
    stop_words = set(stopwords.words('english'))
    stop_words.remove("not")
    words = text.split()  # Split the space-separated string into a list of words
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)  # Convert the list of words back to a space-separated string

# Apply the remove_stopwords function to the "Tokenized_Comment" column
df['Without_Stopwords'] = df['Tokenized_Comment'].apply(remove_stopwords_except_not)
df[df['Tokenized_Comment'] != df['Without_Stopwords']][['Tokenized_Comment', 'Without_Stopwords']][1251:]
# Out:
#                                       Tokenized_Comment  \
# 1253  😳 should not the appropriate response be to se...
# 1254  i like dark mode , i prefer dark mode . but ri...
# 1255  ll log l ' ho vista da qualche altar part . . ...
# 1256  `` commander , the liberals keep making progre...
# 1257  musk can not continue to get away with this ma...
# ...                                                 ...
# 1995  i just can not help but wonder if he is playin...
# 1996  that is such an imaginative and petty list and...
# 1997  good to see the hearings methods are working t...
# 1998  x . com was a farce . elon actually tried comi...
# 1999  now many times does someone need to tell the r...
#
#                                       Without_Stopwords
# 1253  😳 not appropriate response send information au...
# 1254  like dark mode , prefer dark mode . rich guy d...
# 1255  log l ' ho vista da qualche altar part . . . [...
# 1256  `` commander , liberals keep making progress a...
# 1257  musk not continue get away manipulation bullsh...
# ...                                                 ...
# 1995  not help wonder playing intricate game chess n...
# 1996  imaginative petty list meaningless not compare...
# 1997  good see hearings methods working lead change ...
# 1998  x . com farce . elon actually tried coming . t...
# 1999  many times someone need tell rest get `` whate...
#
# [743 rows x 2 columns]

# %% [markdown]
# **12. Remove emojis, punctations**

# %%
import string

def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # Emoticons
                               u"\U0001F300-\U0001F5FF"  # Symbols & Pictographs
                               u"\U0001F680-\U0001F6FF"  # Transport & Map Symbols
                               u"\U0001F700-\U0001F77F"  # Alchemical Symbols
                               u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                               u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                               u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                               u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                               u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                               u"\U00002702-\U000027B0"  # Dingbats
                               u"\U000024C2-\U0001F251" 
                               "]+")
    return emoji_pattern.sub(r'', text)

def remove_punctuation_and_quotes(text):
    # Combine the punctuation string with the double quote character
    custom_punctuation = string.punctuation + '"' + "“"
    return text.translate(str.maketrans('', '', custom_punctuation))

# Apply the functions to the "Without_Stopwords" column
df['Prepared_Comment'] = df['Without_Stopwords'].apply(remove_emojis)
df['Prepared_Comment'] = df['Prepared_Comment'].apply(remove_punctuation_and_quotes)

df[df['Prepared_Comment'] != df['Without_Stopwords']][['Comment_Body', 'Prepared_Comment']][1240:]
# Out:
#                                            Comment_Body  \
# 1253  😳\n\nShouldn’t the appropriate response be to ...
# 1254  I like dark mode, I prefer dark mode. But rich...
# 1255  Il logo l'ho visto da qualche altra parte ...\...
# 1256  "Commander, the liberals keep making progress ...
# 1257  Musk cannot continue to get away with this man...
# ...                                                 ...
# 1995  I just can't help but wonder if he is playing ...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                                        Prepared_Comment
# 1253   not appropriate response send information aut...
# 1254  like dark mode  prefer dark mode  rich guy dic...
# 1255  log l  ho vista da qualche altar part     link...
# 1256   commander  liberals keep making progress abor...
# 1257  musk not continue get away manipulation bullsh...
# ...                                                 ...
# 1995  not help wonder playing intricate game chess n...
# 1996  imaginative petty list meaningless not compare...
# 1997  good see hearings methods working lead change ...
# 1998  x  com farce  elon actually tried coming  tell...
# 1999  many times someone need tell rest get  whateve...
#
# [719 rows x 2 columns]

# %% [markdown]
# **13. Apply lemmatisation**

# %%
from nltk.stem import WordNetLemmatizer

nltk.download('omw-1.4')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
    return ' '.join(lemmatized_words)

df['Lemmatized_Comment'] = df['Prepared_Comment'].apply(preprocess_text)
df[df['Lemmatized_Comment'] != df['Prepared_Comment']][['Prepared_Comment', 'Lemmatized_Comment']][:]
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/hasanenesguray/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                        Prepared_Comment  \
# 0     evident differences zuckerburg  watching polic...
# 1     warning  size  years  hopefully someone famous...
# 2     tesla  space x   sexual assault  harassment ra...
# 3     firmly believe endgame  whole debate episode  ...
# 4     unfortunately unpopular opinion  elon musk don...
# ...                                                 ...
# 1995  not help wonder playing intricate game chess n...
# 1996  imaginative petty list meaningless not compare...
# 1997  good see hearings methods working lead change ...
# 1998  x  com farce  elon actually tried coming  tell...
# 1999  many times someone need tell rest get  whateve...
#
#                                      Lemmatized_Comment
# 0     evident difference zuckerburg watching policy ...
# 1     warning size year hopefully someone famous bri...
# 2     tesla space x sexual assault harassment racism...
# 3     firmly believe endgame whole debate episode du...
# 4     unfortunately unpopular opinion elon musk done...
# ...                                                 ...
# 1995  help wonder playing intricate game chess under...
# 1996  imaginative petty list meaningless compared pr...
# 1997  good see hearing method working lead change mi...
# 1998  x com farce elon actually tried coming tell ev...
# 1999  many time someone need tell rest get whatever ...
#
# [1985 rows x 2 columns]

# %% [markdown]
# **14. Remove duplicates**

# %%
df.drop_duplicates(subset=['Comment_Body', 'Author'], keep='first', inplace=True)
df
# Out:
#                                            Comment_Body                Author  \
# 0     This is evident with the differences between h...  BadBoysWillBeSpanked
# 1     I have been warning about this for 2 years. Ho...                Hatrct
# 2     Tesla / Space X:\n\n* All the sexual assault, ...                Chroko
# 3     I firmly believe there is no endgame. This who...              Joec1211
# 4     Unfortunately unpopular opinion:\n\nElon musk ...              SkonerTM
# ...                                                 ...                   ...
# 1995  I just can't help but wonder if he is playing ...       XHandsomexJackx
# 1996  That is such an unimaginative and petty list a...                 Surur
# 1997  Good to see the hearings methods are working t...          dandilion788
# 1998  x.com was a farce. Elon actually tried coding ...                  oht7
# 1999  How many times does someone need to tell the r...          couchnapper3
#
#       Upvotes  Awards                Date  \
# 0           1       0 2023-07-28 16:20:38
# 1           3       0 2023-07-26 00:57:32
# 2           2       0 2023-07-28 07:43:22
# 3          10       0 2023-07-24 20:30:07
# 4           0       0 2023-07-29 22:41:01
# ...       ...     ...                 ...
# 1995        2       0 2023-07-28 04:55:09
# 1996      -17       0 2023-07-28 10:34:27
# 1997        1       0 2023-07-27 18:17:28
# 1998        1       0 2023-07-25 05:00:55
# 1999        3       0 2023-07-28 01:45:31
#
#                                           Fixed_Comment  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for 2 years. Ho...
# 2     Tesla / Space X:\n\n* All the sexual assault, ...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                                     Substituted_Comment  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for [SIZE] year...
# 2     Tesla / Space X:\n\n* All the sexual assault, ...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                                        Replaced_Comment  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for [SIZE] year...
# 2     Tesla / Space X:\n\n* All the sexual assault, ...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:\n\nElon musk ...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                                      Without_LineBreaks  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for [SIZE] year...
# 2     Tesla / Space X:  * All the sexual assault, ha...
# 3     I firmly believe there is no endgame. This who...
# 4     Unfortunately unpopular opinion:  Elon musk ha...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an unimaginative and petty list a...
# 1997  Good to see the hearings methods are working t...
# 1998  x.com was a farce. Elon actually tried coding ...
# 1999  How many times does someone need to tell the r...
#
#                    Corrected_Comment(SentimentAnalysis)  \
# 0     This is evident with the differences between h...
# 1     I have been warning about this for [ SIZE ] ye...
# 2     Tesla / Space X : * All the sexual assault , h...
# 3     I firmly believe there is no endgame . This wh...
# 4     Unfortunately unpopular opinion : Elon musk ha...
# ...                                                 ...
# 1995  I just cannot help but wonder if he is playing...
# 1996  That is such an imaginative and petty list and...
# 1997  Good to see the hearings methods are working t...
# 1998  x . com was a farce . Elon actually tried comi...
# 1999  Now many times does someone need to tell the r...
#
#                                           Lower_Comment  \
# 0     this is evident with the differences between h...
# 1     i have been warning about this for [ size ] ye...
# 2     tesla / space x : * all the sexual assault , h...
# 3     i firmly believe there is no endgame . this wh...
# 4     unfortunately unpopular opinion : elon musk ha...
# ...                                                 ...
# 1995  i just cannot help but wonder if he is playing...
# 1996  that is such an imaginative and petty list and...
# 1997  good to see the hearings methods are working t...
# 1998  x . com was a farce . elon actually tried comi...
# 1999  now many times does someone need to tell the r...
#
#                                       Tokenized_Comment  \
# 0     this is evident with the differences between h...
# 1     i have been warning about this for [ size ] ye...
# 2     tesla / space x : * all the sexual assault , h...
# 3     i firmly believe there is no endgame . this wh...
# 4     unfortunately unpopular opinion : elon musk ha...
# ...                                                 ...
# 1995  i just can not help but wonder if he is playin...
# 1996  that is such an imaginative and petty list and...
# 1997  good to see the hearings methods are working t...
# 1998  x . com was a farce . elon actually tried comi...
# 1999  now many times does someone need to tell the r...
#
#                                       Without_Stopwords  \
# 0     evident differences zuckerburg ' watching poli...
# 1     warning [ size ] years . hopefully someone fam...
# 2     tesla / space x : * sexual assault , harassmen...
# 3     firmly believe endgame . whole debate episode ...
# 4     unfortunately unpopular opinion : elon musk do...
# ...                                                 ...
# 1995  not help wonder playing intricate game chess n...
# 1996  imaginative petty list meaningless not compare...
# 1997  good see hearings methods working lead change ...
# 1998  x . com farce . elon actually tried coming . t...
# 1999  many times someone need tell rest get `` whate...
#
#                                        Prepared_Comment  \
# 0     evident differences zuckerburg  watching polic...
# 1     warning  size  years  hopefully someone famous...
# 2     tesla  space x   sexual assault  harassment ra...
# 3     firmly believe endgame  whole debate episode  ...
# 4     unfortunately unpopular opinion  elon musk don...
# ...                                                 ...
# 1995  not help wonder playing intricate game chess n...
# 1996  imaginative petty list meaningless not compare...
# 1997  good see hearings methods working lead change ...
# 1998  x  com farce  elon actually tried coming  tell...
# 1999  many times someone need tell rest get  whateve...
#
#                                      Lemmatized_Comment
# 0     evident difference zuckerburg watching policy ...
# 1     warning size year hopefully someone famous bri...
# 2     tesla space x sexual assault harassment racism...
# 3     firmly believe endgame whole debate episode du...
# 4     unfortunately unpopular opinion elon musk done...
# ...                                                 ...
# 1995  help wonder playing intricate game chess under...
# 1996  imaginative petty list meaningless compared pr...
# 1997  good see hearing method working lead change mi...
# 1998  x com farce elon actually tried coming tell ev...
# 1999  many time someone need tell rest get whatever ...
#
# [1995 rows x 15 columns]

# %% [markdown]
# **15. Extract the dataframe as csv**

# %%
df.to_csv('PreprocessedComments_ElonMusk.csv', index=False)
