# %%
import pandas as pd

df_lex = pd.read_csv("2000.tsv", sep="\t", header=None)
df_lex.columns=["word","sentiment", "std.dev"]

# %%
df_lex
# Out:
#            word  sentiment  std.dev
# 0          ugly      -3.90     1.16
# 1       painful      -3.69     1.53
# 2        intent      -3.49     1.67
# 3      terrible      -3.38     1.55
# 4         drunk      -3.28     1.16
# ...         ...        ...      ...
# 4919  perfectly       2.69     0.83
# 4920   romantic       2.70     0.76
# 4921   delicate       2.72     0.93
# 4922  beautiful       2.73     0.69
# 4923  wonderful       2.76     0.71
#
# [4924 rows x 3 columns]

# %%
import json

comments = []
for i in range(1,6):
  with open("yt%i.json" % i, "r") as f:
    data = json.load(f)
    for item in data["items"]:
      comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
      comment = comment.strip()
      if len(comment) < 10:
        continue
      comments.append({"text": comment})
df = pd.DataFrame(comments)
df
# Out:
#                                                   text
# 0    They had to smash it with the handle of a knif...
# 1                     YEAH SIMPLE INGREDIENTS MR BETCH
# 2                     Tuco’s looking pretty tight yo ❤
# 3      I’m wondering if these are keto friendly.. Lol.
# 4                         They ain’t that good low key
# ..                                                 ...
# 462  This is literally the reason why i bought popc...
# 463  aint no way they actually made this a commerci...
# 464  When I tasted the white cheddar popcorners shi...
# 465  Imagine the production and recipe teams for Po...
# 466  I seen the commercial on Super Bowl LVII and g...
#
# [467 rows x 1 columns]

# %%
#Q1
df_lex["sentiment"].plot(kind="hist", color="g",
                         title="Frequency distribution of normalised sentiment score")
# Out:
# <Axes: title={'center': 'Frequency distribution of normalised sentiment score'}, ylabel='Frequency'>

# %%
#Q2
df_lex["sentiment"].mean()
# Out:
# 1.4216084484146291e-05

# %%
#Q3
df_lex.sort_values(by="sentiment",
                   ascending=False).head(5)["sentiment"].mean().round(2)
# Out:
# 2.72

# %%
df_lex["sentiment"] <= -.5
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4919    False
# 4920    False
# 4921    False
# 4922    False
# 4923    False
# Name: sentiment, Length: 4924, dtype: bool

# %%
#Q4
df_lex[df_lex["sentiment"] <= -.5]
# Out:
#          word  sentiment  std.dev
# 0        ugly      -3.90     1.16
# 1     painful      -3.69     1.53
# 2      intent      -3.49     1.67
# 3    terrible      -3.38     1.55
# 4       drunk      -3.28     1.16
# ..        ...        ...      ...
# 851    dozens      -0.50     0.40
# 852      arab      -0.50     0.65
# 853  somebody      -0.50     1.10
# 854       fog      -0.50     0.74
# 855  identity      -0.50     0.42
#
# [856 rows x 3 columns]

# %%
#Q5
mapping = {}
for row in df_lex[["word", "sentiment"]].to_dict("records"):
  mapping[row["word"]] = row["sentiment"]
mapping
# Out:
# {'ugly': -3.9,
#  'painful': -3.69,
#  'intent': -3.49,
#  'terrible': -3.38,
#  'drunk': -3.28,
#  'tragedy': -3.26,
#  'awful': -3.21,
#  'weak': -3.12,
#  'worst': -3.1,
#  'accident': -3.03,
#  'nightmare': -3.02,
#  'victim': -3.01,
#  'destruction': -2.95,
#  'faced': -2.93,
#  'damned': -2.92,
#  'souls': -2.92,
#  'scary': -2.92,
#  'poverty': -2.89,
#  'suicide': -2.85,
#  'events': -2.85,
#  'sorts': -2.84,
#  'trapped': -2.83,
#  'monster': -2.82,
#  'lonely': -2.8,
#  'circles': -2.8,
#  'scream': -2.79,
#  'ridiculous': -2.76,
#  'situations': -2.75,
#  'fate': -2.69,
#  'stupid': -2.67,
#  'bitter': -2.66,
#  'rural': -2.66,
#  'harsh': -2.66,
#  'fault': -2.62,
#  're': -2.6,
#  'occurred': -2.6,
#  'circumstances': -2.59,
#  'blame': -2.59,
#  'housing': -2.58,
#  'snake': -2.58,
#  'bored': -2.56,
#  'blacks': -2.55,
#  'sick': -2.53,
#  'dragon': -2.51,
#  'complained': -2.51,
#  'nasty': -2.5,
#  'tired': -2.49,
#  'acts': -2.48,
#  'bloody': -2.48,
#  'beast': -2.47,
#  'smelled': -2.44,
#  'minority': -2.43,
#  'incident': -2.42,
#  'boring': -2.42,
#  'creatures': -2.42,
#  'suffering': -2.39,
#  'creature': -2.39,
#  'anxious': -2.37,
#  'smells': -2.36,
#  'suffer': -2.36,
#  'frustrated': -2.36,
#  'worried': -2.34,
#  'mistakes': -2.33,
#  'witch': -2.33,
#  'battles': -2.31,
#  'upset': -2.3,
#  'angry': -2.3,
#  'beings': -2.29,
#  'victims': -2.28,
#  'mad': -2.27,
#  'admitted': -2.27,
#  'suffered': -2.27,
#  'confused': -2.26,
#  'opponents': -2.26,
#  'deadly': -2.26,
#  'smell': -2.26,
#  'alien': -2.25,
#  'stayed': -2.24,
#  'inevitable': -2.21,
#  'bother': -2.2,
#  'hungry': -2.2,
#  'scent': -2.19,
#  'cole': -2.19,
#  'bothered': -2.19,
#  'shame': -2.17,
#  'frightened': -2.15,
#  'troubled': -2.15,
#  'random': -2.15,
#  'guessed': -2.14,
#  'disaster': -2.12,
#  'ghost': -2.11,
#  'mess': -2.11,
#  'exhausted': -2.1,
#  'punishment': -2.1,
#  'demanding': -2.09,
#  'fucking': -2.09,
#  'contrast': -2.09,
#  'merely': -2.09,
#  'minds': -2.08,
#  'disappointed': -2.08,
#  'belong': -2.07,
#  'practically': -2.07,
#  'necessarily': -2.07,
#  'desperate': -2.07,
#  'strange': -2.06,
#  'aging': -2.06,
#  'crash': -2.05,
#  'bin': -2.05,
#  'worse': -2.04,
#  'hurt': -2.02,
#  'deaths': -2.01,
#  'cast': -2.01,
#  'scared': -2.01,
#  'lack': -1.97,
#  'fever': -1.96,
#  'concerned': -1.95,
#  'dirty': -1.94,
#  'murder': -1.93,
#  'likes': -1.93,
#  'powers': -1.92,
#  'burns': -1.91,
#  'remind': -1.89,
#  'crime': -1.89,
#  'mistake': -1.87,
#  'cat': -1.86,
#  'crimes': -1.86,
#  'lillian': -1.85,
#  'humanity': -1.85,
#  'uncomfortable': -1.85,
#  'injured': -1.84,
#  'damage': -1.82,
#  'dangerous': -1.82,
#  'devil': -1.81,
#  'occasional': -1.81,
#  'dealing': -1.8,
#  'insisted': -1.8,
#  'hurricane': -1.78,
#  'committed': -1.78,
#  'precisely': -1.77,
#  'cheap': -1.76,
#  'forgot': -1.74,
#  'everywhere': -1.74,
#  'cigarettes': -1.73,
#  'considering': -1.73,
#  'creation': -1.72,
#  'protest': -1.72,
#  'death': -1.72,
#  'deserve': -1.71,
#  'enemies': -1.71,
#  'gods': -1.7,
#  'families': -1.69,
#  'nervous': -1.69,
#  'causing': -1.69,
#  'wounded': -1.68,
#  'improve': -1.68,
#  'animal': -1.68,
#  'fool': -1.68,
#  'harm': -1.68,
#  'suspect': -1.68,
#  'occur': -1.67,
#  'minor': -1.66,
#  'guilty': -1.66,
#  'bird': -1.66,
#  'invisible': -1.65,
#  'suddenly': -1.64,
#  'chaos': -1.64,
#  'mccarthy': -1.63,
#  'smoke': -1.63,
#  'startled': -1.62,
#  'violence': -1.62,
#  'living': -1.62,
#  'feared': -1.62,
#  'threatened': -1.61,
#  'injuries': -1.6,
#  'injury': -1.6,
#  'innocent': -1.59,
#  'magic': -1.59,
#  'accompanied': -1.59,
#  'crisis': -1.58,
#  'bear': -1.56,
#  'soap': -1.56,
#  'embarrassed': -1.56,
#  'dogs': -1.55,
#  'tiger': -1.55,
#  'wealthy': -1.54,
#  'dog': -1.54,
#  'wolf': -1.54,
#  'burned': -1.53,
#  'arrested': -1.53,
#  'bomb': -1.52,
#  'bunch': -1.52,
#  'wound': -1.52,
#  'shocked': -1.52,
#  'absolute': -1.51,
#  'damn': -1.51,
#  'caused': -1.51,
#  'severe': -1.51,
#  'spirits': -1.5,
#  'accused': -1.5,
#  'sweat': -1.5,
#  'angels': -1.5,
#  'assault': -1.49,
#  'strikes': -1.48,
#  'attacks': -1.46,
#  'deeply': -1.46,
#  'survived': -1.46,
#  'pig': -1.46,
#  'beer': -1.44,
#  'insects': -1.44,
#  'stroke': -1.44,
#  'attack': -1.44,
#  'terrorism': -1.44,
#  'illness': -1.44,
#  'animals': -1.43,
#  'dumb': -1.43,
#  'humans': -1.42,
#  'pain': -1.42,
#  'killed': -1.41,
#  'lately': -1.41,
#  'whole': -1.4,
#  'mixed': -1.4,
#  'tail': -1.4,
#  'afraid': -1.4,
#  'communities': -1.39,
#  'virus': -1.39,
#  'trembling': -1.39,
#  'terrorist': -1.38,
#  'birds': -1.38,
#  'sad': -1.37,
#  'elderly': -1.37,
#  'whoever': -1.36,
#  'drank': -1.36,
#  'cared': -1.36,
#  'urban': -1.36,
#  'spell': -1.35,
#  'tobacco': -1.35,
#  'bleeding': -1.35,
#  'increasingly': -1.34,
#  'drinks': -1.34,
#  'useless': -1.34,
#  'giant': -1.33,
#  'pet': -1.33,
#  'drink': -1.33,
#  'changing': -1.33,
#  'act': -1.33,
#  'loss': -1.33,
#  'bears': -1.32,
#  'threatening': -1.32,
#  'stunned': -1.32,
#  'flies': -1.32,
#  'killing': -1.31,
#  'feeling': -1.31,
#  'situation': -1.31,
#  'racial': -1.3,
#  'countless': -1.3,
#  'explosion': -1.3,
#  'arrest': -1.3,
#  'alcohol': -1.29,
#  'wished': -1.29,
#  'repeatedly': -1.28,
#  'bandar': -1.28,
#  'nation': -1.27,
#  'drinking': -1.27,
#  'affected': -1.27,
#  'trap': -1.27,
#  'trouble': -1.26,
#  'suspected': -1.26,
#  'consequences': -1.26,
#  'changed': -1.26,
#  'bug': -1.26,
#  'bull': -1.25,
#  'residents': -1.25,
#  'conditions': -1.25,
#  'cigarette': -1.25,
#  'involved': -1.25,
#  'liked': -1.25,
#  'destroyed': -1.24,
#  'robot': -1.24,
#  'counted': -1.24,
#  'fought': -1.24,
#  'symptoms': -1.23,
#  'disorder': -1.23,
#  'african': -1.23,
#  'surprised': -1.22,
#  'big': -1.22,
#  'infection': -1.22,
#  'bitch': -1.21,
#  'causes': -1.21,
#  'jail': -1.21,
#  'burning': -1.21,
#  'collapse': -1.21,
#  'imagined': -1.21,
#  'terrorists': -1.2,
#  'cause': -1.2,
#  'essentially': -1.19,
#  'crazy': -1.19,
#  'cry': -1.19,
#  'reaction': -1.19,
#  'threats': -1.19,
#  'failure': -1.18,
#  'isolated': -1.18,
#  'got': -1.18,
#  'relieved': -1.18,
#  'witness': -1.17,
#  'teddy': -1.17,
#  'crying': -1.17,
#  'violent': -1.17,
#  'scene': -1.16,
#  'result': -1.16,
#  'slavery': -1.16,
#  'reminded': -1.15,
#  'cats': -1.14,
#  'immigrants': -1.14,
#  'species': -1.14,
#  'prison': -1.14,
#  'habit': -1.13,
#  'enemy': -1.13,
#  'disease': -1.13,
#  'cities': -1.13,
#  'warned': -1.13,
#  'vulnerable': -1.12,
#  'scenes': -1.12,
#  'recovery': -1.12,
#  'seemingly': -1.11,
#  'ali': -1.11,
#  'abruptly': -1.11,
#  'sort': -1.11,
#  'mouse': -1.1,
#  'boy': -1.1,
#  'feed': -1.1,
#  'trick': -1.1,
#  'regions': -1.1,
#  'sometimes': -1.1,
#  'destroy': -1.09,
#  'knew': -1.09,
#  'air': -1.09,
#  'damp': -1.08,
#  'danger': -1.08,
#  'phenomenon': -1.08,
#  'hunger': -1.08,
#  'serious': -1.07,
#  'feel': -1.07,
#  'abuse': -1.07,
#  'worlds': -1.07,
#  'error': -1.07,
#  'definition': -1.07,
#  'towns': -1.07,
#  'rich': -1.06,
#  'charges': -1.06,
#  'illegal': -1.06,
#  'clean': -1.06,
#  'attitude': -1.06,
#  'collapsed': -1.05,
#  'transformed': -1.05,
#  'saddam': -1.05,
#  'challenge': -1.05,
#  'actions': -1.05,
#  'wise': -1.05,
#  'distant': -1.05,
#  'frequent': -1.04,
#  'nest': -1.04,
#  'ill': -1.04,
#  'combination': -1.04,
#  'peterson': -1.04,
#  'talked': -1.03,
#  'aware': -1.03,
#  'charged': -1.03,
#  'weapons': -1.03,
#  'problems': -1.03,
#  'horror': -1.03,
#  'deal': -1.03,
#  'wings': -1.03,
#  'depression': -1.03,
#  'alabama': -1.02,
#  'breath': -1.02,
#  'afghanistan': -1.02,
#  'taliban': -1.02,
#  'observed': -1.02,
#  'cage': -1.02,
#  'experienced': -1.02,
#  'saudi': -1.02,
#  'sounded': -1.01,
#  'captured': -1.01,
#  'diseases': -1.01,
#  'loves': -1.01,
#  'demands': -1.01,
#  'convinced': -1.01,
#  'gang': -1.01,
#  'initially': -1.01,
#  'ethnic': -1.0,
#  'possibility': -1.0,
#  'criminal': -1.0,
#  'coffin': -0.99,
#  'potentially': -0.99,
#  'aimed': -0.98,
#  'fires': -0.98,
#  'bastard': -0.98,
#  'champagne': -0.98,
#  'challenges': -0.98,
#  'healing': -0.98,
#  'areas': -0.97,
#  'dying': -0.97,
#  'breathe': -0.97,
#  'feeding': -0.97,
#  'resulting': -0.97,
#  'deer': -0.97,
#  'bite': -0.97,
#  'afford': -0.97,
#  'silly': -0.97,
#  'killer': -0.97,
#  'threat': -0.96,
#  'warming': -0.96,
#  'bodies': -0.96,
#  'ass': -0.96,
#  'bacteria': -0.95,
#  'taste': -0.95,
#  'slave': -0.95,
#  'fish': -0.95,
#  'solve': -0.95,
#  'escaped': -0.95,
#  'woke': -0.95,
#  'suburban': -0.94,
#  'extreme': -0.94,
#  'weapon': -0.94,
#  'hunt': -0.94,
#  'americans': -0.94,
#  'mississippi': -0.94,
#  'represent': -0.94,
#  'wrong': -0.94,
#  'pipe': -0.94,
#  'criticism': -0.93,
#  'intense': -0.93,
#  'whites': -0.93,
#  'individuals': -0.93,
#  'panic': -0.93,
#  'loud': -0.93,
#  'eaten': -0.92,
#  'alarm': -0.92,
#  'southern': -0.92,
#  'survive': -0.92,
#  'ignoring': -0.91,
#  'forgotten': -0.91,
#  'smoking': -0.91,
#  'pakistan': -0.91,
#  'lots': -0.91,
#  'attacked': -0.91,
#  'northern': -0.91,
#  'washed': -0.91,
#  'homes': -0.9,
#  'concerns': -0.9,
#  'stern': -0.9,
#  'noise': -0.89,
#  'area': -0.89,
#  'faint': -0.89,
#  'rescue': -0.89,
#  'sheep': -0.88,
#  'problem': -0.88,
#  'wild': -0.88,
#  'throat': -0.88,
#  'biological': -0.88,
#  'stress': -0.88,
#  'due': -0.88,
#  'awkward': -0.88,
#  'cleaning': -0.87,
#  'immigration': -0.87,
#  'prevent': -0.87,
#  'target': -0.87,
#  'represented': -0.87,
#  'aids': -0.87,
#  'wondering': -0.87,
#  'battle': -0.87,
#  'sudden': -0.87,
#  'somewhat': -0.86,
#  'sound': -0.86,
#  'lot': -0.86,
#  'immediate': -0.86,
#  'care': -0.86,
#  'population': -0.86,
#  'guy': -0.86,
#  'human': -0.85,
#  'treat': -0.85,
#  'wars': -0.85,
#  'nerve': -0.85,
#  'country': -0.85,
#  'flying': -0.85,
#  'avoid': -0.85,
#  'cow': -0.85,
#  'units': -0.85,
#  'these': -0.85,
#  'knight': -0.85,
#  'slept': -0.84,
#  'jay': -0.84,
#  'dusty': -0.84,
#  'indians': -0.84,
#  'fraud': -0.83,
#  'screaming': -0.83,
#  'prisoners': -0.82,
#  'hero': -0.82,
#  'drugs': -0.82,
#  'hear': -0.82,
#  'existence': -0.82,
#  'curious': -0.82,
#  'issue': -0.81,
#  'confusion': -0.81,
#  'wake': -0.81,
#  'blind': -0.81,
#  'trial': -0.81,
#  'aspects': -0.81,
#  'dream': -0.8,
#  'survival': -0.8,
#  'event': -0.8,
#  'powerful': -0.8,
#  'linked': -0.8,
#  'absence': -0.8,
#  'encounter': -0.8,
#  'bone': -0.8,
#  'facing': -0.8,
#  'heard': -0.8,
#  'islamic': -0.8,
#  'reference': -0.8,
#  'dreams': -0.8,
#  'riding': -0.8,
#  'strike': -0.8,
#  'kinds': -0.79,
#  'constantly': -0.79,
#  'defeat': -0.79,
#  'endless': -0.79,
#  'shouting': -0.79,
#  'centers': -0.79,
#  'cycle': -0.79,
#  'remote': -0.78,
#  'climate': -0.78,
#  'hunting': -0.78,
#  'alike': -0.78,
#  'direct': -0.78,
#  'screamed': -0.78,
#  'wet': -0.78,
#  'laden': -0.78,
#  'shit': -0.77,
#  'limited': -0.77,
#  'viewed': -0.77,
#  'laugh': -0.77,
#  'dull': -0.76,
#  'shift': -0.76,
#  'variety': -0.76,
#  'hunter': -0.76,
#  'rival': -0.76,
#  'becoming': -0.76,
#  'thing': -0.76,
#  'struck': -0.76,
#  'racing': -0.76,
#  'angle': -0.76,
#  'fly': -0.76,
#  'hollow': -0.75,
#  'figures': -0.75,
#  'fresh': -0.75,
#  'asleep': -0.75,
#  'persons': -0.75,
#  'diabetes': -0.75,
#  'jet': -0.74,
#  'characters': -0.74,
#  'stare': -0.74,
#  'helicopter': -0.74,
#  'internal': -0.74,
#  'empire': -0.74,
#  'felt': -0.74,
#  'blood': -0.73,
#  'fur': -0.73,
#  'cattle': -0.73,
#  'surrounding': -0.73,
#  'targets': -0.73,
#  'admit': -0.73,
#  'plane': -0.73,
#  'concentration': -0.73,
#  'badly': -0.73,
#  'physically': -0.73,
#  'toilet': -0.73,
#  'reasons': -0.73,
#  'knocked': -0.73,
#  'remarkable': -0.72,
#  'fighting': -0.72,
#  'argued': -0.72,
#  'races': -0.72,
#  'mental': -0.72,
#  'lit': -0.72,
#  'police': -0.72,
#  'bit': -0.72,
#  'familiar': -0.72,
#  'allies': -0.72,
#  'acting': -0.72,
#  'risk': -0.71,
#  'facilities': -0.71,
#  'led': -0.71,
#  'cases': -0.71,
#  'flew': -0.71,
#  'bottle': -0.71,
#  'impressed': -0.71,
#  'fire': -0.71,
#  'kill': -0.71,
#  'fight': -0.71,
#  'coastal': -0.71,
#  'instantly': -0.71,
#  'transportation': -0.7,
#  'hears': -0.7,
#  'convince': -0.7,
#  'kitchen': -0.69,
#  'offices': -0.69,
#  'war': -0.69,
#  'responsible': -0.69,
#  'losses': -0.68,
#  'troops': -0.68,
#  'fired': -0.68,
#  'drug': -0.68,
#  'civilization': -0.68,
#  'handful': -0.68,
#  'quit': -0.68,
#  'crew': -0.68,
#  'basement': -0.68,
#  'upstairs': -0.67,
#  'highly': -0.67,
#  'swallowed': -0.67,
#  'capture': -0.67,
#  'change': -0.67,
#  'changes': -0.67,
#  'feels': -0.67,
#  'joining': -0.67,
#  'forces': -0.67,
#  'closely': -0.67,
#  'associated': -0.67,
#  'resist': -0.67,
#  'baghdad': -0.67,
#  'cave': -0.67,
#  'shock': -0.67,
#  'lone': -0.67,
#  'rome': -0.66,
#  'blast': -0.66,
#  'referred': -0.66,
#  'schools': -0.66,
#  'excited': -0.66,
#  'stated': -0.66,
#  'authorities': -0.66,
#  'fuck': -0.66,
#  'interested': -0.66,
#  'farms': -0.65,
#  'hell': -0.65,
#  'case': -0.65,
#  'wash': -0.65,
#  'jump': -0.65,
#  'effects': -0.65,
#  'coffee': -0.65,
#  'garbage': -0.65,
#  'wine': -0.65,
#  'meat': -0.65,
#  'alone': -0.65,
#  'involving': -0.65,
#  'critics': -0.65,
#  'equivalent': -0.65,
#  'continuing': -0.65,
#  'latter': -0.65,
#  'ears': -0.64,
#  'extremely': -0.64,
#  'fed': -0.64,
#  'declined': -0.64,
#  'statistics': -0.64,
#  'literally': -0.64,
#  'iran': -0.64,
#  'blow': -0.64,
#  'basically': -0.64,
#  'plot': -0.64,
#  'traveling': -0.64,
#  'historical': -0.64,
#  'describes': -0.64,
#  'jury': -0.64,
#  'steal': -0.64,
#  'room': -0.64,
#  'flames': -0.64,
#  'demanded': -0.63,
#  'filled': -0.63,
#  'spreading': -0.63,
#  'missile': -0.63,
#  'condition': -0.63,
#  'bet': -0.63,
#  'risks': -0.63,
#  'such': -0.63,
#  'opposed': -0.63,
#  'muslim': -0.63,
#  'heavily': -0.63,
#  'boom': -0.63,
#  'torn': -0.63,
#  'against': -0.62,
#  'becomes': -0.62,
#  'investigation': -0.62,
#  'overhead': -0.62,
#  'sentence': -0.62,
#  'louder': -0.62,
#  'landing': -0.62,
#  'genes': -0.62,
#  'sleep': -0.62,
#  'ate': -0.62,
#  'thousands': -0.62,
#  'straw': -0.62,
#  'region': -0.62,
#  'terror': -0.62,
#  'cancer': -0.62,
#  'opposition': -0.62,
#  'count': -0.61,
#  'poured': -0.61,
#  'sleeping': -0.61,
#  'rapid': -0.61,
#  'spite': -0.61,
#  'nor': -0.61,
#  'evolution': -0.61,
#  'mentioned': -0.61,
#  'bedroom': -0.61,
#  'race': -0.61,
#  'iraqi': -0.61,
#  'stole': -0.61,
#  'bullet': -0.61,
#  'particularly': -0.61,
#  'shower': -0.6,
#  'difficult': -0.6,
#  'reality': -0.6,
#  'burn': -0.6,
#  'moreover': -0.6,
#  'without': -0.6,
#  'episode': -0.6,
#  'bottles': -0.6,
#  'psychological': -0.6,
#  'affect': -0.6,
#  'cure': -0.6,
#  'terms': -0.6,
#  'firing': -0.6,
#  'trigger': -0.6,
#  'burst': -0.59,
#  'limits': -0.59,
#  'pressure': -0.59,
#  'raw': -0.59,
#  'during': -0.59,
#  'challenging': -0.59,
#  'planes': -0.59,
#  'iraq': -0.58,
#  'space': -0.58,
#  'ordinary': -0.58,
#  'economic': -0.58,
#  'shut': -0.58,
#  'aircraft': -0.58,
#  'grew': -0.58,
#  'exposure': -0.58,
#  'signs': -0.58,
#  'genetic': -0.58,
#  'tea': -0.58,
#  'shoot': -0.58,
#  'hearing': -0.58,
#  'labor': -0.58,
#  'laughter': -0.58,
#  'buildings': -0.58,
#  'awake': -0.58,
#  'purpose': -0.58,
#  'emergency': -0.57,
#  'gotten': -0.57,
#  'less': -0.57,
#  'type': -0.57,
#  'pouring': -0.57,
#  'chemicals': -0.57,
#  'shot': -0.57,
#  'treated': -0.57,
#  'rid': -0.57,
#  'acknowledged': -0.57,
#  'funny': -0.57,
#  'sink': -0.57,
#  'groups': -0.56,
#  'ignore': -0.56,
#  'mention': -0.56,
#  'development': -0.56,
#  'catching': -0.56,
#  'washing': -0.56,
#  'hunters': -0.56,
#  'protect': -0.56,
#  'hit': -0.56,
#  'concluded': -0.56,
#  'comment': -0.55,
#  'mercy': -0.55,
#  'anxiety': -0.55,
#  'blew': -0.55,
#  'needs': -0.55,
#  'flame': -0.55,
#  'flight': -0.54,
#  'apparent': -0.54,
#  'patients': -0.54,
#  'actual': -0.54,
#  'decisions': -0.54,
#  'prospect': -0.54,
#  'busy': -0.54,
#  'little': -0.54,
#  'ribs': -0.54,
#  'repair': -0.54,
#  'politicians': -0.54,
#  'community': -0.54,
#  'gene': -0.54,
#  'spots': -0.54,
#  'citizens': -0.54,
#  'activities': -0.53,
#  'majority': -0.53,
#  'soldiers': -0.53,
#  'missed': -0.53,
#  'tension': -0.53,
#  'lighting': -0.53,
#  'steam': -0.53,
#  'nuclear': -0.53,
#  'difficulty': -0.53,
#  'sharply': -0.53,
#  'processes': -0.53,
#  'slaves': -0.53,
#  'shooting': -0.53,
#  'wing': -0.53,
#  'pills': -0.52,
#  'favor': -0.52,
#  'negative': -0.52,
#  'projects': -0.52,
#  'added': -0.52,
#  'ignored': -0.52,
#  'issues': -0.52,
#  'construction': -0.52,
#  'eat': -0.52,
#  'ian': -0.52,
#  'sounds': -0.52,
#  'expecting': -0.52,
#  'suggested': -0.52,
#  'shield': -0.52,
#  'cries': -0.51,
#  'storm': -0.51,
#  'constant': -0.51,
#  'thinks': -0.51,
#  'wildlife': -0.51,
#  'examples': -0.51,
#  'burden': -0.51,
#  'spread': -0.51,
#  'leader': -0.5,
#  'guns': -0.5,
#  'border': -0.5,
#  'cloud': -0.5,
#  'broken': -0.5,
#  'partly': -0.5,
#  'tales': -0.5,
#  'fierce': -0.5,
#  'glass': -0.5,
#  'decline': -0.5,
#  'denied': -0.5,
#  'towel': -0.5,
#  'brain': -0.5,
#  'recognized': -0.5,
#  'dozens': -0.5,
#  'arab': -0.5,
#  'somebody': -0.5,
#  'fog': -0.5,
#  'identity': -0.5,
#  'became': -0.49,
#  'shadow': -0.49,
#  'lightning': -0.49,
#  'too': -0.49,
#  'brad': -0.49,
#  'charge': -0.49,
#  'typically': -0.49,
#  'landed': -0.49,
#  'realized': -0.49,
#  'himself': -0.49,
#  'powell': -0.49,
#  'thoroughly': -0.49,
#  'mood': -0.49,
#  'effectively': -0.49,
#  'teeth': -0.49,
#  'currently': -0.49,
#  'makes': -0.49,
#  'cruz': -0.48,
#  'quickly': -0.48,
#  'al': -0.48,
#  'yankees': -0.48,
#  'joke': -0.48,
#  'total': -0.48,
#  'treatment': -0.48,
#  'dust': -0.48,
#  'facts': -0.48,
#  'types': -0.48,
#  'tissue': -0.48,
#  'horses': -0.48,
#  'brains': -0.48,
#  'bathroom': -0.48,
#  'breakfast': -0.47,
#  'mist': -0.47,
#  'jokes': -0.47,
#  'rooms': -0.47,
#  'bar': -0.47,
#  'footsteps': -0.47,
#  'ongoing': -0.47,
#  'believes': -0.47,
#  'combat': -0.47,
#  'many': -0.47,
#  'seemed': -0.47,
#  'punch': -0.47,
#  'harris': -0.47,
#  'pilot': -0.47,
#  'nonetheless': -0.47,
#  'armed': -0.47,
#  'horse': -0.47,
#  'gulf': -0.47,
#  'shadows': -0.46,
#  'shapes': -0.46,
#  'sharp': -0.46,
#  'grief': -0.46,
#  'voices': -0.46,
#  'alliance': -0.46,
#  'everyday': -0.46,
#  'stomach': -0.46,
#  'link': -0.46,
#  'eliot': -0.45,
#  'mild': -0.45,
#  'hoped': -0.45,
#  'rough': -0.45,
#  'overcome': -0.45,
#  'bucket': -0.45,
#  'juice': -0.45,
#  'claimed': -0.45,
#  'expensive': -0.45,
#  'sliced': -0.45,
#  'farmers': -0.45,
#  'stuff': -0.45,
#  'duncan': -0.45,
#  'barrel': -0.45,
#  'matters': -0.44,
#  'hide': -0.44,
#  'cells': -0.44,
#  'universe': -0.44,
#  'wiped': -0.44,
#  'rifle': -0.44,
#  'surgery': -0.44,
#  'mysterious': -0.44,
#  'vanished': -0.44,
#  'lead': -0.44,
#  'gun': -0.44,
#  'often': -0.44,
#  'several': -0.43,
#  'proved': -0.43,
#  'shelter': -0.43,
#  'pitch': -0.43,
#  'become': -0.43,
#  'cops': -0.43,
#  'again': -0.43,
#  'detective': -0.43,
#  'northwest': -0.43,
#  'unknown': -0.43,
#  'themselves': -0.43,
#  'proposed': -0.43,
#  'altogether': -0.43,
#  'wondered': -0.43,
#  'kid': -0.43,
#  'eating': -0.43,
#  'went': -0.43,
#  'shots': -0.43,
#  'force': -0.43,
#  'kicking': -0.43,
#  'describe': -0.43,
#  'calvin': -0.42,
#  'odd': -0.42,
#  'soldier': -0.42,
#  'gone': -0.42,
#  'lungs': -0.42,
#  'failing': -0.42,
#  'orleans': -0.42,
#  'numerous': -0.42,
#  'dozen': -0.42,
#  'ai': -0.42,
#  'tended': -0.42,
#  'doctors': -0.42,
#  'blowing': -0.42,
#  'chemical': -0.42,
#  'challenged': -0.42,
#  'diverse': -0.41,
#  'hogan': -0.41,
#  'clouds': -0.41,
#  'background': -0.41,
#  'lawyer': -0.41,
#  'consciousness': -0.41,
#  'argue': -0.41,
#  'clinical': -0.41,
#  'existed': -0.41,
#  'workers': -0.41,
#  'patient': -0.41,
#  'domestic': -0.41,
#  'crack': -0.41,
#  'explanation': -0.41,
#  'unusual': -0.41,
#  'regarding': -0.41,
#  'lives': -0.41,
#  'handle': -0.41,
#  'jews': -0.41,
#  'skinny': -0.4,
#  'moment': -0.4,
#  'impression': -0.4,
#  'harder': -0.4,
#  'cop': -0.4,
#  ...}

# %%
#Q6
comment = "i think breaking bad is boring"
def sentiment_score_text(text):
  text = text.lower()
  score = 0
  n = 0
  for word in text.split():
    if word in mapping:
      n += 1
      score += mapping[word]
  if n > 0:
    return score / n
  return 0
round(sentiment_score_text(comment),2)
# Out:
# -0.68

# %%
#Q7
def sentiment_score(row):
  text = row["text"].lower()
  score = 0
  n = 0
  for word in text.split():
    if word in mapping:
      n += 1
      score += mapping[word]
  if n > 0:
    return score / n
  return 0

df["simple_sentiment"] = df.apply(sentiment_score, axis=1)
df
# Out:
#                                                   text  simple_sentiment
# 0    They had to smash it with the handle of a knif...         -0.303333
# 1                     YEAH SIMPLE INGREDIENTS MR BETCH          0.550000
# 2                     Tuco’s looking pretty tight yo ❤          0.763333
# 3      I’m wondering if these are keto friendly.. Lol.         -0.860000
# 4                         They ain’t that good low key          0.305000
# ..                                                 ...               ...
# 462  This is literally the reason why i bought popc...         -0.061667
# 463  aint no way they actually made this a commerci...         -0.166667
# 464  When I tasted the white cheddar popcorners shi...          0.030000
# 465  Imagine the production and recipe teams for Po...          0.112727
# 466  I seen the commercial on Super Bowl LVII and g...         -0.278333
#
# [467 rows x 2 columns]

# %%
#Q8
# "absolutely loved" - may have a compounding positive effect
sentiment_score_text("Saw the commercial I tried them as a joke then I absolutely loved them")
# Out:
# -0.078

# %%
mapping["love"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-59772e20288b> in <cell line: 1>()
# ----> 1 mapping["love"]
#
# KeyError: 'love'

# %%
#Q9
comment = "Saw the commercial I tried them as a joke then I absolutely loved them"
words = comment.lower().split()
for left, right in zip(words[:-1], words[1:]):
  print(left, right)

# this is a manual way of creating bigrams or context aware lexicons
# Out:
# saw the
# the commercial
# commercial i
# i tried
# tried them
# them as
# as a
# a joke
# joke then
# then i
# i absolutely
# absolutely loved
# loved them

# %%
#Q10
import nltk

nltk.download("vader_lexicon")
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
def score_vader(row):
  text = row["text"]
  return sia.polarity_scores(text)["compound"]

df["vader_sentiment"] = df.apply(score_vader, axis=1)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
df
# Out:
#                                                   text  simple_sentiment  \
# 0    They had to smash it with the handle of a knif...         -0.303333
# 1                     YEAH SIMPLE INGREDIENTS MR BETCH          0.550000
# 2                     Tuco’s looking pretty tight yo ❤          0.763333
# 3      I’m wondering if these are keto friendly.. Lol.         -0.860000
# 4                         They ain’t that good low key          0.305000
# ..                                                 ...               ...
# 462  This is literally the reason why i bought popc...         -0.061667
# 463  aint no way they actually made this a commerci...         -0.166667
# 464  When I tasted the white cheddar popcorners shi...          0.030000
# 465  Imagine the production and recipe teams for Po...          0.112727
# 466  I seen the commercial on Super Bowl LVII and g...         -0.278333
#
#      vader_sentiment
# 0             0.0000
# 1             0.2960
# 2             0.4939
# 3             0.4215
# 4             0.2023
# ..               ...
# 462          -0.2960
# 463           0.2235
# 464          -0.5574
# 465           0.0000
# 466           0.8449
#
# [467 rows x 3 columns]

# %%
#Q11
df["vader_sentiment"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["simple_sentiment"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
